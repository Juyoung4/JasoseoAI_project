# %%
import pickle
import pandas as pd
import numpy as np
import re

# %%
data_path = "/home/ai-sjjy/workspace/juyoung/JasoseoAI_project/3.data/JobKorea/dataset/"

# %%
f = open(data_path+'JobKorea_convert.pickle', 'rb')
raw_df = pickle.load(f)
f.close()
raw_df.head(3)
# Out:
#   company_name                                        company_url  \
# 0     (주)경동나비엔  https://www.jobkorea.co.kr/Recruit/Co_Read/C/k...
# 1   한국수력원자력(주)  https://www.jobkorea.co.kr/Recruit/Co_Read/C/c...
# 2  (주)포스코인터내셔널  https://www.jobkorea.co.kr/Recruit/Co_Read/C/e...
#
#                apply_info                                     applicant_info  \
# 0   2021년 상반기 신입 제품·서비스영업  \r\n\r\n                    수도권4년\r\n         ...
# 1  2021년 상반기 신입 해외영업·무역영업  \r\n\r\n                    수도권4년\r\n         ...
# 2   2021년 상반기 신입 수출입·무역사무  \r\n\r\n                    고졸\r\n            ...
#
#   score                                         score_desc  \
# 0     2  전반적으로 아쉬운 자기소개서입니다. 질문에 대한 명쾌한 답이 없다는 점이 본 자기소...
# 1     2  전반적으로 호감을 주지 못한 자기소개서입니다. 본 자기소개서의 가장 큰 문제는 지원...
# 2     2  일반적으로 많은 지원자들이 실수하는 방식대로 쓴 자기소개서입니다. 자신에 대해 소개...
#
#                                                paper  \
# 0  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...

# %%
raw_df.iloc[2271]['url']
# Out:
# 'https://www.jobkorea.co.kr/starter/PassAssay/View/193258?Page=114&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0'

# %% [markdown]
# # 전처리

# %% [markdown]
# ### raw_df 필요한 정보만 가져오기 => 'company_name', 'paper', 'url'

# %%
raw_df = raw_df[['company_name', 'paper', 'url']]

# %%
raw_df.head(3)
# Out:
#   company_name                                              paper  \
# 0     (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1   한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...

# %%
raw_df.iloc[1]['paper']
# Out:
# [['본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다양한 활동(학교, 회사, 동아리, 동호회 등)을 통해 지원한 직무와 관련하여 쌓은 경험경력 사항에 대해 작성해 주십시오. (1000자)',
#   '\r\n1) 언제, 어디서 활동했던 경험인지 기술해 주십시오. (200자)\r4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어학과 함께 소프트웨어공학 및 기계공학과의 졸업작품에도 각 1년간 참여했습니다. 조직응용기사 취득 및 2개 기사 1차 합격, 개인 서버 운영, 전자공학과 학부연구생과 지능형 자동차 경진대회 출전 등의 경험도 있습니다만, 자수 제한으로 인해 졸업작품 경험에 관해 기술하겠습니다.아쉬운점 1\r\r2) 해당 활동에서 본인이 맡았던 역할에 대해 기술해 주십시오. (400자)\r정보통신공학에서는 온라인 자동 동기화 시스템을 제작했는데, 하드웨어 설계 및 제작, 펌웨어 (MCU)프로그래밍을 맡았습니다.\rSW학 작품에서는 애플 iOS 앱을 2개 만들었고, 아이디어 회의부터 Swift와 Objective C언어로 프로그래밍, UI 제작, 문서작업, PPT 제작 등을 했습니다.\r기계공학과 작품은 깡통크기의 초소형 위성 쏜 뒤 지상 복귀 중 위성의 자세를 제어하고 통신하는 것 이었습니다. 여기서 전자부품 선정과 C언어 프로그래밍 (통신, 자세제어)에 참여했습니다. 영어학과 응용탐구 (졸업준비 과목)에서는 영어 Resume와 Cover letter, SOP (대학원 진학을 위한 연구계획서) 등을 작성하는 연습을 했고, 매주 모여 연습한 것과 각자의 취업준비 과정을 발표하여 공유했습니다.아쉬운점 2\r\r3) 해당 활동의 결과와 이를 통해 본인이 배운 점은 무엇인지 기술해 주십시오. (400자)\r정보통신공학과 기계공학의 경우 제가 매우 선호하고, 경험이 많은 C언어와 펌웨어 프로그래밍을 맡았기 때문에 기본기를 다질 수 있었습니다. 제가 잘 모르는 타 전공의 기초지식들을 제가 잘 아는 HW지식과 접목시키는 것은 정말 흥미로웠습니다. 또한, 소프트웨어학과 졸업작품은 SW에 대한 색다른 경험을 맛보게 해주어 제가 전자공학과에서 정보통신공학과로 전과하는 계기가 되었습니다. 또한 다양한 전공의 여러 사람들과 정보를 교환하고 소통하며 협업하는 법을 배웠고, 제가 배우고 있던 전자공학에 국한된 시야에서 벗어나 다양한 방면에서 세상을 바라보는 법을 배웠습니다.아쉬운점 3                        글자수 1,054자1,750Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 제시한 내용으로 지원자가 어떤 직무에 지원했는지 알 수 없다는 점이 아쉽습니다. 즉, 특정 직무에 일관된 활동이 아니라 자신이 대학시절에 했던 활동을 모조리 쓴 것 같은 느낌이 듭니다.\r\n                                        아쉬운점 2 만약 지원자가 통신직무로 지원했다면 이 내용들이 직무 내용과 무슨 연관성이 있는지 확인해 봐야 합니다. 어떤 직무로 지원하는지 명확하게 쓴 부분이 없는 상황에서 통신관련 활동 내용을 제시한 것으로 보아 통신직무로 지원한 것 같습니다. 통신 직무는 IT시스템 관리, 구내 통신설비 구축, 네트워크 구축이 대표적인 업무 내용인데, 이 부분에 직접적으로 연관이 있는 내용이 없다는 점이 아쉽습니다. 또한, 전산직무로 지원했다 하더라도 이 회사의 전산 직무에서 요구하는 직무 역량에 딱히 특별하다고 느껴지는 내용이 없습니다.\r\n                                        아쉬운점 3 본인의 생각과 느낌을 쓸 것이 아니라 지식, 스킬에 초점을 맞춰야 합니다. 그리고 그 내용이 직무기술서의 내용과 일치되는 부분이 많을 때 호감을 줄 수 있습니다.\r\n                            '],
#  ['정직, 남을 위한 봉사, 규칙 준수 등 윤리적인 행동으로 좋은 결과를 얻었던 경험을 아래 세부 항목에 따라 구체적으로 작성해 주십시오. (800자)',
#   '\r\n1) 언제, 어디서 있었던 일이며, 본인이 맡았던 역할은 무엇이었는지 기술해 주십시오. (300자)\r2019년 초부터 사회복무요원으로 20개월간 지역아동센터에서 복무했습니다. 사회복무요원은 주로 아동보육, 교육지도 (숙제와 학습할당량), 사무업무와 시설물 관리 (안내문 작성, 장식물 제작 등)의 업무를 맡았습니다. 사무업무 중 엑셀을 쓰는 업무가 많았는데, 대부분 어렵지 않으나 시간이 매우 오래 걸리는 작업이었습니다. 이를 엑셀로 자동화 하였습니다.좋은점 1\r\r2) 구체적으로 한 행동과 그렇게 행동하셨던 이유는 무엇인지 기술해 주십시오. (300자)\r작업 대부분을 함수와 매크로로 대체했습니다. 쉬운 수정을 위해 변수들을 보기 좋게 배치했고, 사용법과 수정법을 담은 안내서를 함께 제작했습니다. 프로그래밍과 비슷해 즐겁게 작업했지만, 작업량이 많았고 아동센터 특성상 한 업무에 집중하기 어려워 이를 마치는 데에 2주가 걸렸습니다.\r센터는 이미 인력 부족을 겪고 있었고, 제 전역 이후 새 요원 배치 예정이 없었습니다. 특별히 지시받지 않았고, 추가로 해야 하는 업무라 고민했습니다. 그러나 복지사들의 업무 감축은 근로자및 아동과 그들의 가족에게까지 영향을 준다고 생각해 진행했습니다.좋은점 2\r\r3) 그러한 행동이 당신과 타인에게 미친 영향은 무엇인지 기술해 주십시오. (200자)\r그 결과 매월, 요원 두 명이 16시간가량 하던 작업을 한 명이 1시간 이내에 끝낼 수 있는 양식이 완성됐습니다. 덕분에 종사자들은 좀 더 아동을 돌보는 데 시간을 할애할 수 있게 되었고, 저의 소집해제 후에도 업무를 떠안은 부담이 적어졌다고 사회복지사분들이 말씀하십니다. 저 역시 엑셀을 적극적으로 활용해볼 수 있는 계기가 되었습니다.좋은점 3                        글자수 851자1,439Byte\r\n                    ',
#   '\r\n                                        좋은점 1 질문의 요구사항에 맞게 작성한 점이 좋습니다.\r\n                                        좋은점 2 질문은 윤리적 행동을 묻고 있습니다. 질문의 의도에 정확하게 맞는 이야기 소재가 아니지만 지원자는 그에 맞게 내용을 구성하려 노력했다는 점이 좋습니다.\r\n                                        좋은점 3 질문에 맞게 내용을 잘 작성했고, 문서 작성 역량을 간접적으로 강조할 수 있는 사례인 점도 호감을 줍니다.\r\n                            '],
#  ['집단(학교, 회사, 동아리, 동호회 등)의 원만한 화합, 또는 공동의 목표 달성을 위해 남들보다 더 많이 노력하고 헌신했던 경험을 아래 세부 항목에 따라 구체적으로 작성해 주십시오. (800자)',
#   '\r\n1) 언제, 어디서 있었던 일이며, 당시 갈등 상황이나 목표는 무엇이었는지 기술해 주십시오. (200자)\r재학 중, 조별 과제로 여러 기능을 가진 Java 프로그램 개발한 적이 있습니다. 프로젝트 규모와 문서작업 비중이 컸기에, 품질 향상과 문서작업 병행이 가능한 폭포수 모델의 소프트웨어 개발 프로세스를 따르자고 제시하였습니다. 하지만 실제 개발 중 진행은 더뎠고, 프로젝트 모듈화가 계획대로 되지 않아 기능들이 정상 작동하지 않았습니다.좋은점 1\r\r2) 당신의 역할은 무엇이었으며, 집단의 화합 또는 목표 달성을 위해 구체적으로 어떤 노력을 하셨는지 기술해 주십시오. (400자)\r나이 차가 많이 나는 저학년생과 함께 팀을 꾸렸고, 자연스레 팀장을 맡게 됐습니다. 더딘 프로젝트 진행은 그대로 갈 경우 문제가 있을 것으로 판단하였습니다. 그래서 개발 중반쯤 상의를 하여 프로세스 미준수와 더딘 문서화의 이유에 대해 물었습니다. 대답을 들어 보니 팀원은 저학년이라 개발 경험이 부족했고, 개발 프로세스에 대해 배우지 않아 이해도가 낮았으나 나이 차이의 압박과 부족한 시간에 쫓겨 따라오기 바빴던 것입니다. 팀원의 이야기를 듣고 나서 저는 팀원의 처지를 이해할 수 있었습니다. 팀원이 이해할 수 있게끔 프로세스를 설명하고, 어려운 부분을 제가 맡아 진행했습니다. 번거롭더라도 개발 중 진행 상황과 문제점을 종종 물어봤고, 팀원이 막혀서 혼자 고민하던 문제들은 같이 해결하며 업무를 도왔습니다.아쉬운점 1\r\r3) 본인이 노력한 결과는 어떠하였고, 이 일이 집단 혹은 공동체에 미친 영향은 무엇인지 기술해 주십시오. (200자)\r기한 내에 구현과 문서작업까지 모두 마쳤고, 프로젝트 점수 만점이라는 좋은 결과를 내었습니다. 또한, 팀장으로서 인력 관리 기법을 얻었습니다. 처음엔 팀원이 비협조적이라 생각하고 비판적 태도를 취했으나, 섣불리 판단치 않고 소통으로 해결했습니다. 앞으로 불통이나 오해가 생겼을 때 대화가 필요하며 상대방의 처지에서 공감할 수 있어야겠음을 느꼈습니다.아쉬운점 2                        글자수 989자1,685Byte\r\n                    ',
#   '\r\n                                        좋은점 1 특별히 문제되는 부분이 없습니다.\r\n                                        아쉬운점 1 글 서두에 지원자는 자신이 폭포수 모델의 소프트웨어 개발 프로세스를 제시했는데, 그 과정에서 팀원들이 이 모델에 대해서 알고 있는지, 해당 팀원들로 이 목표를 달성할 수 있는지도 제대로 확인하지 않았다는 느낌을 주고 있습니다.\r\n                                        아쉬운점 2 갈등 해결의 위한 공감의 중요성을 배우기 전에, 프로젝트 진행에 있어 구성원의 장단점을 꼼꼼하게 체크하고 목표 실현의 가능성을 체계적으로 점검하는 것이 선행되어야 할 것 같습니다.\r\n                            '],
#  ['본인이 한국수력원자력의 인재상에 맞는 인재가 되기 위해 어떤 면에서 준비가 되어 있으며, 해당 능력을 개발하기 위해 어떠한 노력을 하였는지 구체적인 사례를 아래 세부 항목에 따라 작성해 주십시오. (800자)',
#   '\r\n1) 어떤 능력을 개발하였고, 이러한 능력개발을 위해 어떤 목표를 세웠는지 기술해 주십시오. (200자)\r전산시스템을 이루는 HW, SW, 통신 세가지 분야를 모두 아우르는, 전문성을 가지면서도 융합적 사고가 가능한 엔지니어를 목표로 삼아 재학중 다양한 경험을 했습니다. 이 중, 쌓을 수 있는 SW 지식이 제한적인 전자공학과에서 정보통신공학과로 전과를 결심했습니다. 당시 유일하게 전과가 가능했고, 소프트웨어 관련 과목이 많이 있었기 때문입니다.아쉬운점 1\r\r2) 목표 달성을 위해 어떤 계획을 세웠고, 계획을 실천하는 과정에서 가장 어려웠던 점과 이를 어떻게 극복하였는지  기술해 주십시오.(400자)\r전과 당시 이미 고학년이었기 때문에 졸업이 더 늦어지는 것을 막아야 했고, 과목별 학점도 좋게 받아야 했습니다. 하지만 들어야 할 과목은 많았고, 과목들의 특성은 모르는데다 일부 과목은 선행 기초 지식이 없어 학습해야 할 양은 기하급수적으로 늘었습니다.\r\r이를 해결하기 위해 지피지기면 백전불태, 학과를 파악했습니다. 신중한 과목 선택을 위해 듣는 수업마다 무조건 반장에 지원했습니다. 수강생들과 친분을 쌓고 정보를 얻기에 좋았기 때문입니다. 수집 정보 기반으로 다음 과목의 요구 기초를 배워뒀습니다. 또한 수면 시간을 5시간으로 줄였고, 체력을 위해 운동을 병행했습니다. 그리고, 인적 자원의 수율을 끌어 올렸습니다. 프로젝트에서 팀장을 맡으면 SW 개발 프로세스와 HRM기법을 응용해 체계적으로 계획했습니다.\r그 결과 계획대로 3학기 만에 졸업했고, HW와 SW 두 분야의 기본기를 다졌습니다.아쉬운점 2\r\r3) 향후 자신의 능력을 향상시키고 이를 잘 활용하기 위해 어떻게 노력할 것인지 기술해주십시오. (200자)\r이러한 경험을 통해 융합적 사고가 주는 잠재력을 보았고, 배움을 멈추고 싶지 않습니다. 그래서 취직 후 전공과 심리학 박사, 언어학 석사 취득을 계획하고 있습니다. 저의 개인적 역량을 지속적으로 끌어올리고, 집단 안에서 그룹원의 시너지를 향상시켜 기업에 없어선 안될 인재가 되기 위해 노력할 것 입니다.아쉬운점 3                        글자수 1,021자1,723Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 내용상으로 지원자가 통신 직무로 지원했는지, 전산 직무로 지원했는지 명확하게 확인이 되지 않습니다. 이 말은 직무 맞춤으로 내용이 기술되어 있지 않다는 것입니다. 그리고 목표가 적절하지 않습니다.\r\n                                        아쉬운점 2 불필요한 내용이 너무 많습니다. 전문성을 가지면서도 융합적 사고가 가능한 엔지니어 라는 목표가 추상적인 특징이 있어, 목표 달성을 위한 계획과 실천 과정도 구구절절한 내용으로 쓸 수밖에 없었던 것 같습니다.\r\n                                        아쉬운점 3 개인적인 학업계획보다는 회사에 업무적으로 활용할 수 있는 능력에 초점을 맞추는 것이 좋겠습니다.\r\n                            '],
#  ['단체에서 대화나 토론을 통해 상호 입장과 상황을 정확히 이해함으로써 건설적으로 문제를 해결해 본 경험에 대해 아래 세부 항목에 따라 작성해 주십시오. (800자)',
#   '\r\n1) 구성원들이 의견 차이를 보였던 견해에는 어떤 것들이 있었고 그 이유는 무엇인지, 그리고 본인 입장은 어땠는지 기술해주오. (200자)\rSW학과 졸업작품 작업 중, 한 팀원이 대면 작업 중에 피곤하다며 종종 자곤 했습니다. 자는 팀원이 분위기를 저해해 협업에 방해가 된다며 다른 팀원이 화를 냈습니다. 다른 팀원도 평소에 불만을 느꼈기에 제지하지 않았고, 갈등은 고조되어갔습니다. 분쟁에 끼고 싶지 않았지만, 이대로는 팀원 모두가 손실을 떠안게 되리라 판단해 중재했습니다.아쉬운점 1\r\r2) 상대방을 이해하기 위해 어떤 노력을 하셨는지, 상대방을 설득하기 위해 본인이 사용한 방법이 무엇이고 결과는 어땠는지 기술해 주십시오. (400자)\r일단, 감정을 가라앉힌 뒤 양측의 불만과 견해 차이를 정리했습니다. 결과 중심 팀원과 과정 중심 팀원들 간에 의견 차이를 확인하고, 근본적 원인을 찾아보았습니다. 객관적으로 보니 양측의 갈등은 성격 차이로 부터 시작되어 쌓여왔음을 알게 되었습니다. 서로 진행 방식이 틀린 것이 아닌 다른 것임을 알고 이해하자 팀 전체가 안정됐습니다. 각자 성향에 맞게 업무를 재배정하고, 서로의 다름을 비난하기보다 인정하고 배려하기를 당부했습니다. 처음엔 혼란스럽고 막막했지만, 문제점을 객관적인 시각에서 나열하고 토의했습니다. 그 결과로 갈등의 근본적 원인을 파악했으며 기초적 해결책을 얻을 수 있었습니다.아쉬운점 2\r\r3) 대화를 진행하는 과정에서 가장 중요하게 생각한 점은 무엇이었는지 기술해 주십시오. (200자)\r상대방의 입장을 이해하고 배려하는 것 입니다. 대화의 불통과 오해는 근본적으로 상대의 처지를 잘못 이해할 때 생기기 시작합니다. 또한 상대를 배려하지 않는다면 일방적으로 행동하는 사람, 소위 말하는 “꼰대”가 되고 협동력이 떨어지는 사람이 될 것 입니다.아쉬운점 3                        글자수 891자1,520Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 이 항목은 의견이나 생각에 대한 대립과 관련한 항목입니다. 질문에서 의견 차이를 보였던 견해가 무엇이었는지를 묻고 있다는 것이 근거입니다. ‘견해’란 어떤 사물이나 현상에 대한 자기의 의견이나 생각을 뜻합니다. 내용상으로 의견이나 생각에 대한 차이가 아니라 특정인의 행동에 대한 문제를 이야기하고 있습니다.  \r\n                                        아쉬운점 2 이 사례의 문제는 팀 활동에 적극적으로 참여하지 않고 잠을 자는 팀원으로부터 시작되었습니다. 우선 이 팀원이 왜 이런 행동을 했는지에 대한 설명이 구체적으로 제시되어야 합니다. 성격 차이라는 말은 쉽게 이해되지 않으며 막연한 느낌이 듭니다.\r\n                                        아쉬운점 3 꼰대는 늙은이를 뜻하는 은어입니다. 이런 말은 공식적인 특성이 있는 자기소개서에 어울리지 않는 말입니다.\r\n                            ']]

# %%
len(raw_df)
# Out:
# 6760

# %% [markdown]
# ## [아쉬운점, 좋은점, 글자수 제거]

# %%
from IPython.display import clear_output

# %%
new_contents = []

# %%
new_contents
# Out:
# []

# %%
## 아쉬운점은 리스트 2번에 None인지 아닌지 보면 됨 일단은
new_contents = []
for idx in range(len(raw_df)):
    #print(idx)
    temp = []
    for contents in raw_df.iloc[idx].paper:
        question, content, point = contents
        # 일단 \r\n, \r\r 모두 특수문자로 변경
        # \r\n => @@@@@@@@@@@@@@@ \r\r => $$$$$$$$$$$$$$$$$
        # \r => %%%%%%%%%%%%%%%
        content = content.replace("\r\n", "@@@@@@@@@@@@@@@").replace("\r\r", "$$$$$$$$$$$$$$$$$").replace("\r", "%%%%%%%%%%%%%%%")

        # 글자수 제거
        content = re.sub("글\s?자\s?수[ \d자Byte,byte]+", "", content)
        content = re.sub(' +', ' ', content) # 중복 공백 제거
        
        # (200자) 이런거 제거
        content = re.sub("\(\d+자\)", "", content)
        
        if point:
            # 아쉬운 점 제거
            content = re.sub("아\s?쉬\s?운\s?점\s?[\d ]", " ", content)
            
            # 좋은 점 제거
            content = re.sub("좋\s?은\s?점\s?[\d ]", " ", content)
            
            content = re.sub(' +', ' ', content) # 중복 공백 제거
        temp.append(content)

    new_contents.append(temp)
#     input()
#     clear_output(wait=False)

# %%
len(new_contents)
# Out:
# 6760

# %%
new_contents[:3]
# Out:
# [['@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 도전이라 부족한 영어 실력으로 많은 어려움에 부딪쳤습니다. 잠깐 좌절도 했지만 그보다 가장 힘들었던 것은 부모님이 주신 소중한 기회를 제대로 활용하고 있지 못하고 있는 저의 모습이었습니다. 저는 좌절보다는 노력을 택하였습니다. 매주 영어 학원과 스터디그룹에 참석하였으며 다양한 이들과의 대화를 위해 혼자 펍에 가 친구를 사귀기도 하고 아르바이트를 통해 많은 이들과의 소통으로 영어 실력뿐만 아니라 소통력과 관계력까지도 키울 수 있었습니다. 이러한 경험을 바탕으로 경동나비엔의 일원이 되어서도 어떠한 어려움 속에서도 좌절하지 않고 백절불굴의 자세로 부족한 점을 계속해서 연구하고 개선하여 끊임없는 변화 속에서 끊임없는 노력으로 성공이라는 꽃을 피우도록 하겠습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@코카콜라의 뉴코크 실패는 소비자는 단순히 제품만을 소비하는 것이 아니라 그 브랜드 즉, 제품의 상징성을 구매하는 심리를 보여주고 있습니다. 해외시장에 존재하는 고객은 국내시장에 존재하는 고객들보다 기업에 대한 적은 정보를 가지고 있으며 시장진출에 있어 문화, 언어적인 부분을 넘어 다양한 것들을 고려하고 새롭게 시작하여야 합니다. 하지만 이 또한 기회가 될 수 있습니다 해외시장의 경쟁자들이 보여주지 않았던 부분을 통해 시장을 공략한다면 그 부분이 기업의 상징처럼 되어 하나의 문화, 브랜드가 되어 소비자가 소비하는 이유가 될 수 있습니다. 따라서 제품 구매 후에도 빠르고 다양한 서비스를 제공하는 확실한 사후서비스를 더 강화하고 강조한 전략을 통해 해외시장을 공략하고 애프터 서비스 하면 경동나비엔이 제일 먼저 해외시장의 사람들의 뇌리에 떠오를 수 있게 상징화시킬 수 있다면 해외시장 점유율을 꾸준히 높여갈 수 있을 것입니다. @@@@@@@@@@@@@@@ '],
#  ['@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오. %%%%%%%%%%%%%%%4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어학과 함께 소프트웨어공학 및 기계공학과의 졸업작품에도 각 1년간 참여했습니다. 조직응용기사 취득 및 2개 기사 1차 합격, 개인 서버 운영, 전자공학과 학부연구생과 지능형 자동차 경진대회 출전 등의 경험도 있습니다만, 자수 제한으로 인해 졸업작품 경험에 관해 기술하겠습니다. $$$$$$$$$$$$$$$$$2) 해당 활동에서 본인이 맡았던 역할에 대해 기술해 주십시오. %%%%%%%%%%%%%%%정보통신공학에서는 온라인 자동 동기화 시스템을 제작했는데, 하드웨어 설계 및 제작, 펌웨어 (MCU)프로그래밍을 맡았습니다.%%%%%%%%%%%%%%%SW학 작품에서는 애플 iOS 앱을 2개 만들었고, 아이디어 회의부터 Swift와 Objective C언어로 프로그래밍, UI 제작, 문서작업, PPT 제작 등을 했습니다.%%%%%%%%%%%%%%%기계공학과 작품은 깡통크기의 초소형 위성 쏜 뒤 지상 복귀 중 위성의 자세를 제어하고 통신하는 것 이었습니다. 여기서 전자부품 선정과 C언어 프로그래밍 (통신, 자세제어)에 참여했습니다. 영어학과 응용탐구 (졸업준비 과목)에서는 영어 Resume와 Cover letter, SOP (대학원 진학을 위한 연구계획서) 등을 작성하는 연습을 했고, 매주 모여 연습한 것과 각자의 취업준비 과정을 발표하여 공유했습니다. $$$$$$$$$$$$$$$$$3) 해당 활동의 결과와 이를 통해 본인이 배운 점은 무엇인지 기술해 주십시오. %%%%%%%%%%%%%%%정보통신공학과 기계공학의 경우 제가 매우 선호하고, 경험이 많은 C언어와 펌웨어 프로그래밍을 맡았기 때문에 기본기를 다질 수 있었습니다. 제가 잘 모르는 타 전공의 기초지식들을 제가 잘 아는 HW지식과 접목시키는 것은 정말 흥미로웠습니다. 또한, 소프트웨어학과 졸업작품은 SW에 대한 색다른 경험을 맛보게 해주어 제가 전자공학과에서 정보통신공학과로 전과하는 계기가 되었습니다. 또한 다양한 전공의 여러 사람들과 정보를 교환하고 소통하며 협업하는 법을 배웠고, 제가 배우고 있던 전자공학에 국한된 시야에서 벗어나 다양한 방면에서 세상을 바라보는 법을 배웠습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@1) 언제, 어디서 있었던 일이며, 본인이 맡았던 역할은 무엇이었는지 기술해 주십시오. %%%%%%%%%%%%%%%2019년 초부터 사회복무요원으로 20개월간 지역아동센터에서 복무했습니다. 사회복무요원은 주로 아동보육, 교육지도 (숙제와 학습할당량), 사무업무와 시설물 관리 (안내문 작성, 장식물 제작 등)의 업무를 맡았습니다. 사무업무 중 엑셀을 쓰는 업무가 많았는데, 대부분 어렵지 않으나 시간이 매우 오래 걸리는 작업이었습니다. 이를 엑셀로 자동화 하였습니다. $$$$$$$$$$$$$$$$$2) 구체적으로 한 행동과 그렇게 행동하셨던 이유는 무엇인지 기술해 주십시오. %%%%%%%%%%%%%%%작업 대부분을 함수와 매크로로 대체했습니다. 쉬운 수정을 위해 변수들을 보기 좋게 배치했고, 사용법과 수정법을 담은 안내서를 함께 제작했습니다. 프로그래밍과 비슷해 즐겁게 작업했지만, 작업량이 많았고 아동센터 특성상 한 업무에 집중하기 어려워 이를 마치는 데에 2주가 걸렸습니다.%%%%%%%%%%%%%%%센터는 이미 인력 부족을 겪고 있었고, 제 전역 이후 새 요원 배치 예정이 없었습니다. 특별히 지시받지 않았고, 추가로 해야 하는 업무라 고민했습니다. 그러나 복지사들의 업무 감축은 근로자및 아동과 그들의 가족에게까지 영향을 준다고 생각해 진행했습니다. $$$$$$$$$$$$$$$$$3) 그러한 행동이 당신과 타인에게 미친 영향은 무엇인지 기술해 주십시오. %%%%%%%%%%%%%%%그 결과 매월, 요원 두 명이 16시간가량 하던 작업을 한 명이 1시간 이내에 끝낼 수 있는 양식이 완성됐습니다. 덕분에 종사자들은 좀 더 아동을 돌보는 데 시간을 할애할 수 있게 되었고, 저의 소집해제 후에도 업무를 떠안은 부담이 적어졌다고 사회복지사분들이 말씀하십니다. 저 역시 엑셀을 적극적으로 활용해볼 수 있는 계기가 되었습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@1) 언제, 어디서 있었던 일이며, 당시 갈등 상황이나 목표는 무엇이었는지 기술해 주십시오. %%%%%%%%%%%%%%%재학 중, 조별 과제로 여러 기능을 가진 Java 프로그램 개발한 적이 있습니다. 프로젝트 규모와 문서작업 비중이 컸기에, 품질 향상과 문서작업 병행이 가능한 폭포수 모델의 소프트웨어 개발 프로세스를 따르자고 제시하였습니다. 하지만 실제 개발 중 진행은 더뎠고, 프로젝트 모듈화가 계획대로 되지 않아 기능들이 정상 작동하지 않았습니다. $$$$$$$$$$$$$$$$$2) 당신의 역할은 무엇이었으며, 집단의 화합 또는 목표 달성을 위해 구체적으로 어떤 노력을 하셨는지 기술해 주십시오. %%%%%%%%%%%%%%%나이 차가 많이 나는 저학년생과 함께 팀을 꾸렸고, 자연스레 팀장을 맡게 됐습니다. 더딘 프로젝트 진행은 그대로 갈 경우 문제가 있을 것으로 판단하였습니다. 그래서 개발 중반쯤 상의를 하여 프로세스 미준수와 더딘 문서화의 이유에 대해 물었습니다. 대답을 들어 보니 팀원은 저학년이라 개발 경험이 부족했고, 개발 프로세스에 대해 배우지 않아 이해도가 낮았으나 나이 차이의 압박과 부족한 시간에 쫓겨 따라오기 바빴던 것입니다. 팀원의 이야기를 듣고 나서 저는 팀원의 처지를 이해할 수 있었습니다. 팀원이 이해할 수 있게끔 프로세스를 설명하고, 어려운 부분을 제가 맡아 진행했습니다. 번거롭더라도 개발 중 진행 상황과 문제점을 종종 물어봤고, 팀원이 막혀서 혼자 고민하던 문제들은 같이 해결하며 업무를 도왔습니다. $$$$$$$$$$$$$$$$$3) 본인이 노력한 결과는 어떠하였고, 이 일이 집단 혹은 공동체에 미친 영향은 무엇인지 기술해 주십시오. %%%%%%%%%%%%%%%기한 내에 구현과 문서작업까지 모두 마쳤고, 프로젝트 점수 만점이라는 좋은 결과를 내었습니다. 또한, 팀장으로서 인력 관리 기법을 얻었습니다. 처음엔 팀원이 비협조적이라 생각하고 비판적 태도를 취했으나, 섣불리 판단치 않고 소통으로 해결했습니다. 앞으로 불통이나 오해가 생겼을 때 대화가 필요하며 상대방의 처지에서 공감할 수 있어야겠음을 느꼈습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@1) 어떤 능력을 개발하였고, 이러한 능력개발을 위해 어떤 목표를 세웠는지 기술해 주십시오. %%%%%%%%%%%%%%%전산시스템을 이루는 HW, SW, 통신 세가지 분야를 모두 아우르는, 전문성을 가지면서도 융합적 사고가 가능한 엔지니어를 목표로 삼아 재학중 다양한 경험을 했습니다. 이 중, 쌓을 수 있는 SW 지식이 제한적인 전자공학과에서 정보통신공학과로 전과를 결심했습니다. 당시 유일하게 전과가 가능했고, 소프트웨어 관련 과목이 많이 있었기 때문입니다. $$$$$$$$$$$$$$$$$2) 목표 달성을 위해 어떤 계획을 세웠고, 계획을 실천하는 과정에서 가장 어려웠던 점과 이를 어떻게 극복하였는지 기술해 주십시오.%%%%%%%%%%%%%%%전과 당시 이미 고학년이었기 때문에 졸업이 더 늦어지는 것을 막아야 했고, 과목별 학점도 좋게 받아야 했습니다. 하지만 들어야 할 과목은 많았고, 과목들의 특성은 모르는데다 일부 과목은 선행 기초 지식이 없어 학습해야 할 양은 기하급수적으로 늘었습니다.$$$$$$$$$$$$$$$$$이를 해결하기 위해 지피지기면 백전불태, 학과를 파악했습니다. 신중한 과목 선택을 위해 듣는 수업마다 무조건 반장에 지원했습니다. 수강생들과 친분을 쌓고 정보를 얻기에 좋았기 때문입니다. 수집 정보 기반으로 다음 과목의 요구 기초를 배워뒀습니다. 또한 수면 시간을 5시간으로 줄였고, 체력을 위해 운동을 병행했습니다. 그리고, 인적 자원의 수율을 끌어 올렸습니다. 프로젝트에서 팀장을 맡으면 SW 개발 프로세스와 HRM기법을 응용해 체계적으로 계획했습니다.%%%%%%%%%%%%%%%그 결과 계획대로 3학기 만에 졸업했고, HW와 SW 두 분야의 기본기를 다졌습니다. $$$$$$$$$$$$$$$$$3) 향후 자신의 능력을 향상시키고 이를 잘 활용하기 위해 어떻게 노력할 것인지 기술해주십시오. %%%%%%%%%%%%%%%이러한 경험을 통해 융합적 사고가 주는 잠재력을 보았고, 배움을 멈추고 싶지 않습니다. 그래서 취직 후 전공과 심리학 박사, 언어학 석사 취득을 계획하고 있습니다. 저의 개인적 역량을 지속적으로 끌어올리고, 집단 안에서 그룹원의 시너지를 향상시켜 기업에 없어선 안될 인재가 되기 위해 노력할 것 입니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@1) 구성원들이 의견 차이를 보였던 견해에는 어떤 것들이 있었고 그 이유는 무엇인지, 그리고 본인 입장은 어땠는지 기술해주오. %%%%%%%%%%%%%%%SW학과 졸업작품 작업 중, 한 팀원이 대면 작업 중에 피곤하다며 종종 자곤 했습니다. 자는 팀원이 분위기를 저해해 협업에 방해가 된다며 다른 팀원이 화를 냈습니다. 다른 팀원도 평소에 불만을 느꼈기에 제지하지 않았고, 갈등은 고조되어갔습니다. 분쟁에 끼고 싶지 않았지만, 이대로는 팀원 모두가 손실을 떠안게 되리라 판단해 중재했습니다. $$$$$$$$$$$$$$$$$2) 상대방을 이해하기 위해 어떤 노력을 하셨는지, 상대방을 설득하기 위해 본인이 사용한 방법이 무엇이고 결과는 어땠는지 기술해 주십시오. %%%%%%%%%%%%%%%일단, 감정을 가라앉힌 뒤 양측의 불만과 견해 차이를 정리했습니다. 결과 중심 팀원과 과정 중심 팀원들 간에 의견 차이를 확인하고, 근본적 원인을 찾아보았습니다. 객관적으로 보니 양측의 갈등은 성격 차이로 부터 시작되어 쌓여왔음을 알게 되었습니다. 서로 진행 방식이 틀린 것이 아닌 다른 것임을 알고 이해하자 팀 전체가 안정됐습니다. 각자 성향에 맞게 업무를 재배정하고, 서로의 다름을 비난하기보다 인정하고 배려하기를 당부했습니다. 처음엔 혼란스럽고 막막했지만, 문제점을 객관적인 시각에서 나열하고 토의했습니다. 그 결과로 갈등의 근본적 원인을 파악했으며 기초적 해결책을 얻을 수 있었습니다. $$$$$$$$$$$$$$$$$3) 대화를 진행하는 과정에서 가장 중요하게 생각한 점은 무엇이었는지 기술해 주십시오. %%%%%%%%%%%%%%%상대방의 입장을 이해하고 배려하는 것 입니다. 대화의 불통과 오해는 근본적으로 상대의 처지를 잘못 이해할 때 생기기 시작합니다. 또한 상대를 배려하지 않는다면 일방적으로 행동하는 사람, 소위 말하는 “꼰대”가 되고 협동력이 떨어지는 사람이 될 것 입니다. @@@@@@@@@@@@@@@ '],
#  ['@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$$$$$$$$$$$$$어떠한 일을 시작하기 전에 두려운 마음이 들 때마다 이러한 마음가짐을 갖추고 도전하였습니다. 교내에서 실시하는 경제 골든벨 대회에 참여했던 경험이 있습니다. 학교 시험이 끝난 후 담임 선생님께서는 이틀 뒤에 대회가 실시될 것이라며 자세한 일정에 대해서 공지해 주셨습니다. 문제 출제 범위는 70페이지에 달하는 경제 관련 용어들이었습니다. 공부해야 하는 양에 비해 대회 전까지 준비할 수 있는 기간이 짧게 느껴졌기 때문에 주변 친구들은 저에게 지금부터 시작해봤자 좋은 성적을 거두지 못할 것이라며 포기하기를 권유하였습니다. 하지만 전부터 기다렸던 대회였고 꼭 해내고 싶다는 생각이 들어 이틀이라는 기간 동안 시간이 날 때마다 보며 공부하였습니다. 잘 외워지지 않는 부분은 따로 암기 노트를 만들어 들고 다니면서 익숙해지도록 하였고 저만의 암기 매뉴얼을 만들어가며 공부하였습니다. $$$$$$$$$$$$$$$$$그 결과 대회에서 1위라는 성적을 거둬 최우수상을 수상할 수 있었습니다. 이 경험을 통해 모든 일에 포기하지 않고 노력하여 달성하는 방법에 대하여 배우게 되었습니다. 이러한 역량을 바탕으로 맡은 업무에 대해 끝까지 완수해내는 사원이 되겠습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@저의 장점은 어떤 일이든 책임감을 가지고 수행해내는 것입니다. 고등학교 1학년 때 학습 부반장을 맡았던 경험이 있습니다. 당시 반의 수업 분위기가 좋지 않았고 이 점에 불만을 가진 친구들이 생기게 되었습니다. 그래서 저는 학습 분위기 개선이 필요하다는 생각이 들었습니다. 먼저 수업 시간에만 휴대폰을 걷자는 의견을 냈고 대부분이 찬성하여 실시하게 되었습니다. 매 수업 시간 전 반 친구들이 휴대폰을 낼 수 있도록 안내하고 안 낸 친구가 없도록 일일이 수를 세는 역할을 수행하였습니다. 또한 수업 내용을 이해하지 못한 친구들에게는 쉬는 시간과 방과 후 시간을 이용하여 설명해 주었습니다. 그 결과 반 학습 분위기도 좋아지고 학기 초 성적 최하위권 반에서 학기 말에는 1등 반으로 마무리할 수 있었습니다. $$$$$$$$$$$$$$$$$저의 단점은 많은 사람들 앞에서 말하는 것을 조금 두려워하는 것입니다. 이러한 성격 때문에 항상 준비한 만큼 결과를 보여주지 못하여 극복하고 싶었습니다. 그래서 학급 부반장이나 동아리 차장 등 임원 역할을 맡아 친구들 앞에서 말을 하는 연습을 하였고 수업 시간에도 나서서 발표하려고 노력하였습니다. 또한, 중요한 발표 전에는 실제 상황처럼 가정하여 리허설 연습을 하며 극복하고 있습니다. @@@@@@@@@@@@@@@ ',
#   '@@@@@@@@@@@@@@@체육대회 때 반 대항전으로 실시하는 치어리딩에 참여하였습니다. 평소 춤추는 데에 자신이 없어 사람들 앞에서 추는 것을 꺼려 하였습니다. 그러다 보니 연습을 할 때 자연스럽게 동작이 작아졌고 친구들에 비해 진도도 뒤처지게 되었습니다. 치어리딩은 협동심이 중요시되기 때문에 저로 인해 팀 전체에 피해가 갈 수도 있는 상황이었습니다. 이러한 상황을 극복하기 위해 연습하는 모습을 녹화하여 다시 보며 스스로 피드백을 하고 주변 친구들에게도 보여주며 고칠 부분을 찾아나갔습니다. 동작 연습 후에는 가족들 앞에서 춤을 추며 극복해나갔습니다. 그 결과 저희 반은 치어리딩 부분에서 높은 점수를 받아 종합 1위를 할 수 있었고 반 친구들은 체육대회 MVP로 저를 뽑아주었습니다. $$$$$$$$$$$$$$$$$전산회계 운용사 2급 자격증 실기 시험에서 불합격했던 경험이 있습니다. 방과 후 수업에 참여하여 열심히 공부하였지만, 시험 당일 프로그램 오류로 인해 작성했던 답안지가 저장이 되지 않았습니다. 그 결과 다른 과목에서 높은 점수를 받았지만 한 과목에서 0점을 받아 합격하지 못하였습니다. 이 경험을 바탕으로 만일의 상황까지 예측하며 계획하는 습관을 가지게 되었고 다음 시험에 재도전하여 높은 점수로 합격할 수 있었습니다. @@@@@@@@@@@@@@@ ']]

# %%
raw_df['preprocess1'] = new_contents

# %% [markdown]
# ## [소 질문]

# %%
# "\r\n" => [@@@@@@@@@@@@@@@]
# "\r\r" => [$$$$$$$$$$$$$$$$$]
# "\r" => [%%%%%%%%%%%%%%%]

# %%
raw_df.head(3)
# Out:
#   company_name                                              paper  \
# 0     (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1   한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url  \
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                          preprocess1
# 0  [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1  [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2  [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...

# %%
raw_df.iloc[1].paper
# Out:
# [['본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다양한 활동(학교, 회사, 동아리, 동호회 등)을 통해 지원한 직무와 관련하여 쌓은 경험경력 사항에 대해 작성해 주십시오. (1000자)',
#   '\r\n1) 언제, 어디서 활동했던 경험인지 기술해 주십시오. (200자)\r4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어학과 함께 소프트웨어공학 및 기계공학과의 졸업작품에도 각 1년간 참여했습니다. 조직응용기사 취득 및 2개 기사 1차 합격, 개인 서버 운영, 전자공학과 학부연구생과 지능형 자동차 경진대회 출전 등의 경험도 있습니다만, 자수 제한으로 인해 졸업작품 경험에 관해 기술하겠습니다.아쉬운점 1\r\r2) 해당 활동에서 본인이 맡았던 역할에 대해 기술해 주십시오. (400자)\r정보통신공학에서는 온라인 자동 동기화 시스템을 제작했는데, 하드웨어 설계 및 제작, 펌웨어 (MCU)프로그래밍을 맡았습니다.\rSW학 작품에서는 애플 iOS 앱을 2개 만들었고, 아이디어 회의부터 Swift와 Objective C언어로 프로그래밍, UI 제작, 문서작업, PPT 제작 등을 했습니다.\r기계공학과 작품은 깡통크기의 초소형 위성 쏜 뒤 지상 복귀 중 위성의 자세를 제어하고 통신하는 것 이었습니다. 여기서 전자부품 선정과 C언어 프로그래밍 (통신, 자세제어)에 참여했습니다. 영어학과 응용탐구 (졸업준비 과목)에서는 영어 Resume와 Cover letter, SOP (대학원 진학을 위한 연구계획서) 등을 작성하는 연습을 했고, 매주 모여 연습한 것과 각자의 취업준비 과정을 발표하여 공유했습니다.아쉬운점 2\r\r3) 해당 활동의 결과와 이를 통해 본인이 배운 점은 무엇인지 기술해 주십시오. (400자)\r정보통신공학과 기계공학의 경우 제가 매우 선호하고, 경험이 많은 C언어와 펌웨어 프로그래밍을 맡았기 때문에 기본기를 다질 수 있었습니다. 제가 잘 모르는 타 전공의 기초지식들을 제가 잘 아는 HW지식과 접목시키는 것은 정말 흥미로웠습니다. 또한, 소프트웨어학과 졸업작품은 SW에 대한 색다른 경험을 맛보게 해주어 제가 전자공학과에서 정보통신공학과로 전과하는 계기가 되었습니다. 또한 다양한 전공의 여러 사람들과 정보를 교환하고 소통하며 협업하는 법을 배웠고, 제가 배우고 있던 전자공학에 국한된 시야에서 벗어나 다양한 방면에서 세상을 바라보는 법을 배웠습니다.아쉬운점 3                        글자수 1,054자1,750Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 제시한 내용으로 지원자가 어떤 직무에 지원했는지 알 수 없다는 점이 아쉽습니다. 즉, 특정 직무에 일관된 활동이 아니라 자신이 대학시절에 했던 활동을 모조리 쓴 것 같은 느낌이 듭니다.\r\n                                        아쉬운점 2 만약 지원자가 통신직무로 지원했다면 이 내용들이 직무 내용과 무슨 연관성이 있는지 확인해 봐야 합니다. 어떤 직무로 지원하는지 명확하게 쓴 부분이 없는 상황에서 통신관련 활동 내용을 제시한 것으로 보아 통신직무로 지원한 것 같습니다. 통신 직무는 IT시스템 관리, 구내 통신설비 구축, 네트워크 구축이 대표적인 업무 내용인데, 이 부분에 직접적으로 연관이 있는 내용이 없다는 점이 아쉽습니다. 또한, 전산직무로 지원했다 하더라도 이 회사의 전산 직무에서 요구하는 직무 역량에 딱히 특별하다고 느껴지는 내용이 없습니다.\r\n                                        아쉬운점 3 본인의 생각과 느낌을 쓸 것이 아니라 지식, 스킬에 초점을 맞춰야 합니다. 그리고 그 내용이 직무기술서의 내용과 일치되는 부분이 많을 때 호감을 줄 수 있습니다.\r\n                            '],
#  ['정직, 남을 위한 봉사, 규칙 준수 등 윤리적인 행동으로 좋은 결과를 얻었던 경험을 아래 세부 항목에 따라 구체적으로 작성해 주십시오. (800자)',
#   '\r\n1) 언제, 어디서 있었던 일이며, 본인이 맡았던 역할은 무엇이었는지 기술해 주십시오. (300자)\r2019년 초부터 사회복무요원으로 20개월간 지역아동센터에서 복무했습니다. 사회복무요원은 주로 아동보육, 교육지도 (숙제와 학습할당량), 사무업무와 시설물 관리 (안내문 작성, 장식물 제작 등)의 업무를 맡았습니다. 사무업무 중 엑셀을 쓰는 업무가 많았는데, 대부분 어렵지 않으나 시간이 매우 오래 걸리는 작업이었습니다. 이를 엑셀로 자동화 하였습니다.좋은점 1\r\r2) 구체적으로 한 행동과 그렇게 행동하셨던 이유는 무엇인지 기술해 주십시오. (300자)\r작업 대부분을 함수와 매크로로 대체했습니다. 쉬운 수정을 위해 변수들을 보기 좋게 배치했고, 사용법과 수정법을 담은 안내서를 함께 제작했습니다. 프로그래밍과 비슷해 즐겁게 작업했지만, 작업량이 많았고 아동센터 특성상 한 업무에 집중하기 어려워 이를 마치는 데에 2주가 걸렸습니다.\r센터는 이미 인력 부족을 겪고 있었고, 제 전역 이후 새 요원 배치 예정이 없었습니다. 특별히 지시받지 않았고, 추가로 해야 하는 업무라 고민했습니다. 그러나 복지사들의 업무 감축은 근로자및 아동과 그들의 가족에게까지 영향을 준다고 생각해 진행했습니다.좋은점 2\r\r3) 그러한 행동이 당신과 타인에게 미친 영향은 무엇인지 기술해 주십시오. (200자)\r그 결과 매월, 요원 두 명이 16시간가량 하던 작업을 한 명이 1시간 이내에 끝낼 수 있는 양식이 완성됐습니다. 덕분에 종사자들은 좀 더 아동을 돌보는 데 시간을 할애할 수 있게 되었고, 저의 소집해제 후에도 업무를 떠안은 부담이 적어졌다고 사회복지사분들이 말씀하십니다. 저 역시 엑셀을 적극적으로 활용해볼 수 있는 계기가 되었습니다.좋은점 3                        글자수 851자1,439Byte\r\n                    ',
#   '\r\n                                        좋은점 1 질문의 요구사항에 맞게 작성한 점이 좋습니다.\r\n                                        좋은점 2 질문은 윤리적 행동을 묻고 있습니다. 질문의 의도에 정확하게 맞는 이야기 소재가 아니지만 지원자는 그에 맞게 내용을 구성하려 노력했다는 점이 좋습니다.\r\n                                        좋은점 3 질문에 맞게 내용을 잘 작성했고, 문서 작성 역량을 간접적으로 강조할 수 있는 사례인 점도 호감을 줍니다.\r\n                            '],
#  ['집단(학교, 회사, 동아리, 동호회 등)의 원만한 화합, 또는 공동의 목표 달성을 위해 남들보다 더 많이 노력하고 헌신했던 경험을 아래 세부 항목에 따라 구체적으로 작성해 주십시오. (800자)',
#   '\r\n1) 언제, 어디서 있었던 일이며, 당시 갈등 상황이나 목표는 무엇이었는지 기술해 주십시오. (200자)\r재학 중, 조별 과제로 여러 기능을 가진 Java 프로그램 개발한 적이 있습니다. 프로젝트 규모와 문서작업 비중이 컸기에, 품질 향상과 문서작업 병행이 가능한 폭포수 모델의 소프트웨어 개발 프로세스를 따르자고 제시하였습니다. 하지만 실제 개발 중 진행은 더뎠고, 프로젝트 모듈화가 계획대로 되지 않아 기능들이 정상 작동하지 않았습니다.좋은점 1\r\r2) 당신의 역할은 무엇이었으며, 집단의 화합 또는 목표 달성을 위해 구체적으로 어떤 노력을 하셨는지 기술해 주십시오. (400자)\r나이 차가 많이 나는 저학년생과 함께 팀을 꾸렸고, 자연스레 팀장을 맡게 됐습니다. 더딘 프로젝트 진행은 그대로 갈 경우 문제가 있을 것으로 판단하였습니다. 그래서 개발 중반쯤 상의를 하여 프로세스 미준수와 더딘 문서화의 이유에 대해 물었습니다. 대답을 들어 보니 팀원은 저학년이라 개발 경험이 부족했고, 개발 프로세스에 대해 배우지 않아 이해도가 낮았으나 나이 차이의 압박과 부족한 시간에 쫓겨 따라오기 바빴던 것입니다. 팀원의 이야기를 듣고 나서 저는 팀원의 처지를 이해할 수 있었습니다. 팀원이 이해할 수 있게끔 프로세스를 설명하고, 어려운 부분을 제가 맡아 진행했습니다. 번거롭더라도 개발 중 진행 상황과 문제점을 종종 물어봤고, 팀원이 막혀서 혼자 고민하던 문제들은 같이 해결하며 업무를 도왔습니다.아쉬운점 1\r\r3) 본인이 노력한 결과는 어떠하였고, 이 일이 집단 혹은 공동체에 미친 영향은 무엇인지 기술해 주십시오. (200자)\r기한 내에 구현과 문서작업까지 모두 마쳤고, 프로젝트 점수 만점이라는 좋은 결과를 내었습니다. 또한, 팀장으로서 인력 관리 기법을 얻었습니다. 처음엔 팀원이 비협조적이라 생각하고 비판적 태도를 취했으나, 섣불리 판단치 않고 소통으로 해결했습니다. 앞으로 불통이나 오해가 생겼을 때 대화가 필요하며 상대방의 처지에서 공감할 수 있어야겠음을 느꼈습니다.아쉬운점 2                        글자수 989자1,685Byte\r\n                    ',
#   '\r\n                                        좋은점 1 특별히 문제되는 부분이 없습니다.\r\n                                        아쉬운점 1 글 서두에 지원자는 자신이 폭포수 모델의 소프트웨어 개발 프로세스를 제시했는데, 그 과정에서 팀원들이 이 모델에 대해서 알고 있는지, 해당 팀원들로 이 목표를 달성할 수 있는지도 제대로 확인하지 않았다는 느낌을 주고 있습니다.\r\n                                        아쉬운점 2 갈등 해결의 위한 공감의 중요성을 배우기 전에, 프로젝트 진행에 있어 구성원의 장단점을 꼼꼼하게 체크하고 목표 실현의 가능성을 체계적으로 점검하는 것이 선행되어야 할 것 같습니다.\r\n                            '],
#  ['본인이 한국수력원자력의 인재상에 맞는 인재가 되기 위해 어떤 면에서 준비가 되어 있으며, 해당 능력을 개발하기 위해 어떠한 노력을 하였는지 구체적인 사례를 아래 세부 항목에 따라 작성해 주십시오. (800자)',
#   '\r\n1) 어떤 능력을 개발하였고, 이러한 능력개발을 위해 어떤 목표를 세웠는지 기술해 주십시오. (200자)\r전산시스템을 이루는 HW, SW, 통신 세가지 분야를 모두 아우르는, 전문성을 가지면서도 융합적 사고가 가능한 엔지니어를 목표로 삼아 재학중 다양한 경험을 했습니다. 이 중, 쌓을 수 있는 SW 지식이 제한적인 전자공학과에서 정보통신공학과로 전과를 결심했습니다. 당시 유일하게 전과가 가능했고, 소프트웨어 관련 과목이 많이 있었기 때문입니다.아쉬운점 1\r\r2) 목표 달성을 위해 어떤 계획을 세웠고, 계획을 실천하는 과정에서 가장 어려웠던 점과 이를 어떻게 극복하였는지  기술해 주십시오.(400자)\r전과 당시 이미 고학년이었기 때문에 졸업이 더 늦어지는 것을 막아야 했고, 과목별 학점도 좋게 받아야 했습니다. 하지만 들어야 할 과목은 많았고, 과목들의 특성은 모르는데다 일부 과목은 선행 기초 지식이 없어 학습해야 할 양은 기하급수적으로 늘었습니다.\r\r이를 해결하기 위해 지피지기면 백전불태, 학과를 파악했습니다. 신중한 과목 선택을 위해 듣는 수업마다 무조건 반장에 지원했습니다. 수강생들과 친분을 쌓고 정보를 얻기에 좋았기 때문입니다. 수집 정보 기반으로 다음 과목의 요구 기초를 배워뒀습니다. 또한 수면 시간을 5시간으로 줄였고, 체력을 위해 운동을 병행했습니다. 그리고, 인적 자원의 수율을 끌어 올렸습니다. 프로젝트에서 팀장을 맡으면 SW 개발 프로세스와 HRM기법을 응용해 체계적으로 계획했습니다.\r그 결과 계획대로 3학기 만에 졸업했고, HW와 SW 두 분야의 기본기를 다졌습니다.아쉬운점 2\r\r3) 향후 자신의 능력을 향상시키고 이를 잘 활용하기 위해 어떻게 노력할 것인지 기술해주십시오. (200자)\r이러한 경험을 통해 융합적 사고가 주는 잠재력을 보았고, 배움을 멈추고 싶지 않습니다. 그래서 취직 후 전공과 심리학 박사, 언어학 석사 취득을 계획하고 있습니다. 저의 개인적 역량을 지속적으로 끌어올리고, 집단 안에서 그룹원의 시너지를 향상시켜 기업에 없어선 안될 인재가 되기 위해 노력할 것 입니다.아쉬운점 3                        글자수 1,021자1,723Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 내용상으로 지원자가 통신 직무로 지원했는지, 전산 직무로 지원했는지 명확하게 확인이 되지 않습니다. 이 말은 직무 맞춤으로 내용이 기술되어 있지 않다는 것입니다. 그리고 목표가 적절하지 않습니다.\r\n                                        아쉬운점 2 불필요한 내용이 너무 많습니다. 전문성을 가지면서도 융합적 사고가 가능한 엔지니어 라는 목표가 추상적인 특징이 있어, 목표 달성을 위한 계획과 실천 과정도 구구절절한 내용으로 쓸 수밖에 없었던 것 같습니다.\r\n                                        아쉬운점 3 개인적인 학업계획보다는 회사에 업무적으로 활용할 수 있는 능력에 초점을 맞추는 것이 좋겠습니다.\r\n                            '],
#  ['단체에서 대화나 토론을 통해 상호 입장과 상황을 정확히 이해함으로써 건설적으로 문제를 해결해 본 경험에 대해 아래 세부 항목에 따라 작성해 주십시오. (800자)',
#   '\r\n1) 구성원들이 의견 차이를 보였던 견해에는 어떤 것들이 있었고 그 이유는 무엇인지, 그리고 본인 입장은 어땠는지 기술해주오. (200자)\rSW학과 졸업작품 작업 중, 한 팀원이 대면 작업 중에 피곤하다며 종종 자곤 했습니다. 자는 팀원이 분위기를 저해해 협업에 방해가 된다며 다른 팀원이 화를 냈습니다. 다른 팀원도 평소에 불만을 느꼈기에 제지하지 않았고, 갈등은 고조되어갔습니다. 분쟁에 끼고 싶지 않았지만, 이대로는 팀원 모두가 손실을 떠안게 되리라 판단해 중재했습니다.아쉬운점 1\r\r2) 상대방을 이해하기 위해 어떤 노력을 하셨는지, 상대방을 설득하기 위해 본인이 사용한 방법이 무엇이고 결과는 어땠는지 기술해 주십시오. (400자)\r일단, 감정을 가라앉힌 뒤 양측의 불만과 견해 차이를 정리했습니다. 결과 중심 팀원과 과정 중심 팀원들 간에 의견 차이를 확인하고, 근본적 원인을 찾아보았습니다. 객관적으로 보니 양측의 갈등은 성격 차이로 부터 시작되어 쌓여왔음을 알게 되었습니다. 서로 진행 방식이 틀린 것이 아닌 다른 것임을 알고 이해하자 팀 전체가 안정됐습니다. 각자 성향에 맞게 업무를 재배정하고, 서로의 다름을 비난하기보다 인정하고 배려하기를 당부했습니다. 처음엔 혼란스럽고 막막했지만, 문제점을 객관적인 시각에서 나열하고 토의했습니다. 그 결과로 갈등의 근본적 원인을 파악했으며 기초적 해결책을 얻을 수 있었습니다.아쉬운점 2\r\r3) 대화를 진행하는 과정에서 가장 중요하게 생각한 점은 무엇이었는지 기술해 주십시오. (200자)\r상대방의 입장을 이해하고 배려하는 것 입니다. 대화의 불통과 오해는 근본적으로 상대의 처지를 잘못 이해할 때 생기기 시작합니다. 또한 상대를 배려하지 않는다면 일방적으로 행동하는 사람, 소위 말하는 “꼰대”가 되고 협동력이 떨어지는 사람이 될 것 입니다.아쉬운점 3                        글자수 891자1,520Byte\r\n                    ',
#   '\r\n                                        아쉬운점 1 이 항목은 의견이나 생각에 대한 대립과 관련한 항목입니다. 질문에서 의견 차이를 보였던 견해가 무엇이었는지를 묻고 있다는 것이 근거입니다. ‘견해’란 어떤 사물이나 현상에 대한 자기의 의견이나 생각을 뜻합니다. 내용상으로 의견이나 생각에 대한 차이가 아니라 특정인의 행동에 대한 문제를 이야기하고 있습니다.  \r\n                                        아쉬운점 2 이 사례의 문제는 팀 활동에 적극적으로 참여하지 않고 잠을 자는 팀원으로부터 시작되었습니다. 우선 이 팀원이 왜 이런 행동을 했는지에 대한 설명이 구체적으로 제시되어야 합니다. 성격 차이라는 말은 쉽게 이해되지 않으며 막연한 느낌이 듭니다.\r\n                                        아쉬운점 3 꼰대는 늙은이를 뜻하는 은어입니다. 이런 말은 공식적인 특성이 있는 자기소개서에 어울리지 않는 말입니다.\r\n                            ']]

# %%
len("Rain Visor는 우천 시 차량에 장착한 가림막을 작동시켜 승객이 하차할 때 비 맞는 것을 최소화하는 시스템입니다.")
# Out:
# 66

# %%
p = re.compile("\([^\)]*\)")
brackets = []

for cs in new_contents:
    for c in cs:
        brackets.extend(p.findall(c))
print(len(brackets))
print(len(list(set(brackets))))
list(set(brackets))
# Out:
# 3792
# 1976
# ['(重工業)',
#  '(현재는 계속 바뀌고 있습니다)',
#  '(공조냉동기계기사, 가스기사, 산업안전기사)',
#  '(quality assurance)',
#  '(stay+vacation)',
#  '(ICAO)',
#  '(SAP BO, Zeppelin, Minitab)',
#  '(ip, 파싱한 port)',
#  '(Engineer)',
#  '(교통, 환경, 문화, 복지 과학정책, 아동, 관광 등)',
#  '(여행동반자 모집 및 신청할 수 있는 웹어플리케이션)',
#  '(케냐 키스와힐리어로 ‘문제없어’라는 뜻)',
#  '(花裝)',
#  '(2012-3)',
#  '(면세점)',
#  '(초)',
#  '(JAVA, SPASQL)',
#  '(Network Manage System)',
#  '(12일)',
#  '(그래픽기술자격)',
#  '(承)',
#  '(OO OOOO)',
#  '(OOOOO주 5개 기관)',
#  '(Product manager)',
#  '(Analysis)',
#  '(상황)',
#  '(CLT 조사)',
#  '(磨斧爲針)',
#  '(OKTA)',
#  '(美)',
#  '(CPI)',
#  '(시장 및 자사/경쟁사 종합 분석 보고서)',
#  '(약점)',
#  '(라즈베리파이)',
#  '(TiCl4)',
#  '(MY JOB)',
#  '(足浴室)',
#  '(Space Coedinator)',
#  '(200자 이상, 400자 이내)',
#  '(Plasma etching)',
#  '(Java, Android, SQL)',
#  '(EduDream Academy)',
#  '(보급담당관)',
#  '(돌잔치, 스냅사진, 가족사진 등)',
#  '(易地思之)',
#  '(Drug Delivery System)',
#  '(13)',
#  '(지원부문 및 희망부서 선택 동기 등)',
#  '(이하 테스트)',
#  '(PPO)',
#  '(정전류원)',
#  '(PC, 주변기기)',
#  '(Trust)',
#  '(MySQL, 자바 서블릿)',
#  '(Toss)',
#  '(2,4)',
#  '(KTJ)',
#  '(태양광)',
#  '(Git)',
#  '(춘천한림대점 제외)',
#  '(강사)',
#  '(30)',
#  '(경력)',
#  '(글로벌 학생 포럼)',
#  '(free Rider)',
#  '(HIC)',
#  '(ZrO2/HfO2/None Oxide layer)',
#  '(leader)',
#  '(우수 웹 평가 시상식)',
#  '(8)',
#  '(IEEE CyberC 2014)',
#  '(통신학회,전자학회,산악동아리, 족구동아리 참여)',
#  '(신시어리)',
#  '(비전공자 소프트웨어)',
#  '(Voice of Customer)',
#  '(스마트폰을 기준으로 설명)',
#  '(빅풋9, 이코노스퀘어 10/2 기준)',
#  '(아이디어)',
#  '(C언어: 삼각형,가위바위보,다이아몬드 등 개발)',
#  '(주)',
#  '(AR)',
#  '(자동차 렌탈 영업, 광고)',
#  '(酒道)',
#  '(Resource Description Framework)',
#  '(밤 11시전까지 주문 시 다음날 새벽 배송)',
#  '(IMO)',
#  '(부서)',
#  '(ip, port)',
#  '(혼자 밥먹기)',
#  '(2013.3~2014.1)',
#  '(배수)',
#  '(고객 구매특성에 따른 상품별 진열방식 변경, 피크타임 분석을 통한 FILL-UP 시스템 도입, 판매사 일일 근무스케줄을 통한 낭비과업 제거%%%%%%%%%%%%%%%성과: 재고일수 50% 감소 및 일매출 30% 성장$$$$$$$$$$$$$$$$$3)',
#  '(돌, 바람, KT)',
#  '(Google Map API를 가져와 Map에 좌표 및 상태 표시, D3.js 기반의 Chart library로 데이터 시각화 기능)',
#  '(8,500원)',
#  '(separation)',
#  '(포스터 3회, 구두 1회 발표)',
#  '(30%)',
#  '(무인 계산대)',
#  '(24팀 중 3등)',
#  '(유한요소해석)',
#  '(百’見不如一行)',
#  '(Verily)',
#  '(작성하지 않았습니다)',
#  '(350시간)',
#  '(가족사항 등)',
#  '(72.3%)',
#  '(Midas)',
#  '(전기집진기, 백필터, 습식세정탑, SCR촉매탑)',
#  '(화장품)',
#  '(OOO-on-OOO)',
#  '(똑똑한)',
#  '(권역)',
#  '(약 24만원)',
#  '(IGCC)',
#  '(Teaching Skill)',
#  '(TMON)',
#  '(기본적인 문서작성 및 편집 가능합니다.)',
#  '(고객클레임 20%에서 5%로 감소)',
#  '(장난감 블럭)',
#  '(gc)',
#  '(捨己爲人)',
#  '(3시간)',
#  '(상급)',
#  '(항공사, 호텔)',
#  '(정직함)',
#  '(헬기 등)',
#  '(일반적인 비행기)',
#  '(oo, oo장학회, ooo컴퍼니)',
#  '(1D 팀구성, 2D 문제기술, 3D 잠정조치, 4D 근본원인, 5D 시정조치, 6D 대책 효과, 7D 재발방지대책, 8D 승인)',
#  '(Java 기반 안드로이드)',
#  '(출력)',
#  '(수입통관, 내륙운송, 창고보관, D&D Charge 관리)',
#  '(리더는 함께 달리는 것)',
#  '(IF: 3.83)',
#  '(장당 2.2$)',
#  '(검사 공정 제외)',
#  '(熱情)',
#  '(ex. 건물주와의 갈등)',
#  '(한국인정기구)',
#  '(理想)',
#  '(200자 이상, 999자 이하)',
#  '(Advanced Driver Assistance Systems)',
#  '(대학생프로그래밍경진대회문제풀이, 10문제 중 3문제 풀이)',
#  '(Multicultural Festival)',
#  '(이하 kdn)',
#  '(구성원)',
#  '(245)',
#  '(14)',
#  '(무작정 쳐들어간 것 치고는 장소선정을 잘 해 영화과가 있는 학교라 영화과제 제출인 줄 알고 사람들이 잘 협조해주었습니다.)',
#  '(673/700자)',
#  '(1980년 이후에 태어난 사람)',
#  '(獨)',
#  '(약 4개월)',
#  '(Visible Differentiation)',
#  '(OOOO문화센터, OOO구청 일자리센터)',
#  '(마)',
#  '(百思不如一行)',
#  '(신체적 자유도)',
#  '(習)',
#  '(남양유업에 대한 남다른 사랑)',
#  '(전국 기차 일주)',
#  '(Car)',
#  '(전공을 통해)',
#  '(Benzene, Toluene, Xylene)',
#  '(유조선)',
#  '(9편)',
#  '(유지경성 : 하고자 하는 뜻만 있으면 무엇이든지 이룰 수 있다)',
#  '(모바일)',
#  '(월 4~5회)',
#  '(MLlib, R, Mahout, MATLAB 등)',
#  '(LIIV)',
#  '(노력)',
#  '(Computer Vision)',
#  '(IOT)',
#  '(장기현장실습)',
#  '(2013-80호, 2014-2361호)',
#  '(自燃性)',
#  '(B-)',
#  '(곧감)',
#  '(줌 레벨, 지도 데이터를 호출하는 url 등)',
#  '(甘言利說 )',
#  '(교육 과정, 인원, 기간, 홍보방법 등등)',
#  '(월 2-3회)',
#  '(pro bono)',
#  '(ESL)',
#  '(Java, C, Android, SQL)',
#  '(GS글로벌)',
#  '(三思一言)',
#  '(체코어 감사합니다)',
#  '(찰)',
#  '(전력망)',
#  '(2학년 때까지는 학점 위주로 공부를 했었습니다. 솔직히 그때까지는 깊이 취업에 대한 생각을 하지 않았던 것 같습니다. 3학년이 되어도 정말 불안하고 아무 스펙도 없는 저 자신이 한심하고 무기력하게 느껴졌었습니다. 그래서 목표를 딱하나 정하는 게 시급하여 여러 기업을 조사한 뒤 입사를 꿈꾸게 됐습니다. 그중에서도 제가 친절함을 느꼈었던 신한은행을 목표로 하였고 어느 정도의 스펙을 맞추려 공부를 하였습니다.)',
#  '(leehyekang.com)',
#  '(Django)',
#  '(20)',
#  '(0,3)',
#  '(학점: A+)',
#  '(거리 공연)',
#  '(Rule)',
#  '(의사)',
#  '(사물 인터넷)',
#  '(Standard Operating Procedures)',
#  '(솔라보트 제작)',
#  '(예. 친구, 직장 동료)',
#  '(환경)',
#  '(MySQL, AWS Redshift)',
#  '(手記)',
#  '(효율)',
#  '(OO 재단 협업)',
#  '(친절)',
#  '(유해물질 사용제한 지침)',
#  '(수수료)',
#  '(시장 조사, 기획서 작성, 행정 업무 보조)',
#  '(MES)',
#  '(繁華)',
#  '(필수)',
#  '(BP)',
#  '(Quality)',
#  '(PEMFC)',
#  '(MOIN)',
#  '(직속상관, 병사)',
#  '(짧은 시간에 짧은 내용의 영상을 소비)',
#  '(주문자 개발 생산 방식)',
#  '(가치)',
#  '(Ex.OO-OOOO)',
#  '(C++, 안드로이드, Linux)',
#  '(최소 300자, 최대 600자 입력가능)',
#  '(천안함과 같은 종)',
#  '(14 일)',
#  '(혁신, 소통의지 / 논리적 사고력 / 직관력, 통찰력 / 문제해결능력 / 통섭능력, 확장가능성)',
#  '(21개월)',
#  '(블랭크 세일링)',
#  '(3,500원 내지 3,800원)',
#  '(FGD/DVI 조사)',
#  '(以患爲利)',
#  '(전기,기계)',
#  '(IGBT)',
#  '(성장지원)',
#  '(STATCOM·정지형 무효전력 보상장치)',
#  '(기술사업화)',
#  '(PEET)',
#  '(솜:씨)',
#  '(PT)',
#  '(수 처리 실습, 생물학적, 물리학적 수 처리공학 등)',
#  '(Post-Marketing Surveillance)',
#  '(layered home)',
#  '(MT, 운동회, 기획봉사)',
#  '(몸)',
#  '(TPP)',
#  '(혼자서 술을 먹는 사람들)',
#  '(여성 54 % 자외선 차단제 사용)',
#  '(SAS등)',
#  '(기본)',
#  '(존경인물 : 니체, 이유 : 현실을 현실감있게 전달)',
#  '(SMAC)',
#  '(299)',
#  '(Networking Technologies and Applications)',
#  '(Abeek)',
#  '(중소 기업 지원)',
#  '(미국)',
#  '(MFC)',
#  '(matrix)',
#  '(200자 미만)',
#  '(Linux)',
#  '(自强不息)',
#  '(IoT)',
#  '(전기/계장)',
#  '(신사업 기획/전략)',
#  '(WIN-WIN 영업 전략의 협상으로 이루어낸 해운대상권과의 계약)',
#  '(狂)',
#  '(CSR)',
#  '(MCU)',
#  '(三好)',
#  '(MFC,C++)',
#  '(기획서 작성 경험 有)',
#  '(2009~2011)',
#  '(의사소통능력)',
#  '(산업분석, 통계분석, 수익성분석 등)',
#  '(KSP)',
#  '(情)',
#  '(게임방송BJ 혹은 ‘게임방송’이라는 형태를 이용한 TV광고)',
#  '(4.5/4.5)',
#  '(삼성인재양성프로그램)',
#  '(PM)',
#  '(2015)',
#  '(원가)',
#  '(가격, 인테리어, 청결도 등)',
#  '(학과, 학급 등)',
#  '(Citrus tea)',
#  '(Axcycle, Axstream, EES)',
#  '(粉)',
#  '(병원 내에 있는 CU 점포 제외할 시)',
#  '(Orcle DB,Java)',
#  '(산청목)',
#  '(Jang)',
#  '(Billing)',
#  '(한국어를 배우고 있는 베트남 친구의 소개)',
#  '(Global Value-Creative World-Leading University)',
#  '(脫)',
#  '(월 16시간)',
#  '(총상금 1000만원)',
#  '(Fit)',
#  '(P6)',
#  '(3년6개월)',
#  '(***위원회)',
#  '(OO Sharing System)',
#  '(분기마다 평가)',
#  '(樂爲之事)',
#  '(학원가)',
#  '(여성 54% 자외선 차단제 사용)',
#  '(GA)',
#  '(UTRI)',
#  '(식품 연구원으로의 성장)',
#  '(프로시저, 뷰, 트리거, 사용자정의함수 구현)',
#  '(13개월)',
#  '(15/04/01)',
#  '(look+덕후)',
#  '(perception)',
#  '(비판적 사고력)',
#  '(3명이 팀을 이뤄 출전)',
#  '(일본어)',
#  '(Social Network Game)',
#  '(skill)',
#  '(업무)',
#  '(파이)',
#  '(SME)',
#  '(溫故知新)',
#  '(악기)',
#  '(항공사, 호텔 등)',
#  '(스스로 공부하는 자세)',
#  '(경쟁력)',
#  '(문자, 카카오톡 등)',
#  '(responsibility)',
#  '(학년대표 장학금 수여)',
#  '(효)',
#  '(설계만 하게되면 그림쟁이만 될 수 도있습니다.. $$$$$$$$$$$$$$$$$예를들어 자기가 설계한 설비의 규모도 모른체 설계하는 경우, 설치가 여건을 고려하지않은 도면이 아닌 그림을 그리는 등...)',
#  '(SAP)',
#  '(숙제와 학습할당량)',
#  '(경청, 공감, 집중)',
#  '(runner)',
#  '(人生世間)',
#  '(BM 구상, 사업 미팅, 마케팅)',
#  '(Authorized Economic Operator)',
#  '(3주)',
#  '(Hadoop, Java, C#)',
#  '(치인트)',
#  '(Mobile)',
#  '(지)',
#  '(영화관람, 푸드파티)',
#  '(醫食同源)',
#  '(줄을 잡아주는 사람)',
#  '(Ceramics International, IF: OOOO(2020)',
#  '(LKS)',
#  '(총 44명 중 8명, OOOO 프로젝트매니저 선정)',
#  '(만 원)',
#  '(6기)',
#  '(혹은 부스)',
#  '(chord length)',
#  '(Gift)',
#  '(Measure)',
#  '(體)',
#  '(virtual integrated development environment)',
#  '(함께 가자)',
#  '(스마트폰)',
#  '(GENIE)',
#  '(이하 아이디어 생략)',
#  '(이공계)',
#  '(14:00, 17:00, 23:00)',
#  '(봉사활동)',
#  '(單)',
#  '(PACE MAKER)',
#  '(火星)',
#  '(심심풀이+simple의 의미)',
#  '(입행 후 포부)',
#  '(사업타당성조사)',
#  '(2016.08~2018.12)',
#  '(Java)',
#  '(理解)',
#  '(신뢰, 혼연일체, 인재, 불굴의 의지)',
#  '(狂敲-미치도록 두드림)',
#  '(3급)',
#  '(1일)',
#  '(4/10자)',
#  '(품질수준, Q)',
#  '(소변)',
#  '(저자 헤르만헤세)',
#  '(100자 이내)',
#  '(Electronic Shelf Label : 전자 가격 표시기)',
#  '(영업)',
#  '(CFA)',
#  '(***** 인턴 과제)',
#  '(AM)',
#  '(연인과 데이트)',
#  '(chassis)',
#  '(동일 분야 자격 산업기사 이상)',
#  '(Scala,R)',
#  '(逢山開道 遇水架橋)',
#  '(가상화)',
#  '(VFX)',
#  '(PBL)',
#  '(현재 KNN)',
#  '(KcLep, CAMP, ERP)',
#  '(농업용 중장비제조)',
#  '(기술)',
#  '(총 21개 고등학교)',
#  '(取)',
#  '(느낌, 생각, 그리고 실천)',
#  '(학회,족구동아리)',
#  '(Central)',
#  '(新)',
#  '(이하 멤버십)',
#  '(NFV)',
#  '(****, 2014.**.** - 현재)',
#  '(JSP, JAVA, HTML, CSS, JQuery, SQL)',
#  '(상)',
#  '(toggle)',
#  '(internet of things)',
#  '(Best Available Technology)',
#  '(LAN)',
#  '(현 소프트웨어학과 소속)',
#  '(sub way)',
#  '(장갑 지원 프로젝트/ 폐소방호스 아이디어 브랜드)',
#  '(mainly analysts)',
#  '(경제 학술 동아리)',
#  '(축구, 농구 등의 공놀이)',
#  '(paas)',
#  '(MINITAB, EXCEL)',
#  '(Vision)',
#  '(150~300)',
#  '(망)',
#  '(RA)',
#  '(procedure oriented programming)',
#  '(사람들)',
#  '(청자)',
#  '(락 밴드 동아리)',
#  '(Mircoservice Architecture)',
#  '(지능형교통시스템)',
#  '(재료)',
#  '(유관 동호회 활동, 블로그 운영, 수상경력, 사회봉사, 강의, 외국어 특기사항 및 소스코드나 포트폴리오 URL 등)',
#  '(2015-6)',
#  '(朝三暮四)',
#  '(공유)',
#  '(25점)',
#  '(키토 아야, 이덴슬리벨)',
#  '(WM)',
#  '(MCFC)',
#  '(리눅스시스템프로그래밍-CentOS 활용 기본 리눅스활용)',
#  '(Rain Visor는 우천 시 차량에 장착한 가림막을 작동시켜 승객이 하차할 때 비 맞는 것을 최소화하는 시스템입니다.)',
#  '(일)',
#  '(LCC)',
#  '(ingredient)',
#  '(Official Development assistance)',
#  '(File Descriptor)',
#  '(각 50자 이내)',
#  '(Repeat)',
#  '(魂)',
#  '(詩語)',
#  '(`꽃`과 불어 ‘Je t`aime’의 합성어)',
#  '(Edelman)',
#  '(위기는 성공을 위한 자극제)',
#  '(Denaturing Gradient Gel Electrophoresis)',
#  '(Advanced Driver Assistance System)',
#  '(outdoor sales)',
#  '(Frank-van der Merwe)',
#  '(54.6%)',
#  '(캐릭터 이동 + 적 처리)',
#  '(산출근거: 협업역량(30%)',
#  '(Electronics Technology)',
#  '(회원 관리 및 상품 관리)',
#  '(라이브러리)',
#  '(보험회사, 은행)',
#  '(TestCase)',
#  '(자동으로 열리는 현관문)',
#  '(이하 국과수)',
#  '(Plan)',
#  '(OO대학교 유비쿼터스 네트워킹 연구실)',
#  '(thermal oxidation, CVD, PVD, ion implantation, photolithography…)',
#  '(10%)',
#  '(Effort)',
#  '(ASEAN Economic Community)',
#  '(학점: B+)',
#  '(2루)',
#  '(혼자 술마시기)',
#  '(RAPA)',
#  '(水)',
#  '(代購)',
#  '(총장명의 수료증 발급)',
#  '(Parsing)',
#  '(-46.6%)',
#  '(세대 관련 자료 미파악)',
#  '(기아차 생산시스템)',
#  '(6개월 24일)',
#  '(BCG컨설팅그룹발표 2013년 세계 100대 혁신기업)',
#  '(Big)',
#  '(#)',
#  '(OOO, OOOO 외 2개 사)',
#  '(IIS6.0)',
#  '(約束)',
#  '(NH2)',
#  '(조리실, 이트인 코너 등)',
#  '(이하 던파)',
#  '(실무경력 1년)',
#  '(길거리 공연)',
#  '(협업능력)',
#  '(강점)',
#  '(6개월)',
#  '(한국OOOOOOOO)',
#  '(있을 경우 상품을 눌러 상세옵션 입력 후 장바구니에 담아둔다.)',
#  '(세무정보처리)',
#  '(2018.06~2018.07)',
#  '(3개월)',
#  '(2015/03/27)',
#  '(2일)',
#  '(액체 증기압 감소로 인한 펌프 손상)',
#  '(Convergence)',
#  '(5개월)',
#  '(SH)',
#  '(2013 ~ 2015, 3년간)',
#  '(商務)',
#  '(Flipped Learning)',
#  '(1줄에 카트 8대)',
#  '(互相帮助)',
#  '(설계의 꿈을 갖고 기초공사를 마치다)',
#  '(소비자)',
#  '(‘마트운영’을 통해 배운 정직성과 밝은 웃음)',
#  '( Java, XML. PHP, SQL)',
#  '(자전거 행복 나눔)',
#  '(?系)',
#  '(ERP,MES,위치기반서비스,앱카드)',
#  '(Integrity)',
#  '(Space coordinator)',
#  '(RCS)',
#  '(전주)',
#  '(OO군 환경과)',
#  '(한국통신학회 등)',
#  '(80포트)',
#  '( 정체, 사고 등 )',
#  '(ESI)',
#  '(Representational State Transfer)',
#  '(기획 업무)',
#  '(2명)',
#  '(http://www.facebook.com)',
#  '(OOO OOO)',
#  '(대표병사)',
#  '(유사사례 분석)',
#  '(팔팔)',
#  '(人本主義)',
#  '(Total Productive Maintenance)',
#  '(자본)',
#  '(과정 및 결과)',
#  '(수학포기자)',
#  '(1루)',
#  '(린)',
#  '(Diversity)',
#  '(deep learning)',
#  '(안전하게)',
#  '(에너지관리/공조냉동기계/전기 등)',
#  '(이하 엔씨문화재단)',
#  '(JIT)',
#  '(계약회사)',
#  '("HCN의 이윤뿐 아니라 지역주민이 함께 발전하는 직업 가치관")',
#  '(JAVA,SQL,ANDROID,PHP)',
#  '(合)',
#  '(200자 이내)',
#  '(하루 평균 400대)',
#  '(행동으로 옮기는 추진력과, 팀워크역량)',
#  '(Self-directed Safety Spread)',
#  '(화학물질관리법)',
#  '(400자 이내)',
#  '(천주교)',
#  '(1년~4년)',
#  '(R, SAS, SPSS)',
#  '(원장님)',
#  '(sPEEK 막의 연료전지 성능에 미치는 바인더 효과)',
#  '(Usher)',
#  '(웹 사이트 트래픽 추적 및 보고서를 통한 온라인 user행동 패턴 파악)',
#  '(美辭麗句)',
#  '(Cent OS 활용 기본 리눅스활용)',
#  '(0,x)',
#  '(영국본사)',
#  '(비지니스 일본어)',
#  '(OO, OOOOO, OOOOOO, OOOO)',
#  '(스즈키 토시후미)',
#  '(Internet of Things)',
#  '(CTCS)',
#  '(이후 앱)',
#  '(패션)',
#  '(NRA)',
#  '(Wearable)',
#  '(OCED)',
#  '(고객의 소리)',
#  '(B)',
#  '(X-ray)',
#  '(성공의 `연`은 역풍을 맞으며 솟아오른다)',
#  '(부품 실장 검사장치)',
#  '(이하 OFC)',
#  '(Engagement)',
#  '(대구 암벽 등반 동호회)',
#  '(부모, 조부모, 외조부모)',
#  '(10-2015-0064762)',
#  '(Live Brilliant)',
#  '(직책)',
#  '(Confined)',
#  '(CBOT)',
#  '(토익 및 토익스피킹)',
#  '(OA)',
#  '(自進苦生)',
#  '(전기/전자)',
#  '(Project Based Lesson)',
#  '( OOOOOOOOO, OOOOOOOO)',
#  '(동아비즈니스리뷰)',
#  '(Youth marketing)',
#  '(ex. 디자인)',
#  '(Customer Focus)',
#  '(배송지 정보)',
#  '(EXCEL, PPT)',
#  '(?)',
#  '(EDRM)',
#  '(또는 집단)',
#  '(전자상거래소비자보호법에서의 최근 법적 쟁점)',
#  '(Polyethylene terephthalate)',
#  '(제안동기, 향후 수정할점)',
#  '(교량의 바닥판 및 거더)',
#  '(6,000원)',
#  '(스티븐 코비)',
#  '(示)',
#  '(Competence)',
#  '(JDBC 은행관리 시스템 UML작업 및 개발총관리)',
#  '(SNS)',
#  '(수학 선생님)',
#  '(조달능력, D)',
#  '(눈삽, 너까래 등)',
#  '(1,000자 이내)',
#  '(김대식)',
#  '(Benefit)',
#  '(LNG)',
#  '(A-)',
#  '(시장)',
#  '(소통)',
#  '(ex 나이키 운동화)',
#  '(열 충격, 전기천공법, 접합)',
#  '(Advanced Design System)',
#  '(ELD)',
#  '(100-53=)',
#  '(Volmer-Weber)',
#  '(신)',
#  '(예산, 기획, 마케팅)',
#  '(정하균 의원실 담당)',
#  '(Hot)',
#  '(different)',
#  '(OOOOOOO학회)',
#  '(11)',
#  '(박광수, 예담)',
#  '(현KNN)',
#  '(전체참여)',
#  '(ex-인스타그램)',
#  '(예를 들어, 크레인의 모터를 구동하는 전기회로가 고장 시)',
#  '(脣亡齒寒)',
#  '(유아용 소비재)',
#  '(4번 타자)',
#  '(Improve)',
#  '(刃)',
#  '(.exe)',
#  '(신사업 기획 팀 PJT)',
#  '(4인 팀 리더)',
#  '(Humanity, Respect, Trust)',
#  '(Trend)',
#  '(입점 협력업체)',
#  '(최적설계)',
#  '(입력)',
#  '(1년 11개월)',
#  '(소화,구명정수,응급처치)',
#  '(fintech)',
#  '(조직)',
#  '(기계/배관)',
#  '(성장과정)',
#  '(Internet Protocol Security)',
#  '(MPS)',
#  '(CRM)',
#  '(Multi Input Multi Output)',
#  "('15년 2학기)",
#  '(People)',
#  '(C, File System)',
#  '(CiscoNetwork switch제어)',
#  '(Virtual Integrated Development Environment)',
#  '(전체 범위-X)',
#  '(凍三尺非一日之寒)',
#  '(Check)',
#  '(중간, 하단)',
#  '(2달)',
#  '(리소스 사용률)',
#  '(제조)',
#  '(美貌)',
#  '(동아리, 봉사 등)',
#  '(생협, 미담장학회, 맥키스컴퍼니, 무지개회)',
#  '(AlphaGo)',
#  '(2급)',
#  '(Requirement)',
#  '(설계쪽에 몸을 담게 되다보면 이후 현장업무에 적응을 못하는 경우도 많이 있습니다, 프로젝트에서 설계가 중요한 포션이고 초속에 잘 다져둬야되는건 맞지만, 여러 과정중 한단계일 뿐입니다, 다양한 경험을 할수가 없을 수도 있습니다)',
#  '(OS 라운드로빈 알고리즘 구현)',
#  '(7개월)',
#  '(MapReduce)',
#  '(OOO대학교 봉사자 소모임 단장)',
#  '(社是)',
#  '(Convenient)',
#  '(엑셀, 워드)',
#  '(sniff and more)',
#  '(90명 →150명)',
#  '(졸업작품을)',
#  '(JQuery)',
#  '(2012)',
#  '(MEA)',
#  '(Ceramics International, IF: OOO)',
#  '(Deposition)',
#  '(195)',
#  '(80점/100점)',
#  '(PLD)',
#  '(知彼知己)',
#  '(6)',
#  '(협력업체품질관리)',
#  '(Technical Order)',
#  '(당시 약 700명)',
#  '(반경 500m 내)',
#  '(BRD)',
#  '(Youthful-thinking)',
#  '(4.0/4.5)',
#  '(아직도 직접 상점에 가십니까?)',
#  '(“스냅사진 만원만 받고 어떤 사진이든 찍어드리겠습니다”)',
#  '(성실성과 창의적인 역량으로 최고의 시너지 창출)',
#  '(①개인이 추가 부담하여 기존 사업 진행, ②정해진 한도 내 사업 추진)',
#  '(소호사무실 운영 총괄)',
#  '(Commercial section of Korea Embassy in Poland)',
#  '(OO시 OO동)',
#  '(Me Too)',
#  '(매출 왕)',
#  '(동일 분야 자격 기사 이상)',
#  '(www.google.com)',
#  '(막대)',
#  '(2015 SNPD, 2015.06)',
#  '(이하 파이)',
#  '(No problem)',
#  '(Green Belt)',
#  '(옥시)',
#  '(District Health Officer)',
#  '(현OOO)',
#  '(FACT)',
#  '(TI)',
#  '(變化)',
#  '(홈페이지/모바일창구 등)',
#  '(9)',
#  '(Online to Offline, 오프라인에서 이루어진 서비스가 온라인으로 빨려 들어가는 현상)',
#  '(www.facebook.com)',
#  '(꼼꼼함)',
#  '(해외 갔을 때는 물갈이와 언어)',
#  '(안전서비스 어플리케이션 개발-네트워크 시뮬레이터에서 발생하는 차량의 위치 및 이동성 정보를 어플리케이션상에 UI로 표시)',
#  '(고)',
#  '(家家戶戶)',
#  '(KTA)',
#  '(엑셀, 워드, 파워포인트)',
#  '(분대장)',
#  '(성과제 휴식, 포상외박 및 외출, 다과준비 등)',
#  '(인터넷프로그래밍 A0)',
#  '(日日新又日新)',
#  '(JAVA, R)',
#  '(방향)',
#  '(Harmony)',
#  '(Spring Tool Suites)',
#  '(一助)',
#  '(12.1-15.4)',
#  '(Best)',
#  '(2014)',
#  '(기회)',
#  '(테스트 과정의 일부라 할 수 있는)',
#  '(유튜브, 네이버 블로그, 페이스북)',
#  '(Storage Area Network)',
#  '(-39.0%)',
#  '(Scanning Electron Microscope, SEM)',
#  '(Naming)',
#  '(할리갈리)',
#  '(ezUMS)',
#  '(성, 지역, 차종)',
#  '(최고의 신입사원에서 최고의 엔지니어로)',
#  '(ROM)',
#  '(C, Java, JavaScript)',
#  '(Character)',
#  '(Polymerization, IR, NMR 등)',
#  '(OOOO시뮬레이션, OOO세일즈, OOOO OOOO를 찾아라!)',
#  '(θ-2θ mode, x-ray reflectivity, Reciprocal space mapping)',
#  '(Enterprise Resource Planning)',
#  '(12.03-13.12)',
#  '(준법, 소 비자 보호)',
#  '(韓風)',
#  '(Pet+Family)',
#  '(저자 시오노나나미)',
#  '(로드셀)',
#  '(One-Team)',
#  '(透摩撈)',
#  '(散客)',
#  '(共鳴)',
#  '(AICPA)',
#  '(team based project)',
#  '(생협,미담 장학회,맥키스컴퍼니,무지개회)',
#  '(Slowly Slowly)',
#  '(OOO, OOOO)',
#  '(q/RT-PCR, Staining 등)',
#  '(Sincerity)',
#  '(토-일)',
#  '(페이스북: 빅풋9, 인스타그램: 이코노스퀘어 9/30 기준)',
#  '(유기 박막 트랜지스터)',
#  '(Store Controller)',
#  '(業)',
#  '(Shale reservoir)',
#  '(가스와 웨이퍼가 만나서 반응하는 부분에 높은 온도가 유지되어야 했기 때문에)',
#  '(SPC)',
#  '(-3000원↓)',
#  '(뜨거운 열정, 따뜻한 인간미, 시원한 에너지)',
#  '(수자원/전력)',
#  '(Speedy support)',
#  '(수요예측을 통한 손익분석 시뮬레이션)',
#  '(On Demand)',
#  '(타당성, 효과, 주위 반응 등)',
#  '(만점)',
#  '(2.5cm 가량)',
#  '(1년)',
#  '(RBC)',
#  '(팀웍)',
#  '(RFB)',
#  '(talent)',
#  '(마지막 항목에서 기술)',
#  '(199)',
#  '(vim)',
#  '(마트의 호감 있는 젊은이)',
#  '(머시닝센터)',
#  '(oo High School)',
#  '(통신, 자세제어)',
#  '(Excellent)',
#  '(2013.11.8 ~ 2013.11.22)',
#  '(IEEE SNPD 2015)',
#  '(Nursing Intelligent Statistics Research)',
#  '(A+)',
#  '(EES, Axcycle, Axstream)',
#  '(Techno-Business)',
#  '(피아노 계단 - 불편함을 개선하기 위한 노력)',
#  '(Text Analysis)',
#  '(Arduino)',
#  '(locker)',
#  '(유해화학물질 취급시설 안전관리)',
#  '(최소 300자, 최대 700자 입력가능)',
#  '(共感)',
#  '(MRP)',
#  '(REC)',
#  '(KLDP)',
#  '(증착 시간 142s, 플라즈마 인가 전력 160W)',
#  '(1986년)',
#  '(Mos master자격증 소지)',
#  '(교육의원의 지역구)',
#  '(Feed, PFD, P&ID, Plot Plan, ISO)',
#  '(지도교수 : OOO OOO)',
#  '(현 AMD CEO)',
#  '(Cook)',
#  '(이때의 속도는 좌측모터> 우측모터)',
#  '(Java, SQL, C)',
#  '(BeSmart - 집중력 장애 개선 프로젝트)',
#  '(悳)',
#  '(선택)',
#  '(15)',
#  '(한국연구재단)',
#  '(전자상거래소비자보호법 쟁점에 대한 개선방안)',
#  '(일단 해봐라, 기회를 놓치지 마라)',
#  '(RQI 정기조사)',
#  '(醬)',
#  '(가장 할인 폭이 큰 것을 선택)',
#  '(ICITCS 2015)',
#  '(毒)',
#  '(알고리즘)',
#  '(2016.03 ~ 2017.02)',
#  '(선배)',
#  '(15.05-15.12)',
#  '(1998)',
#  '(LEMS)',
#  '(Advanced Smart Cruise Control)',
#  '(주동작위)',
#  '(해결책)',
#  '(前)',
#  '(Buffalo)',
#  '(emartmall.com)',
#  '(oral and written)',
#  '(Legal Entity Identifier)',
#  '(멘티)',
#  '(인력, 설비, 재료, 공정방법)',
#  '(정보파악 하는데 능숙합니다.)',
#  '(쥐가 나는 상항 등)',
#  '(2020)',
#  '(온도, 압력 등)',
#  '(Infortainment=Information+Entertainment)',
#  '(Best People, Right People)',
#  '(음악 감상 동아리)',
#  '(팔)',
#  '(가나안농군학교-이하 농군학교)',
#  '(Test Driven Development)',
#  '(인터넷+IPTV)',
#  '(병원수요: 음료세트와 즉석 죽, 자취생 수요: 야간 시간 패스트푸드 재고 증대 및 관련 할인 상품 개발)',
#  '(一擧兩得)',
#  '(x,4)',
#  '(17년 1학기)',
#  '(reader)',
#  '(일반회원)',
#  '(온도,압력,엔탈피,엔트로피)',
#  '(데이터 분석 동아리)',
#  '(OO OOO Logistics)',
#  '(technology)',
#  '(연료전지)',
#  '(10)',
#  '(Openness)',
#  '(eHSE)',
#  '(독일, 벨기에, 이탈리아, 홍콩 등)',
#  '(수상한그녀 중국판)',
#  '(ITSM 문의응대 및 솔루션 이행작업응대, 유지보수관리 및 통합관리대장 관리- 웹문의응대 및 개선)',
#  '(영혼)',
#  '(Tip Speed Ratio)',
#  '(존중과 배려의 자세)',
#  '(PVC, 점착제 등)',
#  '(복장/자세)',
#  '(국제 재무분석사)',
#  '(Feat.운동)',
#  '(43점)',
#  '(포스팅 상위노출 기준 2건과 페이지 홍보 조건을 내세웠습니다.)',
#  '(Tortoise SVN)',
#  '(CM, 설계, 발주처)',
#  '(50장)',
#  '(15만 원)',
#  '(148)',
#  '(밴드동아리)',
#  '(30점)',
#  '(非)',
#  '(IT기기 케이스, 애견용품 등)',
#  '(CMO)',
#  '(본인 포함)',
#  '(병무청장 표창 제2013-1436호, 성남시장 표창 2014년 제2361호)',
#  '(4인 팀 팔로워)',
#  '(마부작침)',
#  '(古詩)',
#  '(ESS)',
#  '(포스터 3회, 구두 2회)',
#  '(품질보증)',
#  '(중앙일보 공부의신, 13.09-14.01)',
#  '(DC형)',
#  '(이하 IBS)',
#  '(베트남 경제 관련 기사 작성)',
#  '(인격)',
#  '(2009년 7월)',
#  '(대학생프로그래밍경진대회)',
#  '(알고리즘 B0)',
#  '(요구사항 분석, 정규화와 ER 다이어그램)',
#  '(MCDM)',
#  '(고객)',
#  '(長)',
#  '(100점 만점 기준)',
#  '(급식)',
#  '(10-2015-0024497)',
#  '(WLC)',
#  '(SECS)',
#  '(중국의 경기침체에 따른 영향)',
#  '(CCM)',
#  '(The Martian)',
#  '(700자이내)',
#  '(800 자 8 단락 이내)',
#  '(그린에너지)',
#  '(Generalist)',
#  '(개인 자동차 관리 App)',
#  '(솔선수범의 정신)',
#  '(수정현황 업데이트, 유관부서 및 대리점에 전파)',
#  '(Play Music by Pulse)',
#  '(총 4명으로 구성)',
#  '(데이터베이스론과 프로그래밍언어론에 대해 배운 내용들은 입사의지 항목에서 자세히 서술하여서 생략하도록 하겠습니다.)',
#  '(B0)',
#  '(MVC패턴)',
#  '(연 17 %)',
#  '(3루)',
#  '(생협, 미담장학회,맥키스컴퍼니,무지개회)',
#  '(국제 OOOO 전시회)',
#  '(R&D)',
#  '(Tip speed ratio)',
#  '(SecurityPlus Union Academy)',
#  '(안내문 작성, 장식물 제작 등)',
#  '(OO OOOO 전시회)',
#  '(JDBC)',
#  '(주인의식을 가지고 팀원과 함께)',
#  '(행복)',
#  '(PX)',
#  '(BB)',
#  '(DM MART)',
#  '(KENGEN: Kenya Electricity Generating Company Limited)',
#  '(`16 상반기 기준)',
#  '(현 ooo)',
#  '(Online to Offline)',
#  '(10 단락 이내)',
#  '(Autonomous Emergency Braking)',
#  '(1주일 평균 2.5건→1주일 평균 1건)',
#  ...]

# %%
new_contents2 = []

# %%
for i in range(5924, len(raw_df)): # len(raw_df)
    temp = []
    for contents in raw_df.iloc[i].preprocess1:
        contents = contents.replace("%%%%%%%%%%%%%%%", "@@@@@@@@@@@@@@@").replace("$$$$$$$$$$$$$$$$$", "@@@@@@@@@@@@@@@").replace("\t", " ")
        contents = re.sub("\(\d+자 이내\)", "", contents)
        contents = re.sub("\(\d+자\)?", "", contents)
        contents = [c for c in contents.split("@@@@@@@@@@@@@@@") if c and re.sub(' +', ' ', c) != " "]
        #print(contents)

        questions = []
        temp_new_answer = []
        temp_contents = []
        for idx, sequence in enumerate(contents):
            if re.search("(시오|인가요|주세요|바랍니다|있나요|하세요|니까|써라|작성하라|적합한지|니까|는가|주오|였나요|었는지|했나요|되었죠|펼쳤죠|경험|기술|\
            서술|작성|포부|동기|자기소개서?|장점|단점|강점|약점|성장\s?과정|교내\s?생활|대외\s?활동|사례|역량|활동|성장\s?배경|수학\s?내용|성과)[? .]*?$", sequence):
                questions.append(sequence)
                if idx : 
                    temp_new_answer.append(temp_contents)
                    temp_contents = []
            else:
                temp_contents.append(sequence)
        
        if temp_contents: temp_new_answer.append(temp_contents)
        
        if not questions: 
            temp.append("@@@@@@@@@@@@@@@".join(contents))
            continue
        else:
            print(i)
            print(raw_df.iloc[i].url)
            for q, c in zip(questions, temp_new_answer):
                print(q)
                print()
                print(c)
                print()
            
            if input("이상함?") == "y": 
                
                # 숫자 기준으로 나누기
                
                
                print("@@@@@@@@@@@@@@@".join(contents))
                r = input("question-answer로 변경 ? (y=자동, x=직접변경)")
                if r == "y":
                    for answer in temp_new_answer:
                        temp.append("@@@@@@@@@@@@@@@".join(answer))
                elif r == "x":
                    while True:
                        c_temp = input("내용 적기 : ")
                        if c_temp == "stop": break
                        temp.append(c_temp)
                else:
                    temp.append("@@@@@@@@@@@@@@@".join(contents))
            else:
                for answer in temp_new_answer:
                    temp.append("@@@@@@@@@@@@@@@".join(answer))
        
        clear_output(wait=False)
    new_contents2.append(temp)

# %%
len(new_contents2)
# Out:
# 6760

# %%
new_contents2[4201]
# Out:
# ['君師父一體@@@@@@@@@@@@@@@아버지께서는 항상 “의지하지 말고 스스로 도전해라”라고 말씀하셨습니다. 엄격한 가정환경에서 저는 어릴 때부터 남들보다 강한 도전정신을 갖고 성장했습니다. 학업에서도 스스로 해야 하는 분위기에서 성장했습니다. @@@@@@@@@@@@@@@이는 남들보다 주도적이고 창의적인 저를 형성하는 데에 큰 역할을 했다고 생각합니다. 중학교시절까지는 이러한 도전정신이 농구,마술 등 취미생활에 주를 이뤘지만, 고등학교에서 만난 담임선생님과의 어떤 사건을 계기로 공부로 바뀌게 되었습니다.@@@@@@@@@@@@@@@막연하게 고등학생이 되었으니 공부를 하자는 생각으로 공부를 했었고, 운이 따라 3월 모의고사에서 좋은 성적을 받았습니다. 중학교 성적과 비교해 눈에 띄게 성적이 향상되자 담임선생님께서 저를 불러 칭찬을 해주셨습니다. 이후 성적이 떨어졌을 때에는 격려를 해주셨고, 이를 통해 격려와 칭찬이 인간관계에서 얼마나 큰 영향을 미치는지 깨달았습니다. @@@@@@@@@@@@@@@저 역시 기대에 부응하기위해 꾸준히 공부했고, 이는 성적향상으로 이어졌습니다. 주변 친구들과 협동하는 자세 역시 기르게 해주었습니다. 대학교에 진학한 후에도 각 구성원들을 격려하고 칭찬했고, 다른 조보다 효율적인 진행, 그리고 좋은 결과물을 만들었습니다. @@@@@@@@@@@@@@@격려는 작은 변화를 일으키고 큰 혁신을 불러온다는 것을 깨달았습니다. 두 분의 가르침덕에 저는 주도적인 자세를 가졌을 뿐 아니라, 주변을 격려하여 큰 변화를 가져올 수 있는 사람이 되었습니다. ',
#  '[계획은 철저하게, 사고는 미리 방지하자]@@@@@@@@@@@@@@@제 생활신조는 "모든 일은 꼼꼼하고 계획적으로, 그리고 미리미리"입니다. 계획을 세우고 일을 진행해야 효율적이고 사고로 일을 미뤄야 할 경우에도 일을 빠르게 처리할 수 있습니다. 그리고 항상 스스로 예정된 날짜보다 일찍 마감시한을 정합니다. 이는 일을 꼼꼼하게 처리할 수 있고, 마무리한 뒤 필요하다면 재검토를 할 수 있습니다.@@@@@@@@@@@@@@@- 꼼꼼하지만 유연한 계획성@@@@@@@@@@@@@@@제 강점은 월 단위로 할 일을 계획한다는 것입니다. 스마트 시대를 살면서, 스마트 기기와 컴퓨터를 연동하여 제가 해야 할 일정들을 항상 점검합니다. 매달 해야 할 일을 쉽게 점검하고, 다시 1주일 구간으로 나누어 해야 할 일을 분담합니다. 피치 못할 이유로 일을 미뤄야 하면, 유연하게 예정된 계획을 다른 날짜에 수행할 수 있도록 처리하고 있습니다. @@@@@@@@@@@@@@@- 아직은 부족한 통찰력@@@@@@@@@@@@@@@제 단점은 일을 예리하게 바라보는 통찰력이 부족하다는 점입니다. 이를 개선하기 위해, 소설을 읽고 있습니다. 소설을 통해 주인공이 어떤 사태에 직면하면 그 상황을 다시 파악합니다. 입사 후에는 제가 맡은 직무에 관해 공부하고, 코리아써키트의 교육을 따름으로써 이러한 통찰력을 키워 제 단점을 극복해나가고 싶습니다.@@@@@@@@@@@@@@@스마트 시대에 맞는 관리법을 직무에 적용해 관리직무를 어디서든 체크하고, 코리아써키트 동료들과 일정을 공유해 효율적으로 진행해나가겠습니다. 그리고 신기술을 활용한 품질관리를 진행하는 인재가 되겠습니다. ',
#  '@@@@@@@@@@@@@@@ 제 취미는 컴퓨터 하드웨어와 DSLR 카메라입니다. 디지털 시대가 되면서 모든 전자기기가 디지털화되어가고 있습니다. 전자정보용 유기소재와 고분자합성 등 관련 전공을 들으면서, 전자제품의 신경시스템이라고 할 수 있는 PCB 인쇄회로기판에 관심을 갖게 되었습니다.@@@@@@@@@@@@@@@PCB의 평판은 페놀수지, 에폭시수지로 되어있습니다. 큰 규모의 반도체시장, 사물인터넷과 웨어러블(Wearable) 등 새로운 분야가 등장하면서 가파른 성장세가 이어지고 있습니다. 이들의 뼈대라고 할 수 있는 PCB 시장 역시 미래가 유망한 시장이라고 생각합니다.@@@@@@@@@@@@@@@코리아써키트는 PCB기판의 품질면에서 우수한 기업이라고 생각합니다. S회사에서 최근 출시한 스마트폰이 폭발사고를 일으키며 리콜사태가 있었습니다. 이에 대해 찾아보던 중, 코리아써키트와 S그룹 계열사에서 만든 PCB기판 중 코리아써키트의 기판을 사용한 스마트폰은 폭발이 없었다는 것을 알게 되었습니다. 이는 코리아써키트의 품질수준을 증명하는 사례라고 생각합니다.@@@@@@@@@@@@@@@현재는 스마트폰과 메모리의 PCB기판이 주력이지만 향후 일본과 중국 진출 계획을 세우며 카메라 등에도 관심을 갖고 있다는 것을 알았습니다. 저는 이러한 코리아써키트의 높은 품질수준과 미래에 대한 비전에 매료되어 지원하고자 합니다.',
#  '@@@@@@@@@@@@@@@중화권 시장의 성장에 따라 PCB 경쟁업체가 점점 늘고 있습니다. 또한, 선진시장인 일본은 점점 한국 PCB 시장의 경쟁력에 따라잡히고 있습니다. 중화권 시장의 강점은 저가공세이므로 높은 품질을 제공하는 것이 코리아써키트가 앞으로 나아갈 길이라고 생각합니다. 코리아써키트에 입사한 후 교육을 충실히 받아 코리아써키트에 맞는 품질관리의 전문가가 되고자 합니다.@@@@@@@@@@@@@@@',
#  '[재창작으로 만든 도서관의 혁신]@@@@@@@@@@@@@@@창의성과 적극적인 태도로 기존의 부족한 점을 개선한 경험이 있습니다.@@@@@@@@@@@@@@@아동센터에서 6개월간 지도교사 겸 행정보조를 했을 때 입니다. 행정보조 당시 도서관을 개선한 경험이 있습니다. 책 관리체제가 미흡했기 때문에, 책이 없어졌을 때 파악하기 힘들고 아이들이 책을 찾는 데 애를 먹었습니다. @@@@@@@@@@@@@@@책을 더 쉽게 관리할 수는 없을까 고민하던 중 도서관에서의 분류 방식을 떠올리고, 아이들이 이용하는 아동센터라는 점을 합쳐 개선안을 냈습니다. 책 상단에 숫자를 기록하는 것이었습니다. @@@@@@@@@@@@@@@독자가 어린아이들과 청소년인 점을 고려하여 복잡한 기호 대신 숫자를 사용했습니다. 이 개선으로 서적관리가 매우 쉬워졌습니다. 유실된 책을 바로 파악할 수 있었고 아이들이 원하는 책을 찾을 때 더는 선생님을 찾지 않아도 되었습니다.@@@@@@@@@@@@@@@품질관리직무는 상품의 완결성을 체크하는 직무입니다. 하자를 발견했을 때, 창의적으로 접근하고 개선하고자 하는 적극적인 태도가 같이 있다면 코리아써키트와 함께 구매자에게 더 개선된 상품을 제공할 수 있을 것입니다. ']

# %%
raw_df['preprocess2'] = new_contents2

# %%
raw_df
# Out:
#      company_name                                              paper  \
# 0        (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1      한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2     (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
# 3           ㈜하나은행  [[자기소개서, \r\n벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력\r"보...
# 4            조선비즈  [[자유양식, \r\n저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 ...
# ...           ...                                                ...
# 6755   삼화페인트공업(주)  [[본인의 성격, 성장과정, 가치관 등을 기술하시오., \r\n남들을 배려하며 착하...
# 6756      LG디스플레이  [[LG디스플레이 및 지원 직무에 지원하는 동기에 대해 기술해 주십시오. (500~...
# 6757     엘에스전선(주)  [[본인에 대하여 소개해 주시기 바랍니다. (성장과정, 경험, 성격, 강/약점, 가...
# 6758        S-OIL  [[귀하가 회사를 선택하는 기준은 무엇이며 왜 당사가 그 기준에 적합한지를 작성하고...
# 6759        샘표(주)  [[샘표식품㈜에 지원하는 구체적인 이유와 샘표식품에서 여러분을 선택해야 하는 이유에...
#
#                                                     url  \
# 0     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 3     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 4     https://www.jobkorea.co.kr/starter/PassAssay/V...
# ...                                                 ...
# 6755  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6756  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6757  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6758  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6759  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                             preprocess1  \
# 0     [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1     [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2     [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...
# 3     [@@@@@@@@@@@@@@@벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력%...
# 4     [@@@@@@@@@@@@@@@저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무...
# ...                                                 ...
# 6755  [@@@@@@@@@@@@@@@남들을 배려하며 착하게 사는 것이 옳다고 배우며 살아왔...
# 6756  [@@@@@@@@@@@@@@@2013년 여름, 천호식품에서 아르바이트를 했었습니다....
# 6757  [@@@@@@@@@@@@@@@[노력하는 인재]%%%%%%%%%%%%%%% 선배들의 ...
# 6758  [@@@@@@@@@@@@@@@[Be the first? Do the best!!]%...
# 6759  [@@@@@@@@@@@@@@@[세계가 샘내는 기업 샘표]%%%%%%%%%%%%%%%...
#
#                                             preprocess2
# 0     [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1     [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2     ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...
# 3     [벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력@@@@@@@@@@@@@@@"...
# 4     [저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 어려움을 덜어낸 경험...
# ...                                                 ...
# 6755  [남들을 배려하며 착하게 사는 것이 옳다고 배우며 살아왔기 때문에, 이타적인 성향이...
# 6756  [2013년 여름, 천호식품에서 아르바이트를 했었습니다. 제품 생산에서부터 포장, ...
# 6757  [[노력하는 인재]@@@@@@@@@@@@@@@ 선배들의 추천을 받아 13년도 동아리...
# 6758  [[Be the first? Do the best!!]@@@@@@@@@@@@@@@ ...
# 6759  [[세계가 샘내는 기업 샘표]@@@@@@@@@@@@@@@68년의 전통과 최고참 상표...
#
# [6760 rows x 5 columns]

# %%
raw_df.to_csv(data_path+"JobKorea_preprocess1.csv", index=False)

# %%
with open(data_path+'JobKorea_preprocess1.pickle', 'wb') as f: pickle.dump(raw_df, f)

# %%
f = open(data_path+'JobKorea_preprocess1.pickle', 'rb')
raw_df2 = pickle.load(f)
f.close()
raw_df2.head(3)
# Out:
#   company_name                                              paper  \
# 0     (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1   한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url  \
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                          preprocess1  \
# 0  [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1  [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2  [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...
#
#                                          preprocess2
# 0  [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1  [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2  ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...

# %%
tt = raw_df2.preprocess2.tolist()

special = set()
for t in tt:
    for p in t:
        p = re.sub("['가-힣a-zA-Z0-9ㄱ-ㅎㅏ-ㅣ.,']", "", p)
        special |= set(p)

# %%
print(special)
# Out:
# {'］', '仁', 'α', '明', '察', '》', '父', '>', '′', '②', '竟', '\u200b', '語', '石', '短', '倍', '佑', '刮', '麗', '：', '□', '±', '醫', '彼', '造', '目', '秀', '利', '桓', '&', '商', '單', '手', '⓶', '◀', 'Ⅰ', '塞', '流', '思', '合', '客', '·', '△', '③', 'é', '悳', '\U000f0853', '〉', '」', '者', '甲', '休', '年', '∼', '工', '。', '®', '强', '城', '著', '德', '不', '不', '，', '低', '樂', '+', '\\', '身', '王', '地', '➂', '①', '浴', '間', '㎛', '變', '○', '就', '天', '燃', '⑥', '形', '成', ':', '繁', '新', ' ', '行', '●', '狂', '裝', '°', '感', '承', '同', '韓', 'Ⅱ', '４', '論', '當', '\t', '能', '翁', '溫', 'ᆞ', '「', '}', '健', '人', '捨', '博', '多', '忘', '_', '共', '‧', '習', '應', '寧', 'Å', 'ㆍ', '~', '＃', '試', '脫', '⑤', '得', '{', '☆', '樂', '志', '生', '祝', '任', 'Ⅳ', '想', '好', '\u3000', '兵', '|', '…', '▲', '=', '長', '擧', '交', '▶', '對', '作', '華', '敎', '㎠', '針', '◈', '≪', '主', '視', '箭', '齒', '^', '獨', '海', '示', '私', '５', '’', '吝', '公', '見', '⓷', ']', '條', '理', '進', '爲', '動', '↓', ')', '$', '束', '使', '家', '傳', '▷', '凍', '起', '四', '架', '孫', '辭', '–', '遇', '朝', '聞', '信', '‘', '℃', '訓', '*', '以', '-', '＆', '理', '財', '詩', '心', '∙', '粉', '★', '情', '展', '現', '敲', '持', '➀', '古', '子', '④', '㎥', '最', '貌', '．', '』', '師', '金', '氣', '比', '本', '正', '法', '重', '（', '句', '害', '勢', '如', '₂', '毒', '覆', '@', '）', '言', '＞', '獻', '熱', '名', '己', '卽', '［', '美', '取', '◆', '%', '“', 'Ω', '光', '通', '解', '外', '步', '發', '火', '＇', '忠', '代', '逢', '㎍', '神', '傾', '二', '₃', '蔬', '²', '故', '醬', '業', '農', '萬', '㈜', '無', 'μ', '会', '《', '”', '透', '橋', '世', '․', '學', '饮', '社', '自', '⇒', '散', '息', '⓵', '魂', '爛', '後', '讓', 'た', '究', '將', '遊', '有', '•', '幸', '賢', '花', '善', '眞', '內', '<', '購', '日', '化', '利', '#', '未', '相', '源', '；', '水', '待', '孝', '■', '緣', '刃', '\u2003', '場', '患', '器', '脣', '`', '≫', '/', '?', '務', '百', '義', '說', '´', '易', '室', '➁', '月', '道', '苦', '然', '及', '后', '兩', '向', '協', '互', '厚', '開', '追', '鬪', '算', '来', '前', '食', '众', '可', '總', '馬', '士', '先', '『', 'ｍ', '撈', '望', '(', '物', '山', '顚', '上', '大', '尊', '錯', '酒', '＜', '\xa0', '君', '直', '亡', 'θ', '中', ';', '斧', '"', '又', '˙', '初', '折', '入', '才', '備', '一', '!', '系', '約', '做', '乐', '¸', '之', '×', '性', '蘭', '助', '晩', '曰', '暮', '⓸', '寒', '聽', '寨', '切', '風', '體', '帮', '猶', '活', 'ᄁ', '樂', '腐', '八', '∞', '→', '必', '燮', '女', '過', '精', '事', '球', '♬', '＂', '♪', '▣', '下', '[', '別', '七', '尺', '星', '因', '\U000f0852', '記', '知', '坤', '磨', '期', '高', '是', '甘', '足', '登', '愛', '鳴', '遠', '樣', '非', '\u2028', '三', '\uf09e', '橫', '摩', '戶'}

# %% [markdown]
# ## (_________) 제거

# %%
f = open(data_path+'JobKorea_preprocess1.pickle', 'rb')
raw_df2 = pickle.load(f)
f.close()
raw_df2.head(3)
# Out:
#   company_name                                              paper  \
# 0     (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1   한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url  \
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                          preprocess1  \
# 0  [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1  [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2  [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...
#
#                                          preprocess2
# 0  [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1  [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2  ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...

# %%
for idx in range(6):
    print(raw_df2.iloc[idx].preprocess2)
    print()
# Out:
# ['새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 도전이라 부족한 영어 실력으로 많은 어려움에 부딪쳤습니다. 잠깐 좌절도 했지만 그보다 가장 힘들었던 것은 부모님이 주신 소중한 기회를 제대로 활용하고 있지 못하고 있는 저의 모습이었습니다. 저는 좌절보다는 노력을 택하였습니다. 매주 영어 학원과 스터디그룹에 참석하였으며 다양한 이들과의 대화를 위해 혼자 펍에 가 친구를 사귀기도 하고 아르바이트를 통해 많은 이들과의 소통으로 영어 실력뿐만 아니라 소통력과 관계력까지도 키울 수 있었습니다. 이러한 경험을 바탕으로 경동나비엔의 일원이 되어서도 어떠한 어려움 속에서도 좌절하지 않고 백절불굴의 자세로 부족한 점을 계속해서 연구하고 개선하여 끊임없는 변화 속에서 끊임없는 노력으로 성공이라는 꽃을 피우도록 하겠습니다. ', '코카콜라의 뉴코크 실패는 소비자는 단순히 제품만을 소비하는 것이 아니라 그 브랜드 즉, 제품의 상징성을 구매하는 심리를 보여주고 있습니다. 해외시장에 존재하는 고객은 국내시장에 존재하는 고객들보다 기업에 대한 적은 정보를 가지고 있으며 시장진출에 있어 문화, 언어적인 부분을 넘어 다양한 것들을 고려하고 새롭게 시작하여야 합니다. 하지만 이 또한 기회가 될 수 있습니다 해외시장의 경쟁자들이 보여주지 않았던 부분을 통해 시장을 공략한다면 그 부분이 기업의 상징처럼 되어 하나의 문화, 브랜드가 되어 소비자가 소비하는 이유가 될 수 있습니다. 따라서 제품 구매 후에도 빠르고 다양한 서비스를 제공하는 확실한 사후서비스를 더 강화하고 강조한 전략을 통해 해외시장을 공략하고 애프터 서비스 하면 경동나비엔이 제일 먼저 해외시장의 사람들의 뇌리에 떠오를 수 있게 상징화시킬 수 있다면 해외시장 점유율을 꾸준히 높여갈 수 있을 것입니다. ']
#
# ['4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어학과 함께 소프트웨어공학 및 기계공학과의 졸업작품에도 각 1년간 참여했습니다. 조직응용기사 취득 및 2개 기사 1차 합격, 개인 서버 운영, 전자공학과 학부연구생과 지능형 자동차 경진대회 출전 등의 경험도 있습니다만, 자수 제한으로 인해 졸업작품 경험에 관해 기술하겠습니다. ', '정보통신공학에서는 온라인 자동 동기화 시스템을 제작했는데, 하드웨어 설계 및 제작, 펌웨어 (MCU)프로그래밍을 맡았습니다.@@@@@@@@@@@@@@@SW학 작품에서는 애플 iOS 앱을 2개 만들었고, 아이디어 회의부터 Swift와 Objective C언어로 프로그래밍, UI 제작, 문서작업, PPT 제작 등을 했습니다.@@@@@@@@@@@@@@@기계공학과 작품은 깡통크기의 초소형 위성 쏜 뒤 지상 복귀 중 위성의 자세를 제어하고 통신하는 것 이었습니다. 여기서 전자부품 선정과 C언어 프로그래밍 (통신, 자세제어)에 참여했습니다. 영어학과 응용탐구 (졸업준비 과목)에서는 영어 Resume와 Cover letter, SOP (대학원 진학을 위한 연구계획서) 등을 작성하는 연습을 했고, 매주 모여 연습한 것과 각자의 취업준비 과정을 발표하여 공유했습니다. ', '정보통신공학과 기계공학의 경우 제가 매우 선호하고, 경험이 많은 C언어와 펌웨어 프로그래밍을 맡았기 때문에 기본기를 다질 수 있었습니다. 제가 잘 모르는 타 전공의 기초지식들을 제가 잘 아는 HW지식과 접목시키는 것은 정말 흥미로웠습니다. 또한, 소프트웨어학과 졸업작품은 SW에 대한 색다른 경험을 맛보게 해주어 제가 전자공학과에서 정보통신공학과로 전과하는 계기가 되었습니다. 또한 다양한 전공의 여러 사람들과 정보를 교환하고 소통하며 협업하는 법을 배웠고, 제가 배우고 있던 전자공학에 국한된 시야에서 벗어나 다양한 방면에서 세상을 바라보는 법을 배웠습니다. ', '2019년 초부터 사회복무요원으로 20개월간 지역아동센터에서 복무했습니다. 사회복무요원은 주로 아동보육, 교육지도 (숙제와 학습할당량), 사무업무와 시설물 관리 (안내문 작성, 장식물 제작 등)의 업무를 맡았습니다. 사무업무 중 엑셀을 쓰는 업무가 많았는데, 대부분 어렵지 않으나 시간이 매우 오래 걸리는 작업이었습니다. 이를 엑셀로 자동화 하였습니다. ', '작업 대부분을 함수와 매크로로 대체했습니다. 쉬운 수정을 위해 변수들을 보기 좋게 배치했고, 사용법과 수정법을 담은 안내서를 함께 제작했습니다. 프로그래밍과 비슷해 즐겁게 작업했지만, 작업량이 많았고 아동센터 특성상 한 업무에 집중하기 어려워 이를 마치는 데에 2주가 걸렸습니다.@@@@@@@@@@@@@@@센터는 이미 인력 부족을 겪고 있었고, 제 전역 이후 새 요원 배치 예정이 없었습니다. 특별히 지시받지 않았고, 추가로 해야 하는 업무라 고민했습니다. 그러나 복지사들의 업무 감축은 근로자및 아동과 그들의 가족에게까지 영향을 준다고 생각해 진행했습니다. ', '그 결과 매월, 요원 두 명이 16시간가량 하던 작업을 한 명이 1시간 이내에 끝낼 수 있는 양식이 완성됐습니다. 덕분에 종사자들은 좀 더 아동을 돌보는 데 시간을 할애할 수 있게 되었고, 저의 소집해제 후에도 업무를 떠안은 부담이 적어졌다고 사회복지사분들이 말씀하십니다. 저 역시 엑셀을 적극적으로 활용해볼 수 있는 계기가 되었습니다. ', '재학 중, 조별 과제로 여러 기능을 가진 Java 프로그램 개발한 적이 있습니다. 프로젝트 규모와 문서작업 비중이 컸기에, 품질 향상과 문서작업 병행이 가능한 폭포수 모델의 소프트웨어 개발 프로세스를 따르자고 제시하였습니다. 하지만 실제 개발 중 진행은 더뎠고, 프로젝트 모듈화가 계획대로 되지 않아 기능들이 정상 작동하지 않았습니다. ', '나이 차가 많이 나는 저학년생과 함께 팀을 꾸렸고, 자연스레 팀장을 맡게 됐습니다. 더딘 프로젝트 진행은 그대로 갈 경우 문제가 있을 것으로 판단하였습니다. 그래서 개발 중반쯤 상의를 하여 프로세스 미준수와 더딘 문서화의 이유에 대해 물었습니다. 대답을 들어 보니 팀원은 저학년이라 개발 경험이 부족했고, 개발 프로세스에 대해 배우지 않아 이해도가 낮았으나 나이 차이의 압박과 부족한 시간에 쫓겨 따라오기 바빴던 것입니다. 팀원의 이야기를 듣고 나서 저는 팀원의 처지를 이해할 수 있었습니다. 팀원이 이해할 수 있게끔 프로세스를 설명하고, 어려운 부분을 제가 맡아 진행했습니다. 번거롭더라도 개발 중 진행 상황과 문제점을 종종 물어봤고, 팀원이 막혀서 혼자 고민하던 문제들은 같이 해결하며 업무를 도왔습니다. ', '기한 내에 구현과 문서작업까지 모두 마쳤고, 프로젝트 점수 만점이라는 좋은 결과를 내었습니다. 또한, 팀장으로서 인력 관리 기법을 얻었습니다. 처음엔 팀원이 비협조적이라 생각하고 비판적 태도를 취했으나, 섣불리 판단치 않고 소통으로 해결했습니다. 앞으로 불통이나 오해가 생겼을 때 대화가 필요하며 상대방의 처지에서 공감할 수 있어야겠음을 느꼈습니다. ', '전산시스템을 이루는 HW, SW, 통신 세가지 분야를 모두 아우르는, 전문성을 가지면서도 융합적 사고가 가능한 엔지니어를 목표로 삼아 재학중 다양한 경험을 했습니다. 이 중, 쌓을 수 있는 SW 지식이 제한적인 전자공학과에서 정보통신공학과로 전과를 결심했습니다. 당시 유일하게 전과가 가능했고, 소프트웨어 관련 과목이 많이 있었기 때문입니다. ', '전과 당시 이미 고학년이었기 때문에 졸업이 더 늦어지는 것을 막아야 했고, 과목별 학점도 좋게 받아야 했습니다. 하지만 들어야 할 과목은 많았고, 과목들의 특성은 모르는데다 일부 과목은 선행 기초 지식이 없어 학습해야 할 양은 기하급수적으로 늘었습니다.@@@@@@@@@@@@@@@이를 해결하기 위해 지피지기면 백전불태, 학과를 파악했습니다. 신중한 과목 선택을 위해 듣는 수업마다 무조건 반장에 지원했습니다. 수강생들과 친분을 쌓고 정보를 얻기에 좋았기 때문입니다. 수집 정보 기반으로 다음 과목의 요구 기초를 배워뒀습니다. 또한 수면 시간을 5시간으로 줄였고, 체력을 위해 운동을 병행했습니다. 그리고, 인적 자원의 수율을 끌어 올렸습니다. 프로젝트에서 팀장을 맡으면 SW 개발 프로세스와 HRM기법을 응용해 체계적으로 계획했습니다.@@@@@@@@@@@@@@@그 결과 계획대로 3학기 만에 졸업했고, HW와 SW 두 분야의 기본기를 다졌습니다. ', '이러한 경험을 통해 융합적 사고가 주는 잠재력을 보았고, 배움을 멈추고 싶지 않습니다. 그래서 취직 후 전공과 심리학 박사, 언어학 석사 취득을 계획하고 있습니다. 저의 개인적 역량을 지속적으로 끌어올리고, 집단 안에서 그룹원의 시너지를 향상시켜 기업에 없어선 안될 인재가 되기 위해 노력할 것 입니다. ', 'SW학과 졸업작품 작업 중, 한 팀원이 대면 작업 중에 피곤하다며 종종 자곤 했습니다. 자는 팀원이 분위기를 저해해 협업에 방해가 된다며 다른 팀원이 화를 냈습니다. 다른 팀원도 평소에 불만을 느꼈기에 제지하지 않았고, 갈등은 고조되어갔습니다. 분쟁에 끼고 싶지 않았지만, 이대로는 팀원 모두가 손실을 떠안게 되리라 판단해 중재했습니다. ', '일단, 감정을 가라앉힌 뒤 양측의 불만과 견해 차이를 정리했습니다. 결과 중심 팀원과 과정 중심 팀원들 간에 의견 차이를 확인하고, 근본적 원인을 찾아보았습니다. 객관적으로 보니 양측의 갈등은 성격 차이로 부터 시작되어 쌓여왔음을 알게 되었습니다. 서로 진행 방식이 틀린 것이 아닌 다른 것임을 알고 이해하자 팀 전체가 안정됐습니다. 각자 성향에 맞게 업무를 재배정하고, 서로의 다름을 비난하기보다 인정하고 배려하기를 당부했습니다. 처음엔 혼란스럽고 막막했지만, 문제점을 객관적인 시각에서 나열하고 토의했습니다. 그 결과로 갈등의 근본적 원인을 파악했으며 기초적 해결책을 얻을 수 있었습니다. ', '상대방의 입장을 이해하고 배려하는 것 입니다. 대화의 불통과 오해는 근본적으로 상대의 처지를 잘못 이해할 때 생기기 시작합니다. 또한 상대를 배려하지 않는다면 일방적으로 행동하는 사람, 소위 말하는 “꼰대”가 되고 협동력이 떨어지는 사람이 될 것 입니다. ']
#
# ['"끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일을 시작하기 전에 두려운 마음이 들 때마다 이러한 마음가짐을 갖추고 도전하였습니다. 교내에서 실시하는 경제 골든벨 대회에 참여했던 경험이 있습니다. 학교 시험이 끝난 후 담임 선생님께서는 이틀 뒤에 대회가 실시될 것이라며 자세한 일정에 대해서 공지해 주셨습니다. 문제 출제 범위는 70페이지에 달하는 경제 관련 용어들이었습니다. 공부해야 하는 양에 비해 대회 전까지 준비할 수 있는 기간이 짧게 느껴졌기 때문에 주변 친구들은 저에게 지금부터 시작해봤자 좋은 성적을 거두지 못할 것이라며 포기하기를 권유하였습니다. 하지만 전부터 기다렸던 대회였고 꼭 해내고 싶다는 생각이 들어 이틀이라는 기간 동안 시간이 날 때마다 보며 공부하였습니다. 잘 외워지지 않는 부분은 따로 암기 노트를 만들어 들고 다니면서 익숙해지도록 하였고 저만의 암기 매뉴얼을 만들어가며 공부하였습니다. @@@@@@@@@@@@@@@그 결과 대회에서 1위라는 성적을 거둬 최우수상을 수상할 수 있었습니다. 이 경험을 통해 모든 일에 포기하지 않고 노력하여 달성하는 방법에 대하여 배우게 되었습니다. 이러한 역량을 바탕으로 맡은 업무에 대해 끝까지 완수해내는 사원이 되겠습니다. ', '저의 장점은 어떤 일이든 책임감을 가지고 수행해내는 것입니다. 고등학교 1학년 때 학습 부반장을 맡았던 경험이 있습니다. 당시 반의 수업 분위기가 좋지 않았고 이 점에 불만을 가진 친구들이 생기게 되었습니다. 그래서 저는 학습 분위기 개선이 필요하다는 생각이 들었습니다. 먼저 수업 시간에만 휴대폰을 걷자는 의견을 냈고 대부분이 찬성하여 실시하게 되었습니다. 매 수업 시간 전 반 친구들이 휴대폰을 낼 수 있도록 안내하고 안 낸 친구가 없도록 일일이 수를 세는 역할을 수행하였습니다. 또한 수업 내용을 이해하지 못한 친구들에게는 쉬는 시간과 방과 후 시간을 이용하여 설명해 주었습니다. 그 결과 반 학습 분위기도 좋아지고 학기 초 성적 최하위권 반에서 학기 말에는 1등 반으로 마무리할 수 있었습니다. @@@@@@@@@@@@@@@저의 단점은 많은 사람들 앞에서 말하는 것을 조금 두려워하는 것입니다. 이러한 성격 때문에 항상 준비한 만큼 결과를 보여주지 못하여 극복하고 싶었습니다. 그래서 학급 부반장이나 동아리 차장 등 임원 역할을 맡아 친구들 앞에서 말을 하는 연습을 하였고 수업 시간에도 나서서 발표하려고 노력하였습니다. 또한, 중요한 발표 전에는 실제 상황처럼 가정하여 리허설 연습을 하며 극복하고 있습니다. ', '체육대회 때 반 대항전으로 실시하는 치어리딩에 참여하였습니다. 평소 춤추는 데에 자신이 없어 사람들 앞에서 추는 것을 꺼려 하였습니다. 그러다 보니 연습을 할 때 자연스럽게 동작이 작아졌고 친구들에 비해 진도도 뒤처지게 되었습니다. 치어리딩은 협동심이 중요시되기 때문에 저로 인해 팀 전체에 피해가 갈 수도 있는 상황이었습니다. 이러한 상황을 극복하기 위해 연습하는 모습을 녹화하여 다시 보며 스스로 피드백을 하고 주변 친구들에게도 보여주며 고칠 부분을 찾아나갔습니다. 동작 연습 후에는 가족들 앞에서 춤을 추며 극복해나갔습니다. 그 결과 저희 반은 치어리딩 부분에서 높은 점수를 받아 종합 1위를 할 수 있었고 반 친구들은 체육대회 MVP로 저를 뽑아주었습니다. @@@@@@@@@@@@@@@전산회계 운용사 2급 자격증 실기 시험에서 불합격했던 경험이 있습니다. 방과 후 수업에 참여하여 열심히 공부하였지만, 시험 당일 프로그램 오류로 인해 작성했던 답안지가 저장이 되지 않았습니다. 그 결과 다른 과목에서 높은 점수를 받았지만 한 과목에서 0점을 받아 합격하지 못하였습니다. 이 경험을 바탕으로 만일의 상황까지 예측하며 계획하는 습관을 가지게 되었고 다음 시험에 재도전하여 높은 점수로 합격할 수 있었습니다. ']
#
# ['벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력@@@@@@@@@@@@@@@"보드전문 개발 벤처기업부터 제조 공장 자동화, 금융개발까지"@@@@@@@@@@@@@@@저는 어려서 배운 컴퓨터 강의를 동기로 OOOOOOOO OOOO학과를 지원하여, 컴퓨터에 대한 꿈을 키워 나갔습니다. 전공을 통해 컴퓨터의 역사를 다시 공부하면서 운영체제, 소프트웨어 공학, 알고리즘, 프로그래밍 언어론, 데이터베이스 시스템, 자료구조 등을 배웠습니다. 학부시절, 전공뿐 아니라 어학실력을 향상시키기 위해 영어어학원을 열심히 다니면서 영어 회화, 영작문 실력을 길렀습니다. 학부 4년에는 OOO 학생회의 OOOOO 차장으로서 자연대 행사와 축제를 기획하고, GMP 영어 동아리 회원으로 활동하였습니다. @@@@@@@@@@@@@@@학부 졸업후 OOOO에 입사해 하드웨어 관련 개발에서, 태그를 통해 출입통제를 관리하는 시스템을 개발하고, 임베디드 WinCE 운영체제를 개발하여 2000년 OOOO OOO 전시회에 참가하였습니다. 윈도우 컴팩트 에디션인 임베디드 WinCE의 윈도우 시스템에 전시회 관람 온 개발자들 사이에서 호응이 좋았습니다. 이후에 OOOOOO에 입사하여 화상채팅시스템 개발에 투입되어 근무하다가 대구로 이직을 하였습니다. 2000년 12월에 OOOOO시스템에 입사하여 OO 디스플레이 P4공장 TFT Shop 장비 CIM 표준화 개발 프로젝트에 투입되어 Stripper, Asher 장비의 표준화 업무를 하였습니다. 반도체 장비 표준 프로토콜(SECS)로 장비 CIM과의 통신 개발 프로젝트에서 장비 Spec. 미팅, 대응사양서 작성, 테스트 시나리오 작성 등의 업무를 수행하여 LCD P4공장의 장비 셋업을 성공적으로 마쳤습니다. OOOOO에서는 프리랜서 계약으로 한단계 상위 시스템인 OO 디스플레이 P5 CF Shop 장비서버 개발 프로젝트에 투입되어 장비서버와 상위 CCS시스템의 메시지 전송 프로토콜을 개발하였습니다. 패턴 검사기, 높이 측정기, 두께 측정기 등 7종의 장비에 셋업을 마쳤습니다. P4 장비 CIM 표준화 프로젝트와 동일하게 장비 Spec. 미팅, 장비 벤더업체 미팅 및 의견조율, 대응사양서 작성, 테스트 시나리오 작성 등의 프로젝트 기본설계에서 개발단계, 테스팅 및 셋업완료까지 프로젝트에 참여하였습니다. 장비서버 FAB 테스팅 시에는 장비업체 엔지니어가 여자 엔지니어고 저 또한 여자 엔지니어라 주변에 여러 엔지니어가 관심을 보였습니다. OOOO에서는 제조 SCM 시스템 개발과 CF Shop의 P6 장비서버 프로젝트를 수행하였습니다. @@@@@@@@@@@@@@@제조 공장자동화 프로젝트를 그만두고 OOOOO의 OO은행 자금관리시스템 개발 프로젝트에 참여하여 금융업무 중 대금수납업무개발에 델파이와 MS-SQL을 이용하여 구현하였습니다. 다시 자동화 프로젝트로 OOO에서 OO실트론의 스토커 MCS 시스템 개발 프로젝트에서 시스템 개발에 투입되어 스토커 MCS 시스템, MM시뮬레이터, 테스팅 툴 등을 개발하였습니다. OOOOO에서는 OO전자의 MES 시스템의 UI 업데이트 프로젝트에 참여하여 각 장비단에서 온 데이터를 기반으로 웹리포팅하는 화면을 개발하였습니다. @@@@@@@@@@@@@@@저의 강점은 새로운 시스템 적응에 빠르고 창의적인 아이디어를 제안하고, DOS에서 윈도우98, 윈도우2000, 윈도우XP 등의 다양한 윈도우환경에서의 개발 경험과 개발언어로 델파이, 비주얼베이직, MS-SQL, 오라클, JAVA/JSP 등을 이용하였습니다. 구성원들과의 커뮤니케이션과 의견 조율 능력도 갖추었습니다. 개발자로서 테스팅에도 강합니다.@@@@@@@@@@@@@@@자동화 프로젝트를 잠시 그만 두었을 때에는 2003년 OO OO OOOOOO의 선수촌 영어 통역 자원 봉사자로서 활동하였습니다. 대회기간 동안 선수들과 자원봉사 친구들과 친하게 되는 기회가 되었고, 세계적인 국제대회의 영어 통역 자원봉사 활동을 할 수 있어 기뻤습니다. 2011년 부터 현재까지 경력이 단절되어 경력공백이 있으나 프로젝트 수행하는데 아무런 문제없이 설계업무든 Java/JSP/C#/비주얼베이직 등의 개발업무 모두 가능합니다. 현재 2020년 11월부터 OOOO에서 구비 실트론 원부자재 통합 품질관리(MQMS) 구축 프로젝트에 참여하고 있습니다. 개발환경은 .Net, MS Studio 2015 C#, Oracle 환경하에서 시스템을 구축하고 있고, 화면설계 및 개발을 담당하고 있습니다. 저의 경력과 경험이 귀사의 발전에 기여하는 바가 있고, 잠재적 가능성이 귀사에서 발휘할 수 있는 경력이 될 수 있도록 저의 능력을 최대한 활용하겠습니다. 새로운 업무에 적응하여 성심을 다해 임하겠습니다. ']
#
# ['저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 어려움을 덜어낸 경험이 있습니다. 저는 감시부대에서 복무했습니다. 약 100일간 감시임무를 수행하고 임무를 마치면 다른 소대와 교대를 합니다. 교대하는 과정에서 소초 내 물품의 상태를 확인하는데, 양이 너무 많아 약 일주일 동안 감시임무와 병행하면서 확인해야 했습니다. 그래서 전 확인해야 할 품목이 무엇이고, 어디에 있는지 그리고 수량은 몇 개인지 등을 기록한 체크리스트를 만들었습니다. 이것을 활용해 시간을 단축해 효율적으로 처리할 수 있었고 감시인원의 피로도 해결할 수 있었습니다. @@@@@@@@@@@@@@@고등학교 때 저는 서로 다른 국적을 가진 6명이 한 팀을 이뤄 프로젝트를 진행한 적이 있습니다. 성공하지 못하면 졸업을 할 수 없었기에 모두 다 최선을 다해야 했습니다. 약 1년 동안 진행되는 프로젝트를 성공적으로 마무리하기 위해 전 개개인의 뛰어난 역량이 아닌, 6명이 하나로 뭉쳐 주어진 과업을 협력을 통해 해결해나가는 것이 매우 중요하다고 생각했습니다.@@@@@@@@@@@@@@@그래서 전 팀에서 의견을 주장하기보다 먼저 팀원들의 의견을 들었습니다. 상대방의 말에 집중했더니 의견에 부족한 점을 파악할 수 있었고, 저는 주로 그 부족한 점을 보완하는 의견을 제시했습니다. 상대방의 의견에 경청하는 제 태도는 팀원들에게 좋은 인상을 주었고, 자연스럽게 팀을 이끄는 역할을 맡게 되었습니다. 프로젝트를 진행하면서 팀원이 어려움을 느끼면 다가가 도와주었고, 반대로 제가 어려움을 겪으면 다른 팀원이 다가와 도와주었습니다. 그렇게 저희는 협력을 통해 하나로 뭉쳐 맡은 과업을 충실히 수행했고, 졸업식 날 최고의 논문으로 뽑히면서 마무리할 수 있었습니다. @@@@@@@@@@@@@@@마지막으로 전 업무를 수행하면서 기존 방식에 대해 문제의식을 느꼈고, 이를 적극적인 태도로 해결한 적이 있습니다. 이런 제 모습은 주어진 일을 효율적으로 처리할 수 있고 OOOOOOOO을 발전할 수 있는 발판을 만들 수 있다고 생각합니다. @@@@@@@@@@@@@@@군대에서 신고전화가 왔을 때 당직근무를 하는 간부마다 서로 다르게 응대해, 상황을 기록하는 업무를 맡은 전 어려움을 겪었습니다. 신속하고 정확하게 기록한 후 상급부대에 제출해야 하지만 혹시라도 놓친 건 없는지 확인하느라 그러질 못했습니다. 그래서 전 먼저 직속상관에게 이 문제를 보고했습니다. 이후, 문제점을 해결하기 위해 여러 방안을 고안했고, 그중 가장 적절한 것은 무엇인지 주변 전우와 간부들에게 도움을 받았습니다. 또한, 인사과에 방문해 제가 생각한 방안을 이야기하고, 이것을 어떻게 더 활용할 수 있는지를 논의해 부족한 점을 보완했습니다.@@@@@@@@@@@@@@@모든 것을 다 정리한 후 소대장은 중대장에게 문제점 및 해결방안을 보고했고, 중대장은 대대 주간회의에서 보고받은 방안을 소개했습니다. 대대장은 조금만 더 수정한 후 바로 반영하도록 지시를 해 불편함을 해소할 수 있었습니다. 이 문제를 해결하기 전까지 군대는 변화를 꺼리는 집단인 줄 알았습니다. 그렇기에 불편하더라도 불평 없이 감수하는 것이 옳은 선택이라고 생각했습니다. 하지만 적극적인 태도로 다가가 불편함을 해소했을 뿐만 아니라, 다른 부서와 함께 의견을 나누며 협업을 경험할 수 있었습니다. 또한, 이 경험을 통해 고정관념을 부술 수 있었고, 더 나은 선택이라면 무엇이든 적극적으로 행동할 수 있는 계기가 되었습니다. ']
#
# ['음악을 사랑합니다. 음악뿐만 아니라 문화산업 전반에 깊은 관심이 있습니다. CJ ENM은 시장 변화에 발맞춰 문화 콘텐츠 산업의 트렌드를 선도하는 기업입니다. 자본력과 추진력, 그리고 트렌드를 읽는 능력을 바탕으로 영화, 방송, 공연, 음악 등 다양한 장르의 콘텐츠를 만들어내고 있습니다. 바로 이 점에서 매력을 느꼈습니다. 보다 더 다채로운 콘텐츠 제작에 동참하며 기여하고, 회사와 함께 성장하고자 CJ ENM에 지원합니다. @@@@@@@@@@@@@@@Mnet 에 지원자로 출연한 경험이 있습니다. 3차 예선까지 진출하면서 방송이 어떻게 촬영되고 만들어지는지 직접 체험할 수 있었습니다. 2차 예선 당시, 1차 예선을 통과한 100여 명 내외의 출연자들은 각각 한 문장으로 소개되었습니다. 지원자 개개인의 특성을 파악하여 이미지를 부여했다는 점이 흥미로웠습니다. 또한, 인터뷰 영상과 녹음된 음성 파일 같은 소스들이 어떻게 방송에 쓰일지 궁금했습니다. 이후 실제로 방영된 방송분과 촬영 현장 당시를 비교하며 감상하기도 했습니다. 그때부터 콘텐츠 제작에 흥미가 생겼고, 특히 음악 관련 콘텐츠를 만들고 싶었습니다. 자연스럽게 음악 전문 채널인 Mnet의 PD 직무에 관심을 갖게 되었습니다. @@@@@@@@@@@@@@@창의성과 꼼꼼함으로 무장한 PD가 되겠습니다. 음악 활동을 할 때, 크루 동료들과 함께 뮤직비디오를 제작한 경험이 있습니다. 저예산으로 멋진 영상을 만들고 싶었습니다. 비용을 절감하면서도 현장감을 주기 위해 원테이크 기법을 제안했고, 전체적인 콘티와 동선을 짰습니다. 촬영 중에도 동선과 움직임에 관련된 아이디어를 끊임 없이 제안했습니다. 촬영 이후엔 100개가 넘는 테이크에서 최고의 한 테이크를 선정하는 일을 맡았습니다. 모든 테이크를 5회 이상 확인했습니다. 표정, 립싱크, 제스쳐 등을 고려하여 단 하나의 테이크를 정했고 뮤직비디오는 약 2,000회의 조회수를 기록했습니다. 입사 후에도 콘텐츠에 관한 다양한 아이디어를 낼 것이며, 꼼꼼하게 콘텐츠를 검토하여 최선의 결과물을 만들어 내겠습니다. ', "BTS의 성공 요인은 크게 두 가지입니다. 첫 번째로는 전 세계적으로 충성도가 높은 두터운 팬덤입니다. BTS는 대한민국을 넘어 전세계적인 인기를 자랑합니다. 이러한 팬덤은 팬들과의 지속적이면서도 적극적인 소통을 통해 구축되었습니다. 꾸준한 활동과 'V Live'와 같은 실시간 소통으로, BTS는 기존의 팬들을 놓치지 않았고, 새로 유입된 팬들도 그들 곁에 계속 남아 있게 하는 이유가 되었습니다. 끊임없는 커뮤니케이션이야 말로 팬들의 충성도를 높이며 유지하는 방법이라는 것을 다시금 깨달았습니다. @@@@@@@@@@@@@@@두 번째 성공 요인은 자본의 재투자, 그리고 이를 통한 글로벌화입니다. BTS를 제작한 빅히트엔터테인먼트는 벌어들인 수익의 대부분을 재투자하여 뮤직비디오 또는 라이브 영상과 같은 콘텐츠를 지속적으로 생산했습니다. 그 결과 무려 아홉 편의 뮤직비디오에서 유튜브 기준 5억 회 이상의 조회수를 기록했습니다. 이후 대한민국을 넘어 세계로 눈을 돌렸고, 결국 신곡 'Dynamite'는 곡 전체를 영어 가사로 만들며 빌보드 차트 2주 연속 1위라는 성과를 이뤘습니다. 단기적인 성공에 안주하지 않은 과감한 재투자는 세계적인 성공과 더 큰 수익을 창출할 수 있었습니다. @@@@@@@@@@@@@@@BTS를 포함한 K-POP의 전반적인 발전을 위해서는 끊임없이 영상 콘텐츠를 생산해야 합니다. '포스트 코로나'가 아닌 '위드 코로나'의 시대를 준비해야 하는 지금, 공연 산업은 점점 침체되고 있습니다. 이를 대체하기 위해 적지 않은 수의 라이브 스트리밍 공연이 열리지만, 오프라인 공연에서만 느낄 수 있는 현장감을 대체하기는 어렵습니다. 따라서 실시간이 아니더라도, 더 높은 퀄리티의 영상 콘텐츠를 꾸준히 만들어야 합니다. 2020년 1~4월 기준, 국민들의 스마트폰의 동영상 월평균 이용시간은 전년도 동기 대비 무려 31.1% 증가했습니다. 이를 반영하여, 예컨대 M2의 멤버별 무대 직캠 영상과 같은 양질의 콘텐츠를 지속적으로 만들어야 하고, 나아가 전세계 소비자들의 니즈를 충족시키는 콘텐츠를 제작해야 합니다. ", "최근 원더케이의 '본인등판'이라는 콘텐츠를 가장 재밌게 시청했습니다. '본인등판'에서 뮤지션은 SNS에 본인의 이름을 검색합니다. 커뮤니티 게시글, 음원사이트 댓글 등을 읽으며 그 반응을 담는 인터뷰 콘텐츠입니다. 예컨대, 나무위키, 디씨인사이드, 힙합엘이, 인스타그램과 같은 플랫폼에 아티스트가 직접 접속하여 네티즌의 반응을 살핍니다. 또한 멜론과 같은 음원사이트에서 자신의 디스코그래피를 훑으며 앨범 당시의 비하인드 스토리를 공개하기도 합니다. 참신한 아이디어로 해당 콘텐츠는 평균 122만회의 높은 조회수를 기록 중입니다.@@@@@@@@@@@@@@@이 콘텐츠를 재밌게 시청한 가장 큰 이유는 기존에 없던 방식으로 팬들의 궁금증을 효과적으로 해결했다는 점입니다. 팬들은 뮤지션이 댓글을 읽고 어떤 반응을 보일지 궁금해하기 마련입니다. 이 궁금증을 '본인등판'이라는 이름으로 해결하는 콘텐츠를 기획한 점이 참신했습니다. 팬들은 비록 자신이 남긴 댓글이 아닐지라도 간접적으로나마 아티스트와 소통하는 기분을 경험합니다. 또한, 뮤지션의 데뷔부터 현재까지의 디스코그래피를 훑으며 각 앨범 활동 당시 뮤지션 본인의 생각을 엿볼 수 있다는 점에서 소비자의 흥미를 자극합니다. 새로운 아이디어로 소비자들의 니즈를 충족시켜 높은 조회수로 이어진 좋은 사례입니다. @@@@@@@@@@@@@@@하지만 이런 종류의 콘텐츠는 섭외된 아티스트의 인기와 역량에 따라 화제성이 크게 좌우된다는 점에서 명확한 한계점을 가집니다. 회차를 거듭할수록 인기 있는 뮤지션의 수가 고갈되고, 섭외는 점점 어려워집니다. 이를 극복하기 위해서는 섭외의 범위를 더 넓혀야합니다. 예컨대, 해외 뮤지션을 섭외하는 방법이 있습니다. 이를 위해서는 채널과 콘텐츠의 브랜딩화를 통해 인지도와 조회수를 더욱 올려야 할 것입니다. 또한, 섭외 영역을 뮤지션에 국한하지 않고 배우, 방송인, 나아가 대형 크리에이터까지 넓혀야 합니다. 이렇게 섭외의 폭을 넓힌다면 보다 더 지속적으로 콘텐츠를 생산할 수 있게 되고, 더 넓은 층의 소비자들을 타겟팅하여 끌어모을 수 있습니다. "]

# %%
new_contents3 = raw_df2.preprocess2.tolist()

# %%
# 사용된 전체 괄호 확인
p = re.compile("\([^\)]*\)")
brackets = []

for cs in new_contents3:
    for c in cs:
        brackets.extend(p.findall(c))
        
# print(len(brackets))
# brackets = list(set(brackets))
# print(len(brackets))
# brackets

# 긴문장 확인하여 자소서 내용이면 내용 놔두고 괄호 삭제
longbrackets = []

for i, bracket in enumerate(brackets):
    if len(bracket) > 100:
        for j, content in enumerate(new_contents3):
            for c in content:
                if bracket in c:
                    longbrackets.append(j)
                    break
            else:
                continue
            print(raw_df.iloc[j]['url'])
        print(bracket)
        print()

longbrackets = list(set(longbrackets))
longbrackets.sort()
longbrackets

a1 = ['@@@@@@@@@@@@@@@대학 시절 고등학생의 진로 멘토링을 하며 교육업에 뜻을 품었습니다. 인간의 존재 의미는 일을 통한 사회 공헌에 있다고 생각합니다. 원활한 행정처리로 학생들의 대학생활에 도움을 주고싶습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@가장 일하고 싶은 분야는 국제처입니다. 영어 및 중국어 역량을 바탕으로 교환학생들의 어려움에 귀 기울이고 더 나은 교환학생 생활을 위해 다방면으로 지원방안을 마련하는 도움 되는 직원이 되고 싶습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@상대의 의견을 수용할 수 있는 개방적인 태도입니다. 상대방이 틀린것이 아니라 다른것임을 인지함으로써 상대의 의견을 경청할 수 있고 이를 통해 원활한 커뮤니케이션 및 협업을 이룰 수 있기 때문입니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@아르바이트를 할 당시 오전 출근자로부터 당일 새벽에 연락이 와서 급한 일이 생겼으니 근무시간을 바꿔달라는 요구를 받았습니다. 저는 당시 오전에 건강검진이 예정되어 있었습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@이유도 듣지 못했기에 탐탁지 않았지만 다급해 보이는 목소리에 걱정이 되어 건강검진을 연기하고 수락했습니다. 뒤늦게 들은 이유는 아버지의 임종을 지키기 위해서였습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@배려는 사소하지만 영향은 위대하는 것을 배웠습니다. 그 분은 일에 신경 쓰지 않고 아버지의 마지막 모습을 함께 할 수 있었습니다. 오늘날처럼 밖에서 많은 시간을 보내는 사회인에게는 배려가 더욱 필요합니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@1) 패션 브랜드 입/퇴점 기획%%%%%%%%%%%%%%%직무영역: 기획 %%%%%%%%%%%%%%%역할: 프로젝트 매니저%%%%%%%%%%%%%%%수행내용: 분당, 강남, 송파에 위치한 백화점의 상권 분석 및 고객 라이프스타일 분석을 통해, 각 상권에 최적화 된 패션 브랜드의 입점을 제안 및 상권에 맞지 않는 브랜드의 퇴점 제안 %%%%%%%%%%%%%%%성과: 매출 위주의 입/퇴점 관행을 깬 고객중심적 MD 모델 완성$$$$$$$$$$$$$$$$$2) 영업시스템 설계 %%%%%%%%%%%%%%%직무영역: 기획 %%%%%%%%%%%%%%%역할: 프로젝트 매니저%%%%%%%%%%%%%%%수행내용: 판매사가 상주하지 않는 셀프쇼핑 매장의 매출을 높이기 위한 영업시스템 설계. 고객 구매특성에 따른 상품별 진열방식 변경, 피크타임 분석을 통한 FILL-UP 시스템 도입, 판매사 일일 근무스케줄을 통한 낭비과업 제거%%%%%%%%%%%%%%%성과: 재고일수 50% 감소 및 일매출 30% 성장$$$$$$$$$$$$$$$$$3) 브랜드 관리%%%%%%%%%%%%%%%직무영역: 영업관리 %%%%%%%%%%%%%%%역할: 층 관리자%%%%%%%%%%%%%%%수행내용: 한 아울렛의 아동층 관리자로서 약 30개 브랜드의 매출을 관리, 상권 특성 및 시즌 트렌드를 반영한 프로모션 기획%%%%%%%%%%%%%%%성과: 기획전 매출 전년대비 20% 성장 @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@저는 꾸준히 믿고 있는 신앙 및 현재 다니고 있는 교회는 없지만, 대부분의 종교에 대해 개방적인 태도를 갖고 있습니다. 특히, 제가 인생에서 중요하게 생각하는 가치인 섬김과 봉사는 연세대학교의 기독교 정신과도 일치한다고 생각해, 기독교 문화에 대해서 열린 마음을 가지고 있습니다. 따라서 연세대학교의 교직원으로서 사명감을 가지고 섬김과 봉사의 실천을 위해 노력할 것입니다. @@@@@@@@@@@@@@@ ']
a2 = ['@@@@@@@@@@@@@@@"iCOOP생협그룹이 마주보는 춘추전국시대 뛰어들 각오가 되어있습니다."$$$$$$$$$$$$$$$$$iCOOP생협그룹은 최근 국내산 친환경 농산품 판매촉진을 위한 업무협약 및 홍콩시장에 사업진출에 힘써왔습니다. 이러한 두 측면의 행보는 협동조합업의 미래를 꿰뚫는 핵심 Kewword임을 저 또한 여실히 공감을 했습니다. \'생활\' 속에서 필요한 조합원들의 니즈를 반영하고 회계적 펀터멘털을 탄탄히 하기 위한 방안을 고안해내는 일원이 되고자 지원을 결심하게 되었습니다. $$$$$$$$$$$$$$$$$첫째, 회계자격증들을 취득하며 회계에 대한 기본 개념을 배우면서 업무를 위한 밑거름을 쌓아왔습니다. 또한 재무분석 보고서 및 사업보고서를 살펴보며 직접 수치를 구해보며 실무에 부드럽게 적응할 수 있는 능력을 키웠습니다. $$$$$$$$$$$$$$$$$둘째, 최근 게임회사 인턴과 사무보조아르바이트를 하면서 ms office능력과 사무에티켓을 함양할 수 있었습니다. oooooo에서 근무하며 동향보고서와 테스트케이스 등을 작성하면서 엑셀과 워드를 많이 사용해보았고 사무보조아르바이트는 수출행사 대행사의 실적집계요원과 회계사무소에서 주택담보대출심사 보조를 하였습니다. $$$$$$$$$$$$$$$$$이렇게 쌓은 저의 역량으로 은행/대형마켓/다양한 지역사업 등이 얽혀있는 춘추전국시대에서 "iCOOP 조합원의 요구와 사업을 우선적으로 발 빨리 파악하여, 꼼꼼하고 성실한 회계업무를 처리하기 위해 적극적으로 행동할 것입니다" @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@먼저 손을 내밀줄 아는 사람냄새 나는 人 $$$$$$$$$$$$$$$$$러시아의 표트르 대제는 개혁을 통해 서구문물을 수용했지만 흥선대원군은 쇄국정책으로 일관하였고, 결국 정반대의 결과를 낳고 말았습니다. 자신 그리고 조직의 발전과 화목을 위해선 먼저 한발 다가 설 줄아는 노력이 필수라고 생각합니다. 이는 조합업계에서 요구하는 조합원과의 네트워크구축과 회계리뷰를 하기 위한 커뮤니케이션 필요과정에서 필수적인 역량이라 생각합니다.$$$$$$$$$$$$$$$$$대학교 때 전과를 한 저는 첫 팀플과제가 주어졌는데 교수님께서 하고싶은 사람끼리 조를 짜오라 하셨습니다. 아는 사람이 한명도 없었고 모두가 삼삼오오 팀을 만들고 있었습니다. 아무도 다가오는 이가 없었을 때 문득 먼저 말을 걸고 손을 내밀어보고 싶었습니다. $$$$$$$$$$$$$$$$$인상이 친근해보이는 남학우 부터 시작해서 강의실 곳곳에 혼자 앉아있거나 아직 조를 못짠 것 같은 인원들에게 다가가 같이 해보지 않겠냐고 물었습니다. 그랬더니 모두들 흔쾌히 그러겠다고 답해주었습니다. 이렇게 맺은 4명의 인연들은 졸업때까지 친한사이로 유지할 수 있었습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@"똑같은 유형의 고객문의 해결하기"$$$$$$$$$$$$$$$$$최근oo이라는 게임회사에서 CS 및 어플운영관리 업무를 했었습니다. 그 과정에서 하루에 30~50여건의 문의들어 왔는데 중복되는 유형이 눈에 들어왔습니다. ▶어플과 관련없는 각 게임문의 ▶관련사의 게임문의 ▶이미 날짜가 지난 이벤트 문의 등이 대표적이었습니다. 일일이 동일유형에 답변이 다 나가야 했기 때문에 다른 업무도 있는데 행정력이 낭비되는 것 같았습니다. $$$$$$$$$$$$$$$$$그래서 최근 한달 간의 문의들을 접수된 백오피스에서 유형건으로 엑셀정리를 한 후 , 이러한 문의들에 대해서는 강제적으로 경고창이 뜨거나 해당문구를 박아놓자고 의견을 구해보았습니다. 팀업 무회의시간에 팀장님과 직속 사수는 긍정적으로 검토해보겠다고 하였고 사업팀에게 다음 패치 때 적용하겠다고 피드백이 돌아왔었습니다. $$$$$$$$$$$$$$$$$이렇게 행동했던 이유는 우리 부서에는 해결해줄 수 없는 일임에도 계속 이관처리하는 불편함이 있어서였습니다. 그래서 인턴신분에는 이러한 개선점을 발견할만한 시간이 있었기에 최대한 주도적으로 노력해보았던 경험이었습니다. 앞으로 이러한 행동력을 iCOOP생협그룹에서도 꼭 발휘해보고 싶은 마음이 있습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@"정직하게 평가받지 못한 시험점수"$$$$$$$$$$$$$$$$$4학년 2학기 공공정책과 법 기말평가 때 교수님께서 \'조장이 조원들의 참여점수를 메일로 제출해라\'는 공지를 주었습니다. 가장 열심히 한 인원에게는 5점이였고 불성실한 인원에게는 1점이였으며 중복점수는 불가했습니다. 객관적으로 정직하게 점수배분을 하고 싶었지만 결정이 쉽지 않았고 제 나름대로 불만도 있었습니다. $$$$$$$$$$$$$$$$$조원들이 다들 친한 동기와 형들이었고 발표준비를 제가 가장 많이했기 때문입니다. 또한 메일로만 제출하면 아무도 모르기에 나의 점수를 5점으로 주었고 나머지는 저의 주관적인 생각으로 점수를 부여한 후 제출했습니다. 나의 결정으로 타인의 학점이 관련된 중요한 사항임에도 불구하고 구성원들에게 전달이나 공지과정이 없었던 고 그대로 방학을 맞이한게 지금 생각해도 올바르지 못한 실수였다고 생각합니다. $$$$$$$$$$$$$$$$$앞으로는 친한사이의 경우라도, 상황에 맞는 자의적인 판단을 최대한 배제하고 공적인 업무에서는 관련 절차와 객관적인 업무처리를 하기 위해 노력할 것입니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@"팥빙수 한 그릇"$$$$$$$$$$$$$$$$$여름방학 동안 실내포장마차에서 요리보조 및 서빙경험이 있습니다. 여름철을 맞아, 메뉴에 없었던 팥빙수를 손님들에게 공짜로 서비스 해주기로 했습니다. 반응은 좋았고 손님들 또한 꾸준히 이어졌습니다. 바쁜 탓에 쉬는시간이 될 때마다 저와 또래 아르바이트생들은 쉬는공간에서 직접 팥빙수를 만들어먹었습니다. $$$$$$$$$$$$$$$$$그러다가 문득 에어컨도 나오지 않는 주방 뒷공간에서 설거지만 끊임없이 하고 있는 이모님 생각이 났습니다. 어서 팥빙수를 한 그릇 만들어 가져다 드리자 생각보다 굉장히 좋아하시는 모습이 기억에 남습니다. 한 여름 2개월동안, 나이 또래에 맞는 손님들을 챙기기에 급급해 가장 가까운 주변을 돌아보지 못했구나 라고 강한 울림을 느꼈던 경험이었습니다. $$$$$$$$$$$$$$$$$앞으로도 누군가를 처음 만날 때의 설레임을 꾸준히 유지하여 타인에게 강한 믿음을 주고자 합니다. 그런마음가짐이라면 iCOOP생협그룹 조합원 및 사업관련 이해관계자들과 함께 어울려나갈 수 있다고 생각합니다. @@@@@@@@@@@@@@@ ']
a3 = ['@@@@@@@@@@@@@@@[ 장점 : 조직의 마침표를 찍으며 신뢰를 얻었습니다 ] %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%\'10/5/5\' 제가 참여했던 아르바이트/대외활동/봉사활동 숫자입니다. 20개의 활동이 끝나고 마무리 기념사진에는 항상 저의 얼굴이 찍혀있었습니다. 약속한 근무기간 이전에 그만둔적이 한번도 없었고, 팀프로젝트 활동에서도 개인사정을 핑계로 중도하차해 팀원들에게 피해를 끼치게 하는 일은 절대 없었습니다. $$$$$$$$$$$$$$$$$이번 봄에도 계약기간이 끝났지만 전화가 오시는 구두가게 사장님이 있었고, 작년 겨울에는 적극적으로 토론동아리 활동에 참여해준 것에 대한 감사의편지를 보낸 후배가 있었습니다. $$$$$$$$$$$$$$$$$끝까지 맡은 업무를 다하고 남들이 꺼려하는 일을 개의치 않고 묵묵히 했습니다. 그러자 자연스레 주변사람들의 신뢰의 얻었고 이것은 저의 큰 자산으로 남았습니다. "사실 사회人이라면 책임있는 자세로 신뢰를 얻는 것은 당연할 것입니다" 그러나 너무나 당연하기에 다시 한번 되새기고 싶었습니다. $$$$$$$$$$$$$$$$$특히나, 신뢰의 가치는 넥슨네트웍스 게임서비스 직무에서 큰 빛을 발휘할 것이라고 생각합니다. 고객과의 커뮤니케이션이 끊임없이 이루어져야 하는 업무의 특성상 1순위로 갖추어야 할 덕목이기 때문입니다. $$$$$$$$$$$$$$$$$[ 경험 : "관찰력"을 키운 백화점 판매직 ] $$$$$$$$$$$$$$$$$백화점에서 6개월동안 구두 Sales 단기아르바이트를 하였습니다. 게임업과 유통업은 다르지만 그속에는 고객이라는 공통분모가 존재합니다. 단순히 판매하는 것을 넘어서 고객의 동선과 시즌특수에 따른 판매수요를 예측하고 관찰해보았습니다. $$$$$$$$$$$$$$$$$그에 맞추어 제품 DP도 재배치해보며 고객의 편의를 최대한 돕고자 노력했습니다. 이는 고객의 발걸음을 한번이라도 더 붙잡게 만들었다고 자신합니다. 사후적으로 돕는 것이 아니라 실시간으로 세일즈에 최선을 다했던 것처럼 , 넥슨네트웍스에서도 부지런한 관찰人이 되겠습니다. $$$$$$$$$$$$$$$$$관찰력을 통해서 시즌이 바뀌는 것에 대한 수요를 미리 준비했고, 실시간으로도 고객의 동선파악을 통해 매출을 올리고자 노력했습니다. 운영팀에서도 하나의 게임을 맡게 된다면, 이벤트나 새롭게 출시하는 게임의 런칭에 대한 사전준비 부분, 실시간으로 터지는 이슈에 대해 빠른 리포팅을 통해 문제를 최대한 빨리 해결할 수 있다고 생각합니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%[ 특기 : 문제분석 -≫ 대안제시-≫ 환원으로 이어지는 해결적사고와 숫자적 감각 ] %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%행정학 전공이 게임서비스 직무에 어떤 점이 도움이 될까를 고민해보았습니다. 전공특성상 Issue가 되는 사회현상들을 최대한 중립적인 입장에서 해결해야 하는 과제들을 수행했었습니다. 한 가지의 문제에 꼬리에 꼬리가 물리는 이해관계자들을 보면서 사소한 사안이라도 큰 시야로 바라보는 안목을 키웠습니다. $$$$$$$$$$$$$$$$$또한 통계학 강의를 들으면서 직접 필드에 나가 서베이도 해보고 SPSS프로그램을 통한 DATA검증으로 객관적인 수치를 산출해보았습니다. 그리고 기본OA프로그램과 회계관련 자격증들을 취득하여 숫자적 감각도 함양했습니다. 0 @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@[ 마인드 , 소통. 꼼곰함 게임서비스 직무를 위한 3박자를 갖추었습니다 ] $$$$$$$$$$$$$$$$$다수의 아르바이트와 대외활동을 하면서 남녀노소의 사람들을 대하면서 발생하는 "각 계층의 문제들과 요구사항"을 많이 접하였습니다. 그럴때마다 역량내에서 최선을 다해 도우면서 서비스직무의 기본Mind를 키웠습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%또한 블로그를 운영하면서 "oooooo페스티벌 . ooooo시 SNS홍보단"에 참가하였고, 그 기간동안 상대방이 필요한 정보와 문의사항들에 피드백을 하는 소통창구 역할을 했습니다. $$$$$$$$$$$$$$$$$마지막으로는 매사에 꼼꼼하고 신중한 자세입니다. 현재는 회계법인에서 채권실사업무 아르바이트를 하고 있는데 언제나 변수가 생겨 상황마다 달리 접근해야 할때가 있습니다. 그럴때마다 A4용지에 변경사항을 메모해둔 후 집에와서 워드작업으로 기존의 파일을 수정합니다. 다음 업무에는 그것을 보면서 헷갈리지 않고 빨리 숙달하기 위함입니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%이러한 저의 삼박자가 잘 맞물려 넥슨네트웍스의 게임서비스 직무를 해낼 수 있다고 판단했습니다. $$$$$$$$$$$$$$$$$[ 모든 유저들의 마음을 대변하고 싶습니다 ] -1차적 목표 %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%IT기술이 발달하면서 기존의 온라인게임에서 모바일게임으로 트렌드가 옮겨가면서 게임유저들의 `일회성 소비성향이 짙어지고 있습니다. 그만큼 철새들이 많이 늘어나고 침묵하는 다수가 많이 생겨 나는 것 같습니다. 이메일과 커뮤니티게시판을 통해 불만사항을 요구하는 고객은 해결을 해주면 됩니다. $$$$$$$$$$$$$$$$$하지만 말도 없이 게임을 등져버리는 빙산의 일각 아래에 있는 대다수의 유저들이 더 무섭습니다. 잠수이별로 헤어진 커플은 서로 이유도 모르기 때문에 무엇을 고쳐야 하는지도 모르기 때문입니다. 앞으로 입사하게 된다면 비단, 수면 위로 떠오른 문제와 함께 앞으로 예상되는 위협요소도 관리하는 다재다능한 인재가 되겠습니다. $$$$$$$$$$$$$$$$$[ 더 나은 CRM과 게임시스템 개선을 위해서 ] -2차적 목표%%%%%%%%%%%%%%% %%%%%%%%%%%%%%%업무에 어느정도 적응 한후에 전문가로 성장하기 위한 추가적으로 자기계발을 꾸준히 하고 싶습니다. 페이스북에 보면 LG마케팅팀이나 부산경찰서의 홍보활동 들이 FUN한 요소들이 섞여 재생산되고 퍼트려지면서 소비자들에게 친근하게 다가가고 있습니다. $$$$$$$$$$$$$$$$$이는 홍보효과도 높이고 브랜드 긍정적인 이미지도 함께 가져옵니다. 게임산업 또한 주요Target이 10~30대의 젊은층이 많은만큼 IT공간에서 이루어지는 활동들이 많습니다. 앞으로 점점 더 "즉흥적"이고 "스웨그스러워질" 그들의 입맞에 맞는 고객관리도 연구해 나가고 싶습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%[ K - GAME 의 서비스 전문가 ] - 3차적목표 $$$$$$$$$$$$$$$$$마지막은 K-GAME 의 서비스 전문가가 되는 것이 최종목표입니다. 철 없던 고등학교 시절 , 카드라이더에 빠져 독서실 비용으로 PC방에가 대회준비를 했던 기억이 있습니다. 그때는 단순히 즐거움만을 쫓았다면 지금은 게임산업이 가지는 고부가가치를 아는 청년으로 성장했습니다. 0$$$$$$$$$$$$$$$$$IT강국에 걸맞게 다른 그 어떤 분야보다 게임은 미래를 주도할 유력산업이며 그 속에 넥슨의 게임들은 언제나 리더임을 확신합니다. 20년 뒤 세계를 주도할 K-GAME의 서비스 부문을 종합적으로 컨트롤할 수 있는 스페셜리스트로 성장해 자아실현을 이룰 것입니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@[ 행동으로 보여주고(선조치) -≫ 상대설득하기(후보고) ] $$$$$$$$$$$$$$$$$조선education 입시설명회 보조무를 맡은 적이 있습니다. 입시열기가 뜨거운 만큼 학부모들의 열의 또한 못지 않았습니다. 어느 날 , 한 어머니께서 갑자기 화를 내시면서 자신이 필기했던 노트와 필기구들이 강당의 접이식의자 사이에 빠져 꺼내질 못하니 당장 꺼내달라고 하셨습니다. 왜 갑자기 화를내셨나 살펴보니 여자직원 한명이 그것은 고객의 실수라서 어쩔수없다고만 대응했던것 이였습니다. $$$$$$$$$$$$$$$$$화가 난 고객께서 갑자기 저에게 오시더니 당신이 책임자냐면서 몰아붙이셨습니다. 단순 서브의 신분이었지만 학부모님의 마음을 풀어드리기 위해 행동을 취해야 할 것 같았습니다. 직접 의자 틈에 손을 넣어도 보고 엎드려 꺼내보려고 했지만 여의치 않았습니다. $$$$$$$$$$$$$$$$$그래서 강당 홀의 시설관리팀 전화번호를 알아내 연락을 취해보겠다고 하였고, 1시간 정도 후에 시설관리자가 온다고 전해드렸습니다. 한 시간 후 시설담당자가 도착했고 뒷문개방을 통해 무사히 용품들을 돌려드릴 수 있었습니다. $$$$$$$$$$$$$$$$$그 후에 "시설관리는 우리 소관이 아니라 부득이하게 불편을 끼쳐드려서 죄송하다고" 하며 설득했습니다. 말로만 응대하는 것이 아니라 직접 행동하려는 노력을 보여준 것이 학부모님의 마음을 풀어주는 데 성공할 수 있었던 요인이었습니다. $$$$$$$$$$$$$$$$$[ 2PM 친구와 밥먹기? ] $$$$$$$$$$$$$$$$$상대방의 마음을 헤아려 필요한 도움이 무엇일까? 먼저 한발 다가가 보는 좋은 경험을 한 적이 있습니다. 지난 겨울 , 도서관에서 우연히 중학교 동창을 만났습니다. 이런저런 이야기를 나누다가 경찰공무원을 준비하는 것을 알았고 3번의 낙방을 해서 많이 힘들어했습니다. $$$$$$$$$$$$$$$$$그 친구는 1년6개월동안 카톡도 전혀 사용하지 않고 밥도 혼자 먹었다고 하길래 내일부터 같이 먹자고 했습니다. 그러자 외롭고 심심했는데 고맙다며 환히 웃었습니다. 그렇게 2개월이라는 겨울방학 동안 , 항상 오후 2시에 점심을 같이 먹으며 서로 의지할 수 있는 좋은 친구가 되었고, 친구는 금년 가을에 4수만에 합격해서 꼭 한턱쏘겠다는 카톡메시지가 왔습니다. $$$$$$$$$$$$$$$$$위의 2가지 경험을 통해서 요구하는 바를 정확히 파악하는 것과 고객을 가족처럼 대하는 따듯한 마음씨를 배웠고 넥슨네트웍스에서 적극 발휘하고자 합니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@[ 친구의 배신감 풀어주기 ] - 대화만이 살길이다 $$$$$$$$$$$$$$$$$중고등학교 때부터 함께한 5명의 막역한 친구들 모임이 있습니다. 20살때부터 술을 먹기 시작했고 A라는 친구는 술을 먹으면 정신을 잘 잃어버렸고 B라는 친구는 장난을 잘쳤습니다. $$$$$$$$$$$$$$$$$보통은 계산을 할 때되면 다같이 N분의1 을 했지만 어느 한 날에 , 술을 많이 먹게되었고 B라는 친구가 A친구의 지갑에서 "안낸적도 있지 않냐며" 만원을 더 뺐습니다. 그 후 며칠이 지났고 카톡방에서 갑자기 A친구가 나가버리고 대답이 없었습니다. $$$$$$$$$$$$$$$$$왜그런가 하니 C라는 친구가 사건의 전말을 말해주었고 그 사실을 본인에게 말해주지 않은것에 A가화가 난 것이었습니다. 저 역시 돈을 빼는 행위를 보면서도 , 그 사실을 바르게 전달하지 않고 으레 잘 넘어간 평소의 경우처럼 별 신경을 쓰지 않았습니다. $$$$$$$$$$$$$$$$$결국 B와 저는 왜 별걸도 아닌 것 가지고 사건을 크게 부풀려서 말하는 C에 불만을 품게되고, 감정이 격해진 A와도 빨리 해결을 하고싶었습니다. 카톡과 전화로는 제대로 된 상황설명과 진심을 전달못했기에 직접 만나고 각자의 이야기들을 얘기했습니다. 워낙 친한사이였기에 오히려 사과하기가 힘들었고 서로의 눈을 마주치는게 어색했지만 꼭 거쳐야 할 과정이라 판단했습니다. 좋은점 1$$$$$$$$$$$$$$$$$이후 1주일 지난 후 다시 모든 인원이 화해를 했고 지금은 그 일 이후로 오히려 각자의 특징을 더 알게되어 갈등이 일어나지 않았습니다. $$$$$$$$$$$$$$$$$극복방법은 1. 부딪히는것 2.대화입니다. 이번다툼도 서로의 마음을 왜 몰라줄까? 알아서 알아주겠지 하고 부딪힘이 없었다면 여름여행을 계획하고 있는 지금의 모임이 없을지도 모릅니다. 학창시절 조별과제를 하면서도 발표는 안하고 자료조사만을 맡으려는 인원때문에 흔히 갈등이 일어나게 되는데 , 이때 팀의 성공을 위해선 불편함을 감수하고서라도 부딪히고 대화하는 것입니다.$$$$$$$$$$$$$$$$$말은 쉽지만 누구나 꺼리고 하기 싫어하기 때문에 그만큼 갈등도 많은 것이라 생각합니다. 앞으로 멀리숨어서 기계적인 업무처리를 하지 않고 무조건 부딪히고 살을 맞댈 줄 아는 인간적인 게임서비스 관리자가 되고싶습니다.좋은점 2 @@@@@@@@@@@@@@@ ']
a4 = ['@@@@@@@@@@@@@@@%%%%%%%%%%%%%%%2학년 때까지는 학점 위주로 공부를 했었습니다. 솔직히 그때까지는 깊이 취업에 대한 생각을 하지 않았던 것 같습니다. 3학년이 되어도 정말 불안하고 아무 스펙도 없는 저 자신이 한심하고 무기력하게 느껴졌었습니다. 그래서 목표를 딱하나 정하는 게 시급하여 여러 기업을 조사한 뒤 입사를 꿈꾸게 됐습니다. 그중에서도 제가 친절함을 느꼈었던 신한은행을 목표로 하였고 어느 정도의 스펙을 맞추려 공부를 하였습니다. $$$$$$$$$$$$$$$$$학과 학생회를 하여 리더쉽과 협동심, 그리고 책임감을 배우려 하였습니다. 또 온라인 서포터즈를 통해 스펙관련 Q&A를 하여 OO대학교 뿐만 아니라 여러 학교의 취업준비생들과의 대화를 하여 취업에 대해 알아가고 있었습니다. $$$$$$$$$$$$$$$$$자격증도 두달여간을 준비하여 펀드투자상담사와 파생상품투자상담사를 합격했습니다. 금융관련 자격증을 공부하다 보니 여러기업에 더욱 관심이 생기고 자신감이 붙었습니다. $$$$$$$$$$$$$$$$$가장 중요하게 생각한 것은 였습니다.$$$$$$$$$$$$$$$$$제가 토익이란 것을 대학에 들어와서 알게 되었습니다. 1학년 때 잠깐 학과 스터디를 통해 1주일에 2번씩 선배들에게 토익을 배웠습니다. $$$$$$$$$$$$$$$$$토익에 흥미를 느끼고 있었고 점수도 바닥에서 조금씩 오르고 열의에 가득 차 있었습니다. 그러다 입대를 하게 되 손을 놓고 2학년 때 다시 시작하려니 막막하였습니다. 그때는 이제 전역도 했고 취업에 대해 조금씩 알게 되었기 때문입니다. $$$$$$$$$$$$$$$$$그래서 동기와 같이 학교 동아리 TIME시사 연구회에 들어가 매일매일 TIME잡지 해석 및 발표도 하여 영어공부를 제대로 시작하리라 다짐했습니다. $$$$$$$$$$$$$$$$$그러나 동아리는 저에게 조금 벅찼고 따라가기 힘들었습니다. 혼자서 잡지 해석을 하기에는 너무 실력이 없었고 부담되고 점수도 큰 변화가 없었습니다. $$$$$$$$$$$$$$$$$그래도 뒤처지지 않기 위해 계속 공부해보려 노력했었습니다. 3학년 때 동기 학우들과 스터디를 통해 단어시험과 Part5.6을 1주일에 3번씩 모여 2시간씩 서로 알고 있는 문법과 노하우를 공유했습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%그때는 공부에 집중도 잘되고 점수도 올릴 수 있다는 확신이 들었습니다. 정기토익 점수가 올랐습니다. 그렇게 높은 점수는 아니지만 한 단계 나아갈 수 있을 것 같았습니다. $$$$$$$$$$$$$$$$$좋은결과를 얻진 못했지만 계속 점수가 오를 수 있다는 자신감을 가질 수 있었습니다. 4학년 때 취업준비에 앞서 취업스터디에 들어갔습니다. $$$$$$$$$$$$$$$$$학교 취업지원과에서 주최하는 것으로 전문가 선생님과 같이 각자 맡은 기업의 인재상 및 재무분석, 사업보고서를 통한 기업의 현실태를 조사했습니다. $$$$$$$$$$$$$$$$$뿐만 아니라 경제기사를 스크랩해서 분석하고 경제용어 공부도 하여 금융지식을 쌓았습니다. $$$$$$$$$$$$$$$$$이렇게 준비한 결과를 보듯이 저는 기업인이 되어 미래를 내다보고 준비하여 그에 맞게 기업을 이끌도록 하겠습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@%%%%%%%%%%%%%%%중학교 시절부터 사회교과목에 관심이 많았습니다. 지금 현재 일어나는 현상들과 미래에 더 발전될 모습들은 생각하니 과거에는 어땠을까? 하는 궁금증과 함께 역사를 알아보고 싶은 마음이 생겨 고등학교에 문과를 지원하여 수많은 사회과목들을 배우다 보니 경제에 특히 몰두하게 되었습니다. $$$$$$$$$$$$$$$$$대학 진학에 있어 경제학과를 택하게 되었고 대학생활을 함에 있어 딱 마음먹은 것이 있었습니다. 흔히들 말하는 “놀 때는 놀고 공부할 때는 딱 공부만 하자” 말을 새기며 1학년 때는 솔직히 많이 놀면서 1년을 보냈습니다. $$$$$$$$$$$$$$$$$군대를 갔다 와서 정신 차리고 공부하려고 마음먹었습니다. 복학을 해서 학점위주로 공부를 열심히 하다보니 성적도 잘 나오고 국가장학금제도가 생겨 장학금을 4학년까지 거의 전액을 받았었습니다. $$$$$$$$$$$$$$$$$그리고 2학년이 되어 넉넉하지 않은 집안 형편을 생각해서 부모님에게 용돈을 받지 않으려고 근로장학생을 매학기 신청하여 거의 2년간제 스스로 돈을 벌어 학교생활을 했었습니다. $$$$$$$$$$$$$$$$$꾸준히 노력하는 으로 저는 2년간 를 하였습니다. 입사 후 저의 자신있는 모습과 부모님에게 효도를 할 수 있는 기회를 갖고 싶습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@%%%%%%%%%%%%%%%모든 일을 되도록 긍정적으로 받아들이고 마음의 여유를 가지고 생활하려 합니다. 하지만 가끔은 마음의 여유를 갖는다는 것이 지나쳐 게으름으로 이어지기도 했습니다. $$$$$$$$$$$$$$$$$그러나 이제 저는 학생이 아닌 사회인의 신분으로 새로운 시작을 위한 출발점에 서 있습니다. 더 이상 게으름을 피우기보다는 마음의 여유를 가지되 몸소 실천하는 사람이 되고자 합니다. $$$$$$$$$$$$$$$$$그리고 저는 사교적이고 원만한 대인관계를 유지하며 모든 사람들에게 잘 대하고 잘 보이려고 하는 경향이 있습니다. 다만 모든 사람에게 쓴 소리를 못하고 화를 내지 못합니다. $$$$$$$$$$$$$$$$$이런 점은 스트레스만 쌓이고 저에게 불리해서 고치려고 하고 있습니다. 대신 이러한 인맥으로 다른 사람들에게도 친절하고 따뜻하게 다가가 좋은 관계를 보이도록 하겠습니다. $$$$$$$$$$$$$$$$$기업의 고객을 대할때는 진심을 담아 성심성의껏 모시도록 하겠습니다.$$$$$$$$$$$$$$$$$%%%%%%%%%%%%%%%삶에 있어 교만한 것은 자기 자신 안에 갇혀 있어 빛을 보지 못한다고 생각합니다. 겸손한 태도로 한발 한발 나아가면 반드시 스스로에게 득이 생긴다고 믿습니다. $$$$$$$$$$$$$$$$$너무 나서지 않고 또 너무 주눅들지 않고 적당하게, 그리고 고객을 마음을 사로 잡을수 있도록 겸손하고 따뜻한 자세로 고객을 최우선순위로 두고 먼저 생각하도록 하겠습니다. $$$$$$$$$$$$$$$$$이러한 태도로 고객에게 항상 친절하고 따뜻한 모습을 보이도록 하겠습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@%%%%%%%%%%%%%%%작년일이었습니다. 후배의 갑작스러운 연락이 왔는데 할 말이 있다며 저를 부르는 것이었습니다. 그 당시가 시험기간이었는데 시험족보와 또 잘 모르는 게 있다며 가르쳐 달라고 했습니다. $$$$$$$$$$$$$$$$$처음엔 후배여서 챙겨주고 싶은 마음에 제가 아는 대로 다 가르쳐 줬습니다. 그리고 고맙다며 같이 밥도 먹었는데 그 뒤로는 연락이 오질 않았습니다. $$$$$$$$$$$$$$$$$그러려니 하다가 기말고사 때 연락이 오고 가르쳐 주고 나니 다시 연락이 오지 않았습니다. 2학기가 되어 중간고사 때 다시 연락이 와서 참다참다 결국 화를 냈습니다. $$$$$$$$$$$$$$$$$후배가 죄송하다고 그랬지만 변명을 계속하였습니다. 그때는 너무 괘씸하고 이기적이라는 생각이 너무 박혀있어서 얘기조차 하고 싶지 않았습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%그 뒤로 연락이 오질 않다가 후배한테 화를 낸 것이 미안해 먼저 연락해서 대화를 하고 사과를 했습니다. 그 후배는 오히려 자기가 죄송하고 또 고맙다고 해주었습니다. $$$$$$$$$$$$$$$$$그 후에는 친해져서 자주 연락하는 사이가 되고 가끔 술도 마시는 절친한 사이가 되었습니다.$$$$$$$$$$$$$$$$$처음부터 제가 말을 했었더라면 그런 후회도 드는데 갈등은 서로의 불만사항을 이야기하면 풀린다고 생각합니다. 마음에 담아두지 않고 솔직하게 대화하는 것이 중요하다고 생각합니다. $$$$$$$$$$$$$$$$$이런 선후배나 동기간의 갈등이 생길 수 있기에 저는 [고객과의 커뮤니케이션]을 통해 불만사항을 최소화하고 [고객의 말에 진심으로 귀 기울여 신뢰감을 형성]하겠습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@%%%%%%%%%%%%%%%대학생활을 하면서 잘했다고 생각하는 경험이 두가지가 있습니다.$$$$$$$$$$$$$$$$$첫째, 라는 학교 내 동아리에서 영어 및 토익공부를 한 것입니다.$$$$$$$$$$$$$$$$$전역하고 나서 처음으로 영어공부를 시작한 계기가 되었습니다. 이 동아리를 통해 저보다 훨씬 영어에 능통하고 잘하는 사람이 많았습니다. $$$$$$$$$$$$$$$$$1년간 하면서 ‘이 친구들과 계속 하다보면 영어를 잘할 수 있겠지’라는 생각을 하였습니다. 그런데 늘지 않는 실력을 보며 제 자신의 나태함, 게으름을 알게 되었습니다. $$$$$$$$$$$$$$$$$스스로 공부하여 노력하여도 실력이 늘까말까한데 저는 동아리만 믿고 제 스스로 노력을 하지 않았던 것입니다. $$$$$$$$$$$$$$$$$그나마 다행이라 할만한 것은 ‘이대로는 안되겠다’며 스스로를 돌아보게 되고 제 자신이 최선을 다해 좋은 결과를 얻도록 하겠습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%둘째, 인터넷 카페 활동을 통해 취업정보를 공유하고 서로의 고민거리를 상담해주는 서포터즈를 하였습니다. $$$$$$$$$$$$$$$$$이 서포터즈는 2달여간 활동을 하는데 활동내역은 게시글과 댓글을 남겨 취준생들을 도와주는 것입니다.이 활동을 통해 저도 정보를 얻고 제가 아는 정보를 상대방에게도 최대한 상세히 알려주는 것입니다. $$$$$$$$$$$$$$$$$제가 직접 기업사이트에 들어가서 자격증여부, 스펙, 기업정보를 알아보는 등 적극적인 활동을 하였습니다. %%%%%%%%%%%%%%% %%%%%%%%%%%%%%%마침 서포터즈활동 2달 후 수료증을 받은 이후에 활동이 뜸해졌습니다. 그러다 채용공고가 뜨고 다들 바쁘게 준비하는 가운데서 저는 뒤늦게 알아낸 경우가 많았습니다. $$$$$$$$$$$$$$$$$그때마다 후회하고 스스로 안타까웠습니다. 더 적극적으로 알아보고 미리 준비하는 자세를 길러 후회하지 않도록 대비할 것입니다. @@@@@@@@@@@@@@@ ']
a5 = ['@@@@@@@@@@@@@@@저는 해외 각지를 돌아다니며 일을 할 수 있는 건설사 취업을 목표로 하고 있습니다. 그 중에서도 현대건설은 택한 이유는 끝없는 도전정신과 성과에 대해서 공정한 보상을 한다는 것이 매력적이기 때문입니다. 입사한다면 직접 해외를 돌아다니며 현장의 경험을 쌓고 싶습니다. $$$$$$$$$$$$$$$$$그리고 도면과 현장여건을 같이 체크하며 공부를 하고 싶습니다. 그리고 보다 큰 그림을 그리며 설계를 하고 싶습니다. 직접 현장경험이 있다면 설계업무를 맡을 때 이득이 있을 것이라 생각합니다.$$$$$$$$$$$$$$$$$다른 부서도 마찬가지겠지만 이런 현장업무는 협동심이 없으면 안 된다고 생각합니다. 따라서 자기주장보다는 타인의 의견을 들을 줄 아는 능력이 더 필요하다고 생각합니다. 이런 능력은 실제로 다른 사람들과 같이 작업을 하면서 기를 수 있다고 생각하며 밑에서 서술할 공모전 경험을 통하여 이런 소양을 쌓을 수 있었습니다. 이 공모전을 통해 협동심과 열정적이고 자기주도적인 자세를 키웠습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@환경이나 생활이 힘들다면 이를 극복하기 위해선 그 안에서 즐거움을 찾아야 한다고 생각합니다. 전 예전 비행기 수화물을 내리는 곳에서 아르바이트를 한 적이 있습니다. 비행기가 내리면 그 안의 손님들의 짐과 각종 쓰레기 음식물들을 옮기는 일이었습니다. 육체적으로 굉장히 힘든 일이라 원래 근무하던 직원들도 3일 근무 1일 휴식이 기본이었습니다. $$$$$$$$$$$$$$$$$그 곳에서 계속 일만하다가는 제풀에 지쳐 일을 그만둘 것 같아서 다른 방안을 찾아보고자 하였습니다. 따라서 소장님께 건의하여 근무시간에 음악을 들을 수 있게 하고 잠깐씩 쉬는 시간을 지정하여 흡연을 할 수 있게 하였습니다. $$$$$$$$$$$$$$$$$그 결과 전 개강 전까지 아르바이트를 꾸준히 할 수 있었고 등록금에도 적지 않은 보탬이 되었습니다. 해외에 나가서도 예상치 못한 어려움이 있을 수 있고 또 힘들어서 주저앉고 싶어질 수도 있을 것입니다. 하지만 그런 상황에서도 즐거움을 찾고 없으면 만들어서 일을 해나가겠습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@기계공학 부분에서 중요한 것은 모델의 구조적 해석이라고 생각합니다. 이를 위하여 기구학이나 시스템동역학, 계측공학 과목을 통해 본드그래프와 매틀랩의 기본적인 사용법을 배웠습니다. 그리고 전산제도 과목을 통하여 간단한 모델링 방법과 CAD의 기초적인 사용방법등을 익혔습니다. 물론 실제로 회사에서 사용하는 프로그램과는 다르겠지만 기본적인 역량을 갖추고 최대한 빨리 프로그램을 배우는데 도움이 될 것이라 생각합니다. $$$$$$$$$$$$$$$$$그리고 전공에서 배운 실험실습을 통하여 설계에서만 끝나는 것이 아니라 실제로 레고를 조립하거나 모델을 분석을 해보는 일을 하였습니다. 회사라는 곳은 결국 조직이라고 생각합니다. 조직에서 중요한 것은 구성원과 얼마나 함께 잘 일 할 수 있는지와 조직을 사랑하는 마음이라고 생각합니다. 회사가 아무리 힘들고 어렵더라도 그 길을 함께 걷고 싶습니다. @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@현대건설은 설계부분을 현대엔지니어링으로 맡기는 것으로 알고 있습니다. 하지만 직접 현장에서 다양한 경험을 하고 보다 큰 그림을 그릴 줄 알며 설치 여건 등을 고려할 능력이 되는 사람이 설계를 맡는 다면 더 효율적으로 일을 할 수 있을 것 이라 생각합니다. $$$$$$$$$$$$$$$$$오로지 설계만 하던 사람들이 실제 현장의 설치 여건을 고려하지 못하고 설계를 한다면 업무 효율이 좋지 않을 것이라 생각합니다. 따라서 시공에서 일을 하다가 설계를 맡는 것도 나쁘지 않으며 이런 부분을 현대건설내부에서 해결할 수 있다면 더 나아질 수 있을 것이라 생각합니다. 굳이 현대엔지니어링에 다 의존하는 것보다 내부적으로도 일을 처리할 수 있는 부서가 있다면 업무효율을 더 개선할 수 있지 않을까 생각합니다.$$$$$$$$$$$$$$$$$하지만 자신이 노력하면 현장은 도면 및 현장여건을 크로스 체킹하면서 공부도 가능하고 현장은 설계업무 보다 중요한 다양한 경험을 접할 수 있기 때문에 나중에 큰 그림을 그리고 싶으시다면 시공에 몸을 담구는 것도 나쁘지는 않습니다 @@@@@@@@@@@@@@@ ', '@@@@@@@@@@@@@@@2011년에 전 도전정신을 키울 수 있는 경험을 하였습니다. 추억을 쌓을 수 있는 일이 없을까 고민하던 저희의 눈에 들어온 것은 간단한 공모전 이었습니다. 이 공모전에서 작게나마 가작을 받고나자 되든 안 되든 일단 열정을 가지고 무엇인가를 해봐야한다는 사실을 배웠습니다. 이 경험은 다른 공모전을 준비하고자 할 때 도움이 되어 2014년에 타 회사에서 진행한 자동차 에너지 효율 개선 공모전에 나갈 수 있는 발판이 되었습니다. 이번엔 제가 직접 공모전이 없나 나서서 찾아보고 교수님께 여쭤서 공모전을 찾아 준비할 수 있었습니다.$$$$$$$$$$$$$$$$$이 공모전에서 한 가지 주제만을 가지고도 여러 가지의 해결방법이 있다는 사실을 보면서 문제 해결을 위해선 한 분야만이 아니라 여러 분야에서 힘을 모아야 한다는 사실을 깨달았습니다. 그리고 실제로 제품을 만드는 것은 단지 프로그램으로 모델링하는 것과는 다르다는 것을 실감했습니다. 그래도 저희는 서로의 의견을 들으며 협업하여 저번보다 좋은 결과인 우수상을 얻었습니다. @@@@@@@@@@@@@@@ ']

change = [a1, a2, a3, a4, a5]

# 수작업한 내용으로 바꾸기
for i, c in zip(longbrackets, change):
    new_contents3[i] = c
    
# 괄호 제거
p = re.compile("\([^\)]*\)")
brackets = []

for i, contents in enumerate(new_contents3):
    for j, content in enumerate(contents):
        new_contents3[i][j] = p.sub('', content)
        
for cs in new_contents3:
    for c in cs:
        brackets.extend(p.findall(c))
        
print(len(brackets))
brackets = list(set(brackets))
print(len(brackets))
brackets
# Out:
# https://www.jobkorea.co.kr/starter/PassAssay/View/193572?Page=120&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# (고객 구매특성에 따른 상품별 진열방식 변경, 피크타임 분석을 통한 FILL-UP 시스템 도입, 판매사 일일 근무스케줄을 통한 낭비과업 제거@@@@@@@@@@@@@@@성과: 재고일수 50% 감소 및 일매출 30% 성장@@@@@@@@@@@@@@@3)
#
# https://www.jobkorea.co.kr/starter/PassAssay/View/167581?Page=170&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# (oooooo에서 근무하며 동향보고서와 테스트케이스 등을 작성하면서 엑셀과 워드를 많이 사용해보았고 사무보조아르바이트는 수출행사 대행사의 실적집계요원과 회계사무소에서 주택담보대출심사 보조를 함 )
#
# https://www.jobkorea.co.kr/starter/PassAssay/View/166673?Page=194&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# ((=≫관찰력을 통해서 시즌이 바뀌는 것에 대한 수요를 미리 준비했고, 실시간으로도 고객의 동선파악을 통해 매출을 올리고자 노력했습니다. 운영팀에서도 하나의 게임을 맡게 된다면, 이벤트나 새롭게 출시하는 게임의 런칭에 대한 사전준비 부분, 실시간으로 터지는 이슈에 대해 빠른 리포팅을 통해 문제를 최대한 빨리 해결할 수 있다고 생각합니다.)
#
# https://www.jobkorea.co.kr/starter/PassAssay/View/146665?Page=238&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# (2학년 때까지는 학점 위주로 공부를 했었습니다. 솔직히 그때까지는 깊이 취업에 대한 생각을 하지 않았던 것 같습니다. 3학년이 되어도 정말 불안하고 아무 스펙도 없는 저 자신이 한심하고 무기력하게 느껴졌었습니다. 그래서 목표를 딱하나 정하는 게 시급하여 여러 기업을 조사한 뒤 입사를 꿈꾸게 됐습니다. 그중에서도 제가 친절함을 느꼈었던 신한은행을 목표로 하였고 어느 정도의 스펙을 맞추려 공부를 하였습니다.)
#
# https://www.jobkorea.co.kr/starter/PassAssay/View/145003?Page=283&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# (설계만 하게되면 그림쟁이만 될 수 도있습니다.. @@@@@@@@@@@@@@@예를들어 자기가 설계한 설비의 규모도 모른체 설계하는 경우, 설치가 여건을 고려하지않은 도면이 아닌 그림을 그리는 등...)
#
# https://www.jobkorea.co.kr/starter/PassAssay/View/145003?Page=283&OrderBy=0&FavorCo_Stat=0&Pass_An_Stat=0
# (설계쪽에 몸을 담게 되다보면 이후 현장업무에 적응을 못하는 경우도 많이 있습니다, 프로젝트에서 설계가 중요한 포션이고 초속에 잘 다져둬야되는건 맞지만, 여러 과정중 한단계일 뿐입니다, 다양한 경험을 할수가 없을 수도 있습니다)
#
# 0
# 0
# []

# %%
new_contents3[:5]
# Out:
# [['새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 도전이라 부족한 영어 실력으로 많은 어려움에 부딪쳤습니다. 잠깐 좌절도 했지만 그보다 가장 힘들었던 것은 부모님이 주신 소중한 기회를 제대로 활용하고 있지 못하고 있는 저의 모습이었습니다. 저는 좌절보다는 노력을 택하였습니다. 매주 영어 학원과 스터디그룹에 참석하였으며 다양한 이들과의 대화를 위해 혼자 펍에 가 친구를 사귀기도 하고 아르바이트를 통해 많은 이들과의 소통으로 영어 실력뿐만 아니라 소통력과 관계력까지도 키울 수 있었습니다. 이러한 경험을 바탕으로 경동나비엔의 일원이 되어서도 어떠한 어려움 속에서도 좌절하지 않고 백절불굴의 자세로 부족한 점을 계속해서 연구하고 개선하여 끊임없는 변화 속에서 끊임없는 노력으로 성공이라는 꽃을 피우도록 하겠습니다. ',
#   '코카콜라의 뉴코크 실패는 소비자는 단순히 제품만을 소비하는 것이 아니라 그 브랜드 즉, 제품의 상징성을 구매하는 심리를 보여주고 있습니다. 해외시장에 존재하는 고객은 국내시장에 존재하는 고객들보다 기업에 대한 적은 정보를 가지고 있으며 시장진출에 있어 문화, 언어적인 부분을 넘어 다양한 것들을 고려하고 새롭게 시작하여야 합니다. 하지만 이 또한 기회가 될 수 있습니다 해외시장의 경쟁자들이 보여주지 않았던 부분을 통해 시장을 공략한다면 그 부분이 기업의 상징처럼 되어 하나의 문화, 브랜드가 되어 소비자가 소비하는 이유가 될 수 있습니다. 따라서 제품 구매 후에도 빠르고 다양한 서비스를 제공하는 확실한 사후서비스를 더 강화하고 강조한 전략을 통해 해외시장을 공략하고 애프터 서비스 하면 경동나비엔이 제일 먼저 해외시장의 사람들의 뇌리에 떠오를 수 있게 상징화시킬 수 있다면 해외시장 점유율을 꾸준히 높여갈 수 있을 것입니다. '],
#  ['4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어학과 함께 소프트웨어공학 및 기계공학과의 졸업작품에도 각 1년간 참여했습니다. 조직응용기사 취득 및 2개 기사 1차 합격, 개인 서버 운영, 전자공학과 학부연구생과 지능형 자동차 경진대회 출전 등의 경험도 있습니다만, 자수 제한으로 인해 졸업작품 경험에 관해 기술하겠습니다. ',
#   '정보통신공학에서는 온라인 자동 동기화 시스템을 제작했는데, 하드웨어 설계 및 제작, 펌웨어 프로그래밍을 맡았습니다.@@@@@@@@@@@@@@@SW학 작품에서는 애플 iOS 앱을 2개 만들었고, 아이디어 회의부터 Swift와 Objective C언어로 프로그래밍, UI 제작, 문서작업, PPT 제작 등을 했습니다.@@@@@@@@@@@@@@@기계공학과 작품은 깡통크기의 초소형 위성 쏜 뒤 지상 복귀 중 위성의 자세를 제어하고 통신하는 것 이었습니다. 여기서 전자부품 선정과 C언어 프로그래밍 에 참여했습니다. 영어학과 응용탐구 에서는 영어 Resume와 Cover letter, SOP  등을 작성하는 연습을 했고, 매주 모여 연습한 것과 각자의 취업준비 과정을 발표하여 공유했습니다. ',
#   '정보통신공학과 기계공학의 경우 제가 매우 선호하고, 경험이 많은 C언어와 펌웨어 프로그래밍을 맡았기 때문에 기본기를 다질 수 있었습니다. 제가 잘 모르는 타 전공의 기초지식들을 제가 잘 아는 HW지식과 접목시키는 것은 정말 흥미로웠습니다. 또한, 소프트웨어학과 졸업작품은 SW에 대한 색다른 경험을 맛보게 해주어 제가 전자공학과에서 정보통신공학과로 전과하는 계기가 되었습니다. 또한 다양한 전공의 여러 사람들과 정보를 교환하고 소통하며 협업하는 법을 배웠고, 제가 배우고 있던 전자공학에 국한된 시야에서 벗어나 다양한 방면에서 세상을 바라보는 법을 배웠습니다. ',
#   '2019년 초부터 사회복무요원으로 20개월간 지역아동센터에서 복무했습니다. 사회복무요원은 주로 아동보육, 교육지도 , 사무업무와 시설물 관리 의 업무를 맡았습니다. 사무업무 중 엑셀을 쓰는 업무가 많았는데, 대부분 어렵지 않으나 시간이 매우 오래 걸리는 작업이었습니다. 이를 엑셀로 자동화 하였습니다. ',
#   '작업 대부분을 함수와 매크로로 대체했습니다. 쉬운 수정을 위해 변수들을 보기 좋게 배치했고, 사용법과 수정법을 담은 안내서를 함께 제작했습니다. 프로그래밍과 비슷해 즐겁게 작업했지만, 작업량이 많았고 아동센터 특성상 한 업무에 집중하기 어려워 이를 마치는 데에 2주가 걸렸습니다.@@@@@@@@@@@@@@@센터는 이미 인력 부족을 겪고 있었고, 제 전역 이후 새 요원 배치 예정이 없었습니다. 특별히 지시받지 않았고, 추가로 해야 하는 업무라 고민했습니다. 그러나 복지사들의 업무 감축은 근로자및 아동과 그들의 가족에게까지 영향을 준다고 생각해 진행했습니다. ',
#   '그 결과 매월, 요원 두 명이 16시간가량 하던 작업을 한 명이 1시간 이내에 끝낼 수 있는 양식이 완성됐습니다. 덕분에 종사자들은 좀 더 아동을 돌보는 데 시간을 할애할 수 있게 되었고, 저의 소집해제 후에도 업무를 떠안은 부담이 적어졌다고 사회복지사분들이 말씀하십니다. 저 역시 엑셀을 적극적으로 활용해볼 수 있는 계기가 되었습니다. ',
#   '재학 중, 조별 과제로 여러 기능을 가진 Java 프로그램 개발한 적이 있습니다. 프로젝트 규모와 문서작업 비중이 컸기에, 품질 향상과 문서작업 병행이 가능한 폭포수 모델의 소프트웨어 개발 프로세스를 따르자고 제시하였습니다. 하지만 실제 개발 중 진행은 더뎠고, 프로젝트 모듈화가 계획대로 되지 않아 기능들이 정상 작동하지 않았습니다. ',
#   '나이 차가 많이 나는 저학년생과 함께 팀을 꾸렸고, 자연스레 팀장을 맡게 됐습니다. 더딘 프로젝트 진행은 그대로 갈 경우 문제가 있을 것으로 판단하였습니다. 그래서 개발 중반쯤 상의를 하여 프로세스 미준수와 더딘 문서화의 이유에 대해 물었습니다. 대답을 들어 보니 팀원은 저학년이라 개발 경험이 부족했고, 개발 프로세스에 대해 배우지 않아 이해도가 낮았으나 나이 차이의 압박과 부족한 시간에 쫓겨 따라오기 바빴던 것입니다. 팀원의 이야기를 듣고 나서 저는 팀원의 처지를 이해할 수 있었습니다. 팀원이 이해할 수 있게끔 프로세스를 설명하고, 어려운 부분을 제가 맡아 진행했습니다. 번거롭더라도 개발 중 진행 상황과 문제점을 종종 물어봤고, 팀원이 막혀서 혼자 고민하던 문제들은 같이 해결하며 업무를 도왔습니다. ',
#   '기한 내에 구현과 문서작업까지 모두 마쳤고, 프로젝트 점수 만점이라는 좋은 결과를 내었습니다. 또한, 팀장으로서 인력 관리 기법을 얻었습니다. 처음엔 팀원이 비협조적이라 생각하고 비판적 태도를 취했으나, 섣불리 판단치 않고 소통으로 해결했습니다. 앞으로 불통이나 오해가 생겼을 때 대화가 필요하며 상대방의 처지에서 공감할 수 있어야겠음을 느꼈습니다. ',
#   '전산시스템을 이루는 HW, SW, 통신 세가지 분야를 모두 아우르는, 전문성을 가지면서도 융합적 사고가 가능한 엔지니어를 목표로 삼아 재학중 다양한 경험을 했습니다. 이 중, 쌓을 수 있는 SW 지식이 제한적인 전자공학과에서 정보통신공학과로 전과를 결심했습니다. 당시 유일하게 전과가 가능했고, 소프트웨어 관련 과목이 많이 있었기 때문입니다. ',
#   '전과 당시 이미 고학년이었기 때문에 졸업이 더 늦어지는 것을 막아야 했고, 과목별 학점도 좋게 받아야 했습니다. 하지만 들어야 할 과목은 많았고, 과목들의 특성은 모르는데다 일부 과목은 선행 기초 지식이 없어 학습해야 할 양은 기하급수적으로 늘었습니다.@@@@@@@@@@@@@@@이를 해결하기 위해 지피지기면 백전불태, 학과를 파악했습니다. 신중한 과목 선택을 위해 듣는 수업마다 무조건 반장에 지원했습니다. 수강생들과 친분을 쌓고 정보를 얻기에 좋았기 때문입니다. 수집 정보 기반으로 다음 과목의 요구 기초를 배워뒀습니다. 또한 수면 시간을 5시간으로 줄였고, 체력을 위해 운동을 병행했습니다. 그리고, 인적 자원의 수율을 끌어 올렸습니다. 프로젝트에서 팀장을 맡으면 SW 개발 프로세스와 HRM기법을 응용해 체계적으로 계획했습니다.@@@@@@@@@@@@@@@그 결과 계획대로 3학기 만에 졸업했고, HW와 SW 두 분야의 기본기를 다졌습니다. ',
#   '이러한 경험을 통해 융합적 사고가 주는 잠재력을 보았고, 배움을 멈추고 싶지 않습니다. 그래서 취직 후 전공과 심리학 박사, 언어학 석사 취득을 계획하고 있습니다. 저의 개인적 역량을 지속적으로 끌어올리고, 집단 안에서 그룹원의 시너지를 향상시켜 기업에 없어선 안될 인재가 되기 위해 노력할 것 입니다. ',
#   'SW학과 졸업작품 작업 중, 한 팀원이 대면 작업 중에 피곤하다며 종종 자곤 했습니다. 자는 팀원이 분위기를 저해해 협업에 방해가 된다며 다른 팀원이 화를 냈습니다. 다른 팀원도 평소에 불만을 느꼈기에 제지하지 않았고, 갈등은 고조되어갔습니다. 분쟁에 끼고 싶지 않았지만, 이대로는 팀원 모두가 손실을 떠안게 되리라 판단해 중재했습니다. ',
#   '일단, 감정을 가라앉힌 뒤 양측의 불만과 견해 차이를 정리했습니다. 결과 중심 팀원과 과정 중심 팀원들 간에 의견 차이를 확인하고, 근본적 원인을 찾아보았습니다. 객관적으로 보니 양측의 갈등은 성격 차이로 부터 시작되어 쌓여왔음을 알게 되었습니다. 서로 진행 방식이 틀린 것이 아닌 다른 것임을 알고 이해하자 팀 전체가 안정됐습니다. 각자 성향에 맞게 업무를 재배정하고, 서로의 다름을 비난하기보다 인정하고 배려하기를 당부했습니다. 처음엔 혼란스럽고 막막했지만, 문제점을 객관적인 시각에서 나열하고 토의했습니다. 그 결과로 갈등의 근본적 원인을 파악했으며 기초적 해결책을 얻을 수 있었습니다. ',
#   '상대방의 입장을 이해하고 배려하는 것 입니다. 대화의 불통과 오해는 근본적으로 상대의 처지를 잘못 이해할 때 생기기 시작합니다. 또한 상대를 배려하지 않는다면 일방적으로 행동하는 사람, 소위 말하는 “꼰대”가 되고 협동력이 떨어지는 사람이 될 것 입니다. '],
#  ['"끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일을 시작하기 전에 두려운 마음이 들 때마다 이러한 마음가짐을 갖추고 도전하였습니다. 교내에서 실시하는 경제 골든벨 대회에 참여했던 경험이 있습니다. 학교 시험이 끝난 후 담임 선생님께서는 이틀 뒤에 대회가 실시될 것이라며 자세한 일정에 대해서 공지해 주셨습니다. 문제 출제 범위는 70페이지에 달하는 경제 관련 용어들이었습니다. 공부해야 하는 양에 비해 대회 전까지 준비할 수 있는 기간이 짧게 느껴졌기 때문에 주변 친구들은 저에게 지금부터 시작해봤자 좋은 성적을 거두지 못할 것이라며 포기하기를 권유하였습니다. 하지만 전부터 기다렸던 대회였고 꼭 해내고 싶다는 생각이 들어 이틀이라는 기간 동안 시간이 날 때마다 보며 공부하였습니다. 잘 외워지지 않는 부분은 따로 암기 노트를 만들어 들고 다니면서 익숙해지도록 하였고 저만의 암기 매뉴얼을 만들어가며 공부하였습니다. @@@@@@@@@@@@@@@그 결과 대회에서 1위라는 성적을 거둬 최우수상을 수상할 수 있었습니다. 이 경험을 통해 모든 일에 포기하지 않고 노력하여 달성하는 방법에 대하여 배우게 되었습니다. 이러한 역량을 바탕으로 맡은 업무에 대해 끝까지 완수해내는 사원이 되겠습니다. ',
#   '저의 장점은 어떤 일이든 책임감을 가지고 수행해내는 것입니다. 고등학교 1학년 때 학습 부반장을 맡았던 경험이 있습니다. 당시 반의 수업 분위기가 좋지 않았고 이 점에 불만을 가진 친구들이 생기게 되었습니다. 그래서 저는 학습 분위기 개선이 필요하다는 생각이 들었습니다. 먼저 수업 시간에만 휴대폰을 걷자는 의견을 냈고 대부분이 찬성하여 실시하게 되었습니다. 매 수업 시간 전 반 친구들이 휴대폰을 낼 수 있도록 안내하고 안 낸 친구가 없도록 일일이 수를 세는 역할을 수행하였습니다. 또한 수업 내용을 이해하지 못한 친구들에게는 쉬는 시간과 방과 후 시간을 이용하여 설명해 주었습니다. 그 결과 반 학습 분위기도 좋아지고 학기 초 성적 최하위권 반에서 학기 말에는 1등 반으로 마무리할 수 있었습니다. @@@@@@@@@@@@@@@저의 단점은 많은 사람들 앞에서 말하는 것을 조금 두려워하는 것입니다. 이러한 성격 때문에 항상 준비한 만큼 결과를 보여주지 못하여 극복하고 싶었습니다. 그래서 학급 부반장이나 동아리 차장 등 임원 역할을 맡아 친구들 앞에서 말을 하는 연습을 하였고 수업 시간에도 나서서 발표하려고 노력하였습니다. 또한, 중요한 발표 전에는 실제 상황처럼 가정하여 리허설 연습을 하며 극복하고 있습니다. ',
#   '체육대회 때 반 대항전으로 실시하는 치어리딩에 참여하였습니다. 평소 춤추는 데에 자신이 없어 사람들 앞에서 추는 것을 꺼려 하였습니다. 그러다 보니 연습을 할 때 자연스럽게 동작이 작아졌고 친구들에 비해 진도도 뒤처지게 되었습니다. 치어리딩은 협동심이 중요시되기 때문에 저로 인해 팀 전체에 피해가 갈 수도 있는 상황이었습니다. 이러한 상황을 극복하기 위해 연습하는 모습을 녹화하여 다시 보며 스스로 피드백을 하고 주변 친구들에게도 보여주며 고칠 부분을 찾아나갔습니다. 동작 연습 후에는 가족들 앞에서 춤을 추며 극복해나갔습니다. 그 결과 저희 반은 치어리딩 부분에서 높은 점수를 받아 종합 1위를 할 수 있었고 반 친구들은 체육대회 MVP로 저를 뽑아주었습니다. @@@@@@@@@@@@@@@전산회계 운용사 2급 자격증 실기 시험에서 불합격했던 경험이 있습니다. 방과 후 수업에 참여하여 열심히 공부하였지만, 시험 당일 프로그램 오류로 인해 작성했던 답안지가 저장이 되지 않았습니다. 그 결과 다른 과목에서 높은 점수를 받았지만 한 과목에서 0점을 받아 합격하지 못하였습니다. 이 경험을 바탕으로 만일의 상황까지 예측하며 계획하는 습관을 가지게 되었고 다음 시험에 재도전하여 높은 점수로 합격할 수 있었습니다. '],
#  ['벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력@@@@@@@@@@@@@@@"보드전문 개발 벤처기업부터 제조 공장 자동화, 금융개발까지"@@@@@@@@@@@@@@@저는 어려서 배운 컴퓨터 강의를 동기로 OOOOOOOO OOOO학과를 지원하여, 컴퓨터에 대한 꿈을 키워 나갔습니다. 전공을 통해 컴퓨터의 역사를 다시 공부하면서 운영체제, 소프트웨어 공학, 알고리즘, 프로그래밍 언어론, 데이터베이스 시스템, 자료구조 등을 배웠습니다. 학부시절, 전공뿐 아니라 어학실력을 향상시키기 위해 영어어학원을 열심히 다니면서 영어 회화, 영작문 실력을 길렀습니다. 학부 4년에는 OOO 학생회의 OOOOO 차장으로서 자연대 행사와 축제를 기획하고, GMP 영어 동아리 회원으로 활동하였습니다. @@@@@@@@@@@@@@@학부 졸업후 OOOO에 입사해 하드웨어 관련 개발에서, 태그를 통해 출입통제를 관리하는 시스템을 개발하고, 임베디드 WinCE 운영체제를 개발하여 2000년 OOOO OOO 전시회에 참가하였습니다. 윈도우 컴팩트 에디션인 임베디드 WinCE의 윈도우 시스템에 전시회 관람 온 개발자들 사이에서 호응이 좋았습니다. 이후에 OOOOOO에 입사하여 화상채팅시스템 개발에 투입되어 근무하다가 대구로 이직을 하였습니다. 2000년 12월에 OOOOO시스템에 입사하여 OO 디스플레이 P4공장 TFT Shop 장비 CIM 표준화 개발 프로젝트에 투입되어 Stripper, Asher 장비의 표준화 업무를 하였습니다. 반도체 장비 표준 프로토콜로 장비 CIM과의 통신 개발 프로젝트에서 장비 Spec. 미팅, 대응사양서 작성, 테스트 시나리오 작성 등의 업무를 수행하여 LCD P4공장의 장비 셋업을 성공적으로 마쳤습니다. OOOOO에서는 프리랜서 계약으로 한단계 상위 시스템인 OO 디스플레이 P5 CF Shop 장비서버 개발 프로젝트에 투입되어 장비서버와 상위 CCS시스템의 메시지 전송 프로토콜을 개발하였습니다. 패턴 검사기, 높이 측정기, 두께 측정기 등 7종의 장비에 셋업을 마쳤습니다. P4 장비 CIM 표준화 프로젝트와 동일하게 장비 Spec. 미팅, 장비 벤더업체 미팅 및 의견조율, 대응사양서 작성, 테스트 시나리오 작성 등의 프로젝트 기본설계에서 개발단계, 테스팅 및 셋업완료까지 프로젝트에 참여하였습니다. 장비서버 FAB 테스팅 시에는 장비업체 엔지니어가 여자 엔지니어고 저 또한 여자 엔지니어라 주변에 여러 엔지니어가 관심을 보였습니다. OOOO에서는 제조 SCM 시스템 개발과 CF Shop의 P6 장비서버 프로젝트를 수행하였습니다. @@@@@@@@@@@@@@@제조 공장자동화 프로젝트를 그만두고 OOOOO의 OO은행 자금관리시스템 개발 프로젝트에 참여하여 금융업무 중 대금수납업무개발에 델파이와 MS-SQL을 이용하여 구현하였습니다. 다시 자동화 프로젝트로 OOO에서 OO실트론의 스토커 MCS 시스템 개발 프로젝트에서 시스템 개발에 투입되어 스토커 MCS 시스템, MM시뮬레이터, 테스팅 툴 등을 개발하였습니다. OOOOO에서는 OO전자의 MES 시스템의 UI 업데이트 프로젝트에 참여하여 각 장비단에서 온 데이터를 기반으로 웹리포팅하는 화면을 개발하였습니다. @@@@@@@@@@@@@@@저의 강점은 새로운 시스템 적응에 빠르고 창의적인 아이디어를 제안하고, DOS에서 윈도우98, 윈도우2000, 윈도우XP 등의 다양한 윈도우환경에서의 개발 경험과 개발언어로 델파이, 비주얼베이직, MS-SQL, 오라클, JAVA/JSP 등을 이용하였습니다. 구성원들과의 커뮤니케이션과 의견 조율 능력도 갖추었습니다. 개발자로서 테스팅에도 강합니다.@@@@@@@@@@@@@@@자동화 프로젝트를 잠시 그만 두었을 때에는 2003년 OO OO OOOOOO의 선수촌 영어 통역 자원 봉사자로서 활동하였습니다. 대회기간 동안 선수들과 자원봉사 친구들과 친하게 되는 기회가 되었고, 세계적인 국제대회의 영어 통역 자원봉사 활동을 할 수 있어 기뻤습니다. 2011년 부터 현재까지 경력이 단절되어 경력공백이 있으나 프로젝트 수행하는데 아무런 문제없이 설계업무든 Java/JSP/C#/비주얼베이직 등의 개발업무 모두 가능합니다. 현재 2020년 11월부터 OOOO에서 구비 실트론 원부자재 통합 품질관리 구축 프로젝트에 참여하고 있습니다. 개발환경은 .Net, MS Studio 2015 C#, Oracle 환경하에서 시스템을 구축하고 있고, 화면설계 및 개발을 담당하고 있습니다. 저의 경력과 경험이 귀사의 발전에 기여하는 바가 있고, 잠재적 가능성이 귀사에서 발휘할 수 있는 경력이 될 수 있도록 저의 능력을 최대한 활용하겠습니다. 새로운 업무에 적응하여 성심을 다해 임하겠습니다. '],
#  ['저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 어려움을 덜어낸 경험이 있습니다. 저는 감시부대에서 복무했습니다. 약 100일간 감시임무를 수행하고 임무를 마치면 다른 소대와 교대를 합니다. 교대하는 과정에서 소초 내 물품의 상태를 확인하는데, 양이 너무 많아 약 일주일 동안 감시임무와 병행하면서 확인해야 했습니다. 그래서 전 확인해야 할 품목이 무엇이고, 어디에 있는지 그리고 수량은 몇 개인지 등을 기록한 체크리스트를 만들었습니다. 이것을 활용해 시간을 단축해 효율적으로 처리할 수 있었고 감시인원의 피로도 해결할 수 있었습니다. @@@@@@@@@@@@@@@고등학교 때 저는 서로 다른 국적을 가진 6명이 한 팀을 이뤄 프로젝트를 진행한 적이 있습니다. 성공하지 못하면 졸업을 할 수 없었기에 모두 다 최선을 다해야 했습니다. 약 1년 동안 진행되는 프로젝트를 성공적으로 마무리하기 위해 전 개개인의 뛰어난 역량이 아닌, 6명이 하나로 뭉쳐 주어진 과업을 협력을 통해 해결해나가는 것이 매우 중요하다고 생각했습니다.@@@@@@@@@@@@@@@그래서 전 팀에서 의견을 주장하기보다 먼저 팀원들의 의견을 들었습니다. 상대방의 말에 집중했더니 의견에 부족한 점을 파악할 수 있었고, 저는 주로 그 부족한 점을 보완하는 의견을 제시했습니다. 상대방의 의견에 경청하는 제 태도는 팀원들에게 좋은 인상을 주었고, 자연스럽게 팀을 이끄는 역할을 맡게 되었습니다. 프로젝트를 진행하면서 팀원이 어려움을 느끼면 다가가 도와주었고, 반대로 제가 어려움을 겪으면 다른 팀원이 다가와 도와주었습니다. 그렇게 저희는 협력을 통해 하나로 뭉쳐 맡은 과업을 충실히 수행했고, 졸업식 날 최고의 논문으로 뽑히면서 마무리할 수 있었습니다. @@@@@@@@@@@@@@@마지막으로 전 업무를 수행하면서 기존 방식에 대해 문제의식을 느꼈고, 이를 적극적인 태도로 해결한 적이 있습니다. 이런 제 모습은 주어진 일을 효율적으로 처리할 수 있고 OOOOOOOO을 발전할 수 있는 발판을 만들 수 있다고 생각합니다. @@@@@@@@@@@@@@@군대에서 신고전화가 왔을 때 당직근무를 하는 간부마다 서로 다르게 응대해, 상황을 기록하는 업무를 맡은 전 어려움을 겪었습니다. 신속하고 정확하게 기록한 후 상급부대에 제출해야 하지만 혹시라도 놓친 건 없는지 확인하느라 그러질 못했습니다. 그래서 전 먼저 직속상관에게 이 문제를 보고했습니다. 이후, 문제점을 해결하기 위해 여러 방안을 고안했고, 그중 가장 적절한 것은 무엇인지 주변 전우와 간부들에게 도움을 받았습니다. 또한, 인사과에 방문해 제가 생각한 방안을 이야기하고, 이것을 어떻게 더 활용할 수 있는지를 논의해 부족한 점을 보완했습니다.@@@@@@@@@@@@@@@모든 것을 다 정리한 후 소대장은 중대장에게 문제점 및 해결방안을 보고했고, 중대장은 대대 주간회의에서 보고받은 방안을 소개했습니다. 대대장은 조금만 더 수정한 후 바로 반영하도록 지시를 해 불편함을 해소할 수 있었습니다. 이 문제를 해결하기 전까지 군대는 변화를 꺼리는 집단인 줄 알았습니다. 그렇기에 불편하더라도 불평 없이 감수하는 것이 옳은 선택이라고 생각했습니다. 하지만 적극적인 태도로 다가가 불편함을 해소했을 뿐만 아니라, 다른 부서와 함께 의견을 나누며 협업을 경험할 수 있었습니다. 또한, 이 경험을 통해 고정관념을 부술 수 있었고, 더 나은 선택이라면 무엇이든 적극적으로 행동할 수 있는 계기가 되었습니다. ']]

# %%
raw_df2['preprocess3'] = new_contents3

# %%
raw_df2
# Out:
#      company_name                                              paper  \
# 0        (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1      한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2     (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
# 3           ㈜하나은행  [[자기소개서, \r\n벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력\r"보...
# 4            조선비즈  [[자유양식, \r\n저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 ...
# ...           ...                                                ...
# 6755   삼화페인트공업(주)  [[본인의 성격, 성장과정, 가치관 등을 기술하시오., \r\n남들을 배려하며 착하...
# 6756      LG디스플레이  [[LG디스플레이 및 지원 직무에 지원하는 동기에 대해 기술해 주십시오. (500~...
# 6757     엘에스전선(주)  [[본인에 대하여 소개해 주시기 바랍니다. (성장과정, 경험, 성격, 강/약점, 가...
# 6758        S-OIL  [[귀하가 회사를 선택하는 기준은 무엇이며 왜 당사가 그 기준에 적합한지를 작성하고...
# 6759        샘표(주)  [[샘표식품㈜에 지원하는 구체적인 이유와 샘표식품에서 여러분을 선택해야 하는 이유에...
#
#                                                     url  \
# 0     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 3     https://www.jobkorea.co.kr/starter/PassAssay/V...
# 4     https://www.jobkorea.co.kr/starter/PassAssay/V...
# ...                                                 ...
# 6755  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6756  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6757  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6758  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 6759  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                             preprocess1  \
# 0     [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1     [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2     [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...
# 3     [@@@@@@@@@@@@@@@벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력%...
# 4     [@@@@@@@@@@@@@@@저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무...
# ...                                                 ...
# 6755  [@@@@@@@@@@@@@@@남들을 배려하며 착하게 사는 것이 옳다고 배우며 살아왔...
# 6756  [@@@@@@@@@@@@@@@2013년 여름, 천호식품에서 아르바이트를 했었습니다....
# 6757  [@@@@@@@@@@@@@@@[노력하는 인재]%%%%%%%%%%%%%%% 선배들의 ...
# 6758  [@@@@@@@@@@@@@@@[Be the first? Do the best!!]%...
# 6759  [@@@@@@@@@@@@@@@[세계가 샘내는 기업 샘표]%%%%%%%%%%%%%%%...
#
#                                             preprocess2  \
# 0     [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1     [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2     ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...
# 3     [벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력@@@@@@@@@@@@@@@"...
# 4     [저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 어려움을 덜어낸 경험...
# ...                                                 ...
# 6755  [남들을 배려하며 착하게 사는 것이 옳다고 배우며 살아왔기 때문에, 이타적인 성향이...
# 6756  [2013년 여름, 천호식품에서 아르바이트를 했었습니다. 제품 생산에서부터 포장, ...
# 6757  [[노력하는 인재]@@@@@@@@@@@@@@@ 선배들의 추천을 받아 13년도 동아리...
# 6758  [[Be the first? Do the best!!]@@@@@@@@@@@@@@@ ...
# 6759  [[세계가 샘내는 기업 샘표]@@@@@@@@@@@@@@@68년의 전통과 최고참 상표...
#
#                                             preprocess3
# 0     [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1     [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2     ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...
# 3     [벤처기업, 제조 공장 자동화, 금융 시스템 개발 경력@@@@@@@@@@@@@@@"...
# 4     [저는 군대에서 행정 업무를 맡으면서 문제를 해결해 임무수행에 어려움을 덜어낸 경험...
# ...                                                 ...
# 6755  [남들을 배려하며 착하게 사는 것이 옳다고 배우며 살아왔기 때문에, 이타적인 성향이...
# 6756  [2013년 여름, 천호식품에서 아르바이트를 했었습니다. 제품 생산에서부터 포장, ...
# 6757  [[노력하는 인재]@@@@@@@@@@@@@@@ 선배들의 추천을 받아 13년도 동아리...
# 6758  [[Be the first? Do the best!!]@@@@@@@@@@@@@@@ ...
# 6759  [[세계가 샘내는 기업 샘표]@@@@@@@@@@@@@@@68년의 전통과 최고참 상표...
#
# [6760 rows x 6 columns]

# %%
new_contents3[0]
# Out:
# ['새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 도전이라 부족한 영어 실력으로 많은 어려움에 부딪쳤습니다. 잠깐 좌절도 했지만 그보다 가장 힘들었던 것은 부모님이 주신 소중한 기회를 제대로 활용하고 있지 못하고 있는 저의 모습이었습니다. 저는 좌절보다는 노력을 택하였습니다. 매주 영어 학원과 스터디그룹에 참석하였으며 다양한 이들과의 대화를 위해 혼자 펍에 가 친구를 사귀기도 하고 아르바이트를 통해 많은 이들과의 소통으로 영어 실력뿐만 아니라 소통력과 관계력까지도 키울 수 있었습니다. 이러한 경험을 바탕으로 경동나비엔의 일원이 되어서도 어떠한 어려움 속에서도 좌절하지 않고 백절불굴의 자세로 부족한 점을 계속해서 연구하고 개선하여 끊임없는 변화 속에서 끊임없는 노력으로 성공이라는 꽃을 피우도록 하겠습니다. ',
#  '코카콜라의 뉴코크 실패는 소비자는 단순히 제품만을 소비하는 것이 아니라 그 브랜드 즉, 제품의 상징성을 구매하는 심리를 보여주고 있습니다. 해외시장에 존재하는 고객은 국내시장에 존재하는 고객들보다 기업에 대한 적은 정보를 가지고 있으며 시장진출에 있어 문화, 언어적인 부분을 넘어 다양한 것들을 고려하고 새롭게 시작하여야 합니다. 하지만 이 또한 기회가 될 수 있습니다 해외시장의 경쟁자들이 보여주지 않았던 부분을 통해 시장을 공략한다면 그 부분이 기업의 상징처럼 되어 하나의 문화, 브랜드가 되어 소비자가 소비하는 이유가 될 수 있습니다. 따라서 제품 구매 후에도 빠르고 다양한 서비스를 제공하는 확실한 사후서비스를 더 강화하고 강조한 전략을 통해 해외시장을 공략하고 애프터 서비스 하면 경동나비엔이 제일 먼저 해외시장의 사람들의 뇌리에 떠오를 수 있게 상징화시킬 수 있다면 해외시장 점유율을 꾸준히 높여갈 수 있을 것입니다. ']

# %%
with open(data_path+'JobKorea_preprocess2.pickle', 'wb') as f: pickle.dump(raw_df2, f)

# %% [markdown]
# ## 노가다

# %%
f = open(data_path+'JobKorea_preprocess2.pickle', 'rb')
raw_df3 = pickle.load(f)
f.close()
raw_df3.head(3)
# Out:
#   company_name                                              paper  \
# 0     (주)경동나비엔  [[자신의 가장 자랑스러운 성취 경험 또는 자신을 가장 힘들게 했던 실패 경험은 무...
# 1   한국수력원자력(주)  [[본인이 지원한 직무와 관련한 경험 혹은 경력에 대해 기술해 주시기 바랍니다. 다...
# 2  (주)포스코인터내셔널  [[성장과정 및 생활신조 등 자기소개를 기술하여 주시기 바랍니다. , \r\n"끈기...
#
#                                                  url  \
# 0  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 1  https://www.jobkorea.co.kr/starter/PassAssay/V...
# 2  https://www.jobkorea.co.kr/starter/PassAssay/V...
#
#                                          preprocess1  \
# 0  [@@@@@@@@@@@@@@@새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었...
# 1  [@@@@@@@@@@@@@@@1) 언제, 어디서 활동했던 경험인지 기술해 주십시오....
# 2  [@@@@@@@@@@@@@@@"끈기를 가지고 노력하면 불가능한 것은 없다"$$$$$...
#
#                                          preprocess2  \
# 0  [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1  [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2  ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...
#
#                                          preprocess3
# 0  [새로운 도전을 위해 대학 시절 OO 유학을 떠나게 되었습니다. 조금 늦은 나이의 ...
# 1  [4번의 졸업작품 참여한 경험이 있습니다. 주전공인 정보통신공학, 복수 전공인 영어...
# 2  ["끈기를 가지고 노력하면 불가능한 것은 없다"@@@@@@@@@@@@@@@어떠한 일...

# %%
tt = raw_df3.preprocess3.tolist()

# %%
set(re.sub("[가-힣a-zA-Z0-9]", "", tt[2][0]))
# Out:
# {' ', '"', '.', '@'}

# %%
special = set()
for t in tt:
    for p in t:
        p = re.sub("[가-힣a-zA-Z0-9]", "", p)
        special |= set(p)

# %%
print(special)
# Out:
# {'］', 'α', '明', '察', '》', '父', '>', '′', '②', '竟', '\u200b', '石', 'ㄱ', 'ㄹ', '：', '□', '±', '造', '秀', '桓', '&', '⓶', '◀', 'Ⅰ', '塞', '流', '合', '·', '△', '③', 'é', '\U000f0853', '〉', '」', '者', '甲', 'ㅇ', '∼', '。', '®', '强', '城', '著', '德', '不', '樂', '，', '低', '+', '\\', '身', '王', '地', '➂', '①', '間', '㎛', '○', '天', '⑥', '形', '成', ':', '新', ' ', '行', '●', '°', '感', '同', '韓', 'Ⅱ', '４', '\t', '翁', 'ᆞ', '「', '}', '健', '人', '博', '多', '_', '共', '‧', '寧', 'Å', 'ㆍ', '~', '＃', '⑤', '{', '☆', '志', '生', '祝', 'Ⅳ', '好', '\u3000', '|', '…', '▲', '=', '交', '▶', '對', '作', '華', '㎠', '針', '◈', '≪', '主', '^', '示', '私', '５', '’', '吝', '公', '⓷', '見', ']', '爲', '動', ')', '$', '使', '.', '家', '傳', '▷', '起', '–', '信', '‘', '℃', '*', '以', '-', '＆', '財', '心', '∙', '★', '情', '展', '現', '持', '➀', '子', '④', '㎥', ',', '．', '』', '師', '金', '氣', '比', '正', '（', '如', '₂', '覆', '@', '）', '＞', '獻', '名', '［', '美', '◆', '%', '“', 'Ω', '通', 'ㄴ', '外', '發', '火', '＇', '忠', '代', '㎍', '神', '二', '₃', '蔬', '²', '故', '業', '農', '㈜', '無', 'μ', '《', '”', '透', '․', '饮', '社', '自', '⇒', '息', '⓵', '後', 'ㅠ', '賢', '•', '有', '幸', '內', '<', '化', 'ㅡ', '#', '未', 'ㄻ', '；', '孝', '■', '緣', '\u2003', '場', '患', '`', '≫', '/', '?', '務', '´', '➁', '月', '道', 'ㅆ', '向', '協', '厚', 'ㅁ', '算', '来', '前', '食', '众', '可', '總', '馬', '『', 'ｍ', '先', '撈', '望', '(', '物', '顚', '上', '大', '錯', '酒', '＜', '\xa0', '君', '中', ';', '斧', '"', '˙', '初', '才', 'ㅏ', '備', '一', '!', '做', '乐', '¸', '之', '×', '曰', '⓸', '切', '體', '活', 'ᄁ', '樂', '∞', '→', '女', '過', '事', 'ㄷ', '♬', '＂', 'ㅈ', '♪', '▣', '下', "'", '[', '星', '因', '\U000f0852', '記', '知', '坤', '磨', '高', '愛', 'ㅒ', 'ㅅ', '非', '\u2028', '\uf09e', '橫', '摩'}

# %%
for i in range(135, len(raw_df)): # len(raw_df)
    temp = []
    for contents in raw_df3.iloc[i].preprocess2:
        print(i)
        print(contents)
        input()
        clear_output(wait=False)
# Out:
# 137
# "기업금융 전문가 RM"@@@@@@@@@@@@@@@저의 궁극적인 목표는 기업고객에게 통합적인 솔루션을 제공하는 기업RM이 되는 것입니다. 가계부채 규제가 강화되어 기업대출에 대한 경쟁이 심화되는 추세 속에서, 신규고객을 창출하고 종합적인 금융 컨설팅을 제공하는 RM의 역할은 더욱 중요해질 것입니다.@@@@@@@@@@@@@@@단기적으로는 기업 여신/수신 업무를 수행하며 기업금융의 기본적인 프로세스를 배워가겠습니다. 중장기적으로는 수출입 기업을 대상으로 환리스크 관리, 신용장 발행 등의 업무를 수행하며 기업금융 분야의 전문가로 성장하겠습니다. @@@@@@@@@@@@@@@신한은행은 여러 은행 중에서도 기업 금융 분야의 전통적인 강자로 위치해왔습니다. 또한, SOHO 성공지원 센터, SOHO 사관학교, 성공 두드림 맞춤 교실 등 중소기업을 위한 다양한 사업을 진행하며 포용적 금융을 실천함과 동시에 잠재고객 발굴에 앞서고 있습니다. 이러한 신한은행에서 기업금융 업무를 수행한다면, 여러 산업에 걸쳐 폭넓은 인사이트를 키울 수 있을 것입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-210-6f37df76b1e1> in <module>
#       4         print(i)
#       5         print(contents)
# ----> 6         input()
#       7         clear_output(wait=False)
#
# ~/anaconda3/envs/juyoung2/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/anaconda3/envs/juyoung2/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def convert(contents):
    temp = []
    for content in contents:
        temp.append(content.replace("@@@@@@@@@@@@@@@", '\n'))
        
    return temp

raw_df3['convert_preprocess3'] = raw_df3.apply(lambda x: convert(x['preprocess3']), axis=1)

# %%
p = re.compile('(?P<subheder>^\"[^\"]*\"[^\n]*)')
check = []

for contents in raw_df3.convert_preprocess3:
    temp = []
    for content in contents:
        sub_temp = []
        sentences = content.split('\n')
        for s in sentences:
            sub_temp.extend(p.findall(s))
        temp.append(sub_temp)
        
    check.append(temp)

# %%
for i, c in enumerate(check):
    print(i)
    print(c)
    
    input()
    clear_output(wait=False)
# Out:
# 92
# [['"1년간의 학부연구생 생활과 교내 우수 연구센터 인턴 경험"', '"글로벌 자동차 기업의 기술지원 팀 인턴 경험"']]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-181-77bfcbdb5072> in <module>
#       3     print(c)
#       4
# ----> 5     input()
#       6     clear_output(wait=False)
#
# ~/anaconda3/envs/juyoung2/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/anaconda3/envs/juyoung2/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
