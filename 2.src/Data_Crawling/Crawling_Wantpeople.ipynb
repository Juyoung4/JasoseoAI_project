# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # 인재상 크롤링

# %%
MODEL_PATH = 'data/'
url = 'https://www.catch.co.kr/Comp/AnalysisCompGubun'

# %% [markdown]
# ## 기업 분류 및 카테고리화

# %%
def category_classification(url):
    response = requests.get(url)
    categoryType = []
    categoriesDict = {}
    corpOfCategoryDict = {}
    bigCorps = {}

    if response.status_code == 200:
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        rawCorpData = soup.find("div",{"class": "look"})

        category1 = rawCorpData.find("p", {"id":"step1"}).get_text()  # 대기업
        category2 = rawCorpData.find("p", {"id":"step2"}).get_text()  # 산업별
        category3 = rawCorpData.find("p", {"id":"step3"}).get_text()  # 공공기관

        categoryType.append(category1)
        categoryType.append(category2)
        categoryType.append(category3)

        # 카테고리별 기업 리스트
        # [[대기업카테고리의 html], [산업카테고리의 html], [공공기관카테고리의 html], [공공기관카테고리의 html]]
        dataOfCategoryType = rawCorpData.find_all("div", {"class":"list"})

        # categoryType별 category 종류
        # [[삼성, sk][it미디어,  식품][]]
        categoriesList = [[categories.get_text().strip() for categories in dataOfCategoryType[i].find_all("p")] for i in range(len(dataOfCategoryType))]

        # index가 2인 카테고리 이름 지정 : "공공기관", 그리고 index 2, 3 합치기
        # 즉 [['공공기관'],['한전계열사', '금융공기업']] -> ['공공기관', '한전계열사', '금융공기업'] 으로 변환하는 작업
        categoriesList[2] = ["공공기관"]
        categoriesList[2].extend(categoriesList[3])
        del categoriesList[3]

        # categoriesDict -> (key: 카테고리의 타입, value: 카테고리 종류들)
        # (참고 - 대기업: 대기업회사종류, 업종별: 업종 종류, 공공기관: 공공기관종류)
        for i, type_ in enumerate(categoryType):
            categoriesDict[type_] = categoriesList[i]


        # 각 카테고리별 기업의 (기업이름, 기업분석 URL)
        subCategoriesList = [[[(corp.get_text(), corp.find("a")["href"]) for corp in corps.find_all("li")] for corps in dataOfCategoryType[i].find_all("ul")] for i in range(len(dataOfCategoryType))]

        # 공공기관 기업들을 하나로 묶어주고 계열사는 따로 분류
        # [['공공기관'],['한전계열사', '금융공기업']] -> ['공공기관', '한전계열사', '금융공기업'] 으로 변환에 맞추어 형태 변환
        # 계열사로 따로 분류한 기업들은 공공기관 기업안에 이미 들어가 있음 -> 인재상 찾을 때는 공공기관에 있는 기관들만 검색
        temp = []
        for i in subCategoriesList[2]:
            temp.extend(i)
        subCategoriesList[2] = [temp]

        for i in subCategoriesList[3]:
            subCategoriesList[2].append(i)
        del subCategoriesList[3]

        for i, categories in enumerate(categoriesList):
            for j, category in enumerate(categories):
                corpOfCategoryDict[category] = subCategoriesList[i][j]

    else : 
        print(response.status_code)
    
    return categoryType, categoriesDict, corpOfCategoryDict

# %%
categoryType, categoriesDict, corpOfCategoryDict = category_classification(url)
categoryType
categoriesDict
corpOfCategoryDict
# Out:
# {'삼성': [('삼성디스플레이', '/Comp/AnalysisCompView?ID=975'),
#   ('삼성물산', '/Comp/AnalysisCompView?ID=1151'),
#   ('삼성생명보험', '/Comp/AnalysisCompView?ID=891'),
#   ('삼성전기', '/Comp/AnalysisCompView?ID=977'),
#   ('삼성전자', '/Comp/AnalysisCompView?ID=1065'),
#   ('삼성전자로지텍', '/Comp/AnalysisCompView?ID=978'),
#   ('삼성중공업', '/Comp/AnalysisCompView?ID=515'),
#   ('삼성증권', '/Comp/AnalysisCompView?ID=1113'),
#   ('삼성카드', '/Comp/AnalysisCompView?ID=613'),
#   ('삼성화재해상보험', '/Comp/AnalysisCompView?ID=614'),
#   ('삼성SDS', '/Comp/AnalysisCompView?ID=974'),
#   ('제일기획', '/Comp/AnalysisCompView?ID=1068'),
#   ('호텔신라', '/Comp/AnalysisCompView?ID=1174')],
#  'GS': [('GS건설', '/Comp/AnalysisCompView?ID=840'),
#   ('GS리테일', '/Comp/AnalysisCompView?ID=853'),
#   ('GS칼텍스', '/Comp/AnalysisCompView?ID=1083'),
#   ('GS홈쇼핑', '/Comp/AnalysisCompView?ID=1086')],
#  'LG': [('LG CNS', '/Comp/AnalysisCompView?ID=1067'),
#   ('LG디스플레이', '/Comp/AnalysisCompView?ID=1150'),
#   ('LG생활건강', '/Comp/AnalysisCompView?ID=859'),
#   ('LG유플러스', '/Comp/AnalysisCompView?ID=860'),
#   ('LG이노텍', '/Comp/AnalysisCompView?ID=861'),
#   ('LG전자', '/Comp/AnalysisCompView?ID=829'),
#   ('LG화학', '/Comp/AnalysisCompView?ID=1145'),
#   ('LX MMA', '/Comp/AnalysisCompView?ID=530'),
#   ('LX인터내셔널', '/Comp/AnalysisCompView?ID=858'),
#   ('LX하우시스', '/Comp/AnalysisCompView?ID=862')],
#  'SK': [('SK네트웍스', '/Comp/AnalysisCompView?ID=956'),
#   ('SK이노베이션', '/Comp/AnalysisCompView?ID=867'),
#   ('SK텔레콤', '/Comp/AnalysisCompView?ID=868'),
#   ('SK하이닉스', '/Comp/AnalysisCompView?ID=830'),
#   ('SKC', '/Comp/AnalysisCompView?ID=955')],
#  '롯데': [('롯데건설', '/Comp/AnalysisCompView?ID=885'),
#   ('롯데렌탈', '/Comp/AnalysisCompView?ID=699'),
#   ('롯데손해보험', '/Comp/AnalysisCompView?ID=338'),
#   ('롯데쇼핑', '/Comp/AnalysisCompView?ID=1095'),
#   ('롯데알미늄', '/Comp/AnalysisCompView?ID=711'),
#   ('롯데정밀화학', '/Comp/AnalysisCompView?ID=969'),
#   ('롯데칠성음료', '/Comp/AnalysisCompView?ID=970'),
#   ('롯데캐피탈', '/Comp/AnalysisCompView?ID=971'),
#   ('롯데케미칼', '/Comp/AnalysisCompView?ID=887'),
#   ('호텔롯데', '/Comp/AnalysisCompView?ID=1001')],
#  'CJ': [('CJ CGV', '/Comp/AnalysisCompView?ID=1129'),
#   ('CJ ENM', '/Comp/AnalysisCompView?ID=848'),
#   ('CJ올리브네트웍스', '/Comp/AnalysisCompView?ID=1104'),
#   ('CJ제일제당', '/Comp/AnalysisCompView?ID=1122'),
#   ('CJ푸드빌', '/Comp/AnalysisCompView?ID=494')],
#  '현대자동차': [('현대건설', '/Comp/AnalysisCompView?ID=824'),
#   ('현대글로비스', '/Comp/AnalysisCompView?ID=1130'),
#   ('현대모비스', '/Comp/AnalysisCompView?ID=930'),
#   ('현대엔지니어링', '/Comp/AnalysisCompView?ID=641'),
#   ('현대위아', '/Comp/AnalysisCompView?ID=999'),
#   ('현대자동차', '/Comp/AnalysisCompView?ID=1075'),
#   ('현대제철', '/Comp/AnalysisCompView?ID=935'),
#   ('현대카드', '/Comp/AnalysisCompView?ID=1093'),
#   ('현대케피코', '/Comp/AnalysisCompView?ID=572'),
#   ('현대트랜시스', '/Comp/AnalysisCompView?ID=1170'),
#   ('현대파워텍', '/Comp/AnalysisCompView?ID=120')],
#  '현대중공업': [('현대미포조선', '/Comp/AnalysisCompView?ID=640'),
#   ('현대오일뱅크', '/Comp/AnalysisCompView?ID=933')],
#  '현대백화점': [('한섬', '/Comp/AnalysisCompView?ID=1133'),
#   ('현대백화점', '/Comp/AnalysisCompView?ID=931'),
#   ('현대홈쇼핑', '/Comp/AnalysisCompView?ID=937')],
#  '한화': [('한화', '/Comp/AnalysisCompView?ID=925'),
#   ('한화갤러리아', '/Comp/AnalysisCompView?ID=926'),
#   ('한화건설', '/Comp/AnalysisCompView?ID=561'),
#   ('한화글로벌에셋', '/Comp/AnalysisCompView?ID=691'),
#   ('한화생명보험', '/Comp/AnalysisCompView?ID=1111'),
#   ('한화손해보험', '/Comp/AnalysisCompView?ID=628'),
#   ('한화솔루션', '/Comp/AnalysisCompView?ID=927'),
#   ('한화시스템', '/Comp/AnalysisCompView?ID=562'),
#   ('한화에어로스페이스', '/Comp/AnalysisCompView?ID=563'),
#   ('한화종합화학', '/Comp/AnalysisCompView?ID=564'),
#   ('한화토탈', '/Comp/AnalysisCompView?ID=565'),
#   ('한화호텔앤드리조트', '/Comp/AnalysisCompView?ID=996')],
#  'IT·미디어': [('골프존', '/Comp/AnalysisCompView?ID=737'),
#   ('나스미디어', '/Comp/AnalysisCompView?ID=1110'),
#   ('네오위즈', '/Comp/AnalysisCompView?ID=744'),
#   ('네오플', '/Comp/AnalysisCompView?ID=1102'),
#   ('네이버', '/Comp/AnalysisCompView?ID=1147'),
#   ('넥슨코리아', '/Comp/AnalysisCompView?ID=963'),
#   ('넷마블', '/Comp/AnalysisCompView?ID=1101'),
#   ('대학내일', '/Comp/AnalysisCompView?ID=747'),
#   ('딜리버리히어로코리아', '/Comp/AnalysisCompView?ID=883'),
#   ('라인플러스', '/Comp/AnalysisCompView?ID=968'),
#   ('마이다스아이티', '/Comp/AnalysisCompView?ID=1073'),
#   ('멀티캠퍼스', '/Comp/AnalysisCompView?ID=758'),
#   ('비바리퍼블리카', '/Comp/AnalysisCompView?ID=763'),
#   ('삼성SDS', '/Comp/AnalysisCompView?ID=974'),
#   ('스마트스터디', '/Comp/AnalysisCompView?ID=772'),
#   ('야놀자', '/Comp/AnalysisCompView?ID=984'),
#   ('에스엠엔터테인먼트', '/Comp/AnalysisCompView?ID=1106'),
#   ('엔씨소프트', '/Comp/AnalysisCompView?ID=1080'),
#   ('우아한형제들', '/Comp/AnalysisCompView?ID=906'),
#   ('웹젠', '/Comp/AnalysisCompView?ID=790'),
#   ('이노션', '/Comp/AnalysisCompView?ID=1116'),
#   ('이마트24', '/Comp/AnalysisCompView?ID=793'),
#   ('제이와이피엔터테인먼트', '/Comp/AnalysisCompView?ID=731'),
#   ('제이티비씨', '/Comp/AnalysisCompView?ID=795'),
#   ('제일기획', '/Comp/AnalysisCompView?ID=1068'),
#   ('중앙일보', '/Comp/AnalysisCompView?ID=796'),
#   ('카카오', '/Comp/AnalysisCompView?ID=1076'),
#   ('카카오게임즈', '/Comp/AnalysisCompView?ID=798'),
#   ('컴투스', '/Comp/AnalysisCompView?ID=912'),
#   ('코스콤', '/Comp/AnalysisCompView?ID=800'),
#   ('티캐스트', '/Comp/AnalysisCompView?ID=803'),
#   ('한국교육방송공사', '/Comp/AnalysisCompView?ID=644'),
#   ('한국방송공사', '/Comp/AnalysisCompView?ID=1024'),
#   ('한국아이비엠', '/Comp/AnalysisCompView?ID=992'),
#   ('현대오토에버', '/Comp/AnalysisCompView?ID=998'),
#   ('효성ITX', '/Comp/AnalysisCompView?ID=700'),
#   ('CJ CGV', '/Comp/AnalysisCompView?ID=1129'),
#   ('CJ ENM', '/Comp/AnalysisCompView?ID=848'),
#   ('HDC신라면세점', '/Comp/AnalysisCompView?ID=786'),
#   ('KT', '/Comp/AnalysisCompView?ID=857'),
#   ('LG CNS', '/Comp/AnalysisCompView?ID=1067'),
#   ('LG유플러스', '/Comp/AnalysisCompView?ID=860'),
#   ('LG헬로비전', '/Comp/AnalysisCompView?ID=413'),
#   ('NHN', '/Comp/AnalysisCompView?ID=1098'),
#   ('SBS', '/Comp/AnalysisCompView?ID=1087'),
#   ('SK브로드밴드', '/Comp/AnalysisCompView?ID=866'),
#   ('SK텔레콤', '/Comp/AnalysisCompView?ID=868'),
#   ('SK플래닛', '/Comp/AnalysisCompView?ID=1092')],
#  '자동차·운송장비': [('금호타이어', '/Comp/AnalysisCompView?ID=961'),
#   ('기아', '/Comp/AnalysisCompView?ID=871'),
#   ('넥센타이어', '/Comp/AnalysisCompView?ID=88'),
#   ('르노삼성자동차', '/Comp/AnalysisCompView?ID=511'),
#   ('만도', '/Comp/AnalysisCompView?ID=1136'),
#   ('비테스코테크놀로지스코리아', '/Comp/AnalysisCompView?ID=639'),
#   ('삼성중공업', '/Comp/AnalysisCompView?ID=515'),
#   ('서진산업', '/Comp/AnalysisCompView?ID=382'),
#   ('에스엘', '/Comp/AnalysisCompView?ID=901'),
#   ('한국타이어앤테크놀로지', '/Comp/AnalysisCompView?ID=79'),
#   ('한독모터스', '/Comp/AnalysisCompView?ID=384'),
#   ('한성자동차', '/Comp/AnalysisCompView?ID=383'),
#   ('현대글로비스', '/Comp/AnalysisCompView?ID=1130'),
#   ('현대로템', '/Comp/AnalysisCompView?ID=929'),
#   ('현대모비스', '/Comp/AnalysisCompView?ID=930'),
#   ('현대미포조선', '/Comp/AnalysisCompView?ID=640'),
#   ('현대위아', '/Comp/AnalysisCompView?ID=999'),
#   ('현대자동차', '/Comp/AnalysisCompView?ID=1075'),
#   ('현대케피코', '/Comp/AnalysisCompView?ID=572'),
#   ('현대트랜시스', '/Comp/AnalysisCompView?ID=1170'),
#   ('현대파워텍', '/Comp/AnalysisCompView?ID=120')],
#  '식품': [('농심', '/Comp/AnalysisCompView?ID=1126'),
#   ('농협사료', '/Comp/AnalysisCompView?ID=395'),
#   ('대상', '/Comp/AnalysisCompView?ID=1115'),
#   ('동서식품', '/Comp/AnalysisCompView?ID=881'),
#   ('동원F&B;', '/Comp/AnalysisCompView?ID=882'),
#   ('롯데제과', '/Comp/AnalysisCompView?ID=755'),
#   ('롯데칠성음료', '/Comp/AnalysisCompView?ID=970'),
#   ('매일유업', '/Comp/AnalysisCompView?ID=1139'),
#   ('매일홀딩스', '/Comp/AnalysisCompView?ID=682'),
#   ('비알코리아', '/Comp/AnalysisCompView?ID=973'),
#   ('빙그레', '/Comp/AnalysisCompView?ID=889'),
#   ('삼성웰스토리', '/Comp/AnalysisCompView?ID=1152'),
#   ('삼양사', '/Comp/AnalysisCompView?ID=151'),
#   ('삼양식품', '/Comp/AnalysisCompView?ID=766'),
#   ('샘표식품', '/Comp/AnalysisCompView?ID=1132'),
#   ('스타벅스커피코리아', '/Comp/AnalysisCompView?ID=896'),
#   ('신세계푸드', '/Comp/AnalysisCompView?ID=981'),
#   ('오뚜기', '/Comp/AnalysisCompView?ID=1081'),
#   ('오비맥주', '/Comp/AnalysisCompView?ID=1128'),
#   ('코카콜라음료', '/Comp/AnalysisCompView?ID=1125'),
#   ('크라운제과', '/Comp/AnalysisCompView?ID=802'),
#   ('파리크라상', '/Comp/AnalysisCompView?ID=805'),
#   ('풀무원', '/Comp/AnalysisCompView?ID=1142'),
#   ('풀무원식품', '/Comp/AnalysisCompView?ID=808'),
#   ('하이트진로', '/Comp/AnalysisCompView?ID=918'),
#   ('한국인삼공사', '/Comp/AnalysisCompView?ID=814'),
#   ('한국필립모리스', '/Comp/AnalysisCompView?ID=671'),
#   ('현대그린푸드', '/Comp/AnalysisCompView?ID=928'),
#   ('CJ제일제당', '/Comp/AnalysisCompView?ID=1122'),
#   ('CJ푸드빌', '/Comp/AnalysisCompView?ID=494'),
#   ('CJ프레시웨이', '/Comp/AnalysisCompView?ID=851'),
#   ('hy', '/Comp/AnalysisCompView?ID=919'),
#   ('KT&G;', '/Comp/AnalysisCompView?ID=856'),
#   ('SPC삼립', '/Comp/AnalysisCompView?ID=957')],
#  '유통': [('농협하나로유통', '/Comp/AnalysisCompView?ID=835'),
#   ('데상트코리아', '/Comp/AnalysisCompView?ID=748'),
#   ('디에이치엘코리아', '/Comp/AnalysisCompView?ID=752'),
#   ('롯데글로벌로지스', '/Comp/AnalysisCompView?ID=754'),
#   ('롯데쇼핑', '/Comp/AnalysisCompView?ID=1095'),
#   ('무신사', '/Comp/AnalysisCompView?ID=1103'),
#   ('삼성물산', '/Comp/AnalysisCompView?ID=1151'),
#   ('삼천리자전거', '/Comp/AnalysisCompView?ID=516'),
#   ('세아상역', '/Comp/AnalysisCompView?ID=894'),
#   ('신성통상', '/Comp/AnalysisCompView?ID=773'),
#   ('신세계', '/Comp/AnalysisCompView?ID=897'),
#   ('신세계인터내셔날', '/Comp/AnalysisCompView?ID=979'),
#   ('아성다이소', '/Comp/AnalysisCompView?ID=1100'),
#   ('애경산업', '/Comp/AnalysisCompView?ID=779'),
#   ('에프알엘코리아', '/Comp/AnalysisCompView?ID=527'),
#   ('영원무역', '/Comp/AnalysisCompView?ID=787'),
#   ('이랜드리테일', '/Comp/AnalysisCompView?ID=1091'),
#   ('이랜드월드', '/Comp/AnalysisCompView?ID=1148'),
#   ('이마트', '/Comp/AnalysisCompView?ID=909'),
#   ('이베이코리아', '/Comp/AnalysisCompView?ID=987'),
#   ('코리아세븐', '/Comp/AnalysisCompView?ID=913'),
#   ('쿠팡', '/Comp/AnalysisCompView?ID=1074'),
#   ('포스코인터내셔널', '/Comp/AnalysisCompView?ID=826'),
#   ('한섬', '/Comp/AnalysisCompView?ID=1133'),
#   ('한세실업', '/Comp/AnalysisCompView?ID=819'),
#   ('한진', '/Comp/AnalysisCompView?ID=924'),
#   ('한화갤러리아', '/Comp/AnalysisCompView?ID=926'),
#   ('현대백화점', '/Comp/AnalysisCompView?ID=931'),
#   ('현대홈쇼핑', '/Comp/AnalysisCompView?ID=937'),
#   ('홈플러스', '/Comp/AnalysisCompView?ID=574'),
#   ('BGF리테일', '/Comp/AnalysisCompView?ID=1085'),
#   ('CJ대한통운', '/Comp/AnalysisCompView?ID=849'),
#   ('CJ올리브네트웍스', '/Comp/AnalysisCompView?ID=1104'),
#   ('E1', '/Comp/AnalysisCompView?ID=942'),
#   ('GS리테일', '/Comp/AnalysisCompView?ID=853'),
#   ('GS홈쇼핑', '/Comp/AnalysisCompView?ID=1086'),
#   ('LF', '/Comp/AnalysisCompView?ID=1131'),
#   ('LX인터내셔널', '/Comp/AnalysisCompView?ID=858'),
#   ('LX판토스', '/Comp/AnalysisCompView?ID=806'),
#   ('S&I;', '/Comp/AnalysisCompView?ID=1114'),
#   ('SK네트웍스', '/Comp/AnalysisCompView?ID=956')],
#  '은행': [('경남은행', '/Comp/AnalysisCompView?ID=101'),
#   ('광주은행', '/Comp/AnalysisCompView?ID=352'),
#   ('국민은행', '/Comp/AnalysisCompView?ID=869'),
#   ('농협은행', '/Comp/AnalysisCompView?ID=1118'),
#   ('대구은행', '/Comp/AnalysisCompView?ID=107'),
#   ('부산은행', '/Comp/AnalysisCompView?ID=108'),
#   ('새마을금고중앙회', '/Comp/AnalysisCompView?ID=137'),
#   ('수협은행', '/Comp/AnalysisCompView?ID=771'),
#   ('신한은행', '/Comp/AnalysisCompView?ID=1082'),
#   ('우리은행', '/Comp/AnalysisCompView?ID=1107'),
#   ('카카오뱅크', '/Comp/AnalysisCompView?ID=1094'),
#   ('하나은행', '/Comp/AnalysisCompView?ID=917'),
#   ('한국스탠다드차타드은행', '/Comp/AnalysisCompView?ID=278'),
#   ('한국씨티은행', '/Comp/AnalysisCompView?ID=122')],
#  '보험': [('교보생명보험', '/Comp/AnalysisCompView?ID=1137'),
#   ('롯데손해보험', '/Comp/AnalysisCompView?ID=338'),
#   ('메리츠화재해상보험', '/Comp/AnalysisCompView?ID=336'),
#   ('메트라이프생명보험', '/Comp/AnalysisCompView?ID=375'),
#   ('미래에셋생명보험', '/Comp/AnalysisCompView?ID=364'),
#   ('삼성생명보험', '/Comp/AnalysisCompView?ID=891'),
#   ('삼성화재해상보험', '/Comp/AnalysisCompView?ID=614'),
#   ('신한라이프생명보험', '/Comp/AnalysisCompView?ID=677'),
#   ('악사손해보험', '/Comp/AnalysisCompView?ID=619'),
#   ('오렌지라이프생명보험', '/Comp/AnalysisCompView?ID=365'),
#   ('코리안리재보험', '/Comp/AnalysisCompView?ID=799'),
#   ('푸르덴셜생명보험', '/Comp/AnalysisCompView?ID=1061'),
#   ('푸본현대생명보험', '/Comp/AnalysisCompView?ID=807'),
#   ('한화생명보험', '/Comp/AnalysisCompView?ID=1111'),
#   ('한화손해보험', '/Comp/AnalysisCompView?ID=628'),
#   ('현대해상화재보험', '/Comp/AnalysisCompView?ID=631'),
#   ('흥국생명보험', '/Comp/AnalysisCompView?ID=633'),
#   ('흥국화재해상보험', '/Comp/AnalysisCompView?ID=339'),
#   ('DB생명보험', '/Comp/AnalysisCompView?ID=376'),
#   ('DB손해보험', '/Comp/AnalysisCompView?ID=680'),
#   ('KB손해보험', '/Comp/AnalysisCompView?ID=1105')],
#  '증권': [('교보증권', '/Comp/AnalysisCompView?ID=342'),
#   ('대신증권', '/Comp/AnalysisCompView?ID=608'),
#   ('메리츠증권', '/Comp/AnalysisCompView?ID=759'),
#   ('미래에셋자산운용', '/Comp/AnalysisCompView?ID=761'),
#   ('미래에셋증권', '/Comp/AnalysisCompView?ID=888'),
#   ('삼성증권', '/Comp/AnalysisCompView?ID=1113'),
#   ('신영증권', '/Comp/AnalysisCompView?ID=1121'),
#   ('신한금융투자', '/Comp/AnalysisCompView?ID=836'),
#   ('유진투자증권', '/Comp/AnalysisCompView?ID=1127'),
#   ('키움증권', '/Comp/AnalysisCompView?ID=1097'),
#   ('하나금융투자', '/Comp/AnalysisCompView?ID=321'),
#   ('하이투자증권', '/Comp/AnalysisCompView?ID=354'),
#   ('한국증권금융', '/Comp/AnalysisCompView?ID=994'),
#   ('한국투자증권', '/Comp/AnalysisCompView?ID=920'),
#   ('한화투자증권', '/Comp/AnalysisCompView?ID=629'),
#   ('현대차증권', '/Comp/AnalysisCompView?ID=820'),
#   ('DB금융투자', '/Comp/AnalysisCompView?ID=604'),
#   ('KB증권', '/Comp/AnalysisCompView?ID=732'),
#   ('NH투자증권', '/Comp/AnalysisCompView?ID=620')],
#  '카드': [('롯데카드', '/Comp/AnalysisCompView?ID=609'),
#   ('롯데캐피탈', '/Comp/AnalysisCompView?ID=971'),
#   ('비씨카드', '/Comp/AnalysisCompView?ID=611'),
#   ('삼성카드', '/Comp/AnalysisCompView?ID=613'),
#   ('신한카드', '/Comp/AnalysisCompView?ID=617'),
#   ('우리카드', '/Comp/AnalysisCompView?ID=356'),
#   ('하나카드', '/Comp/AnalysisCompView?ID=374'),
#   ('현대카드', '/Comp/AnalysisCompView?ID=1093'),
#   ('현대캐피탈', '/Comp/AnalysisCompView?ID=821'),
#   ('KB캐피탈', '/Comp/AnalysisCompView?ID=351')],
#  '전기전자·반도체': [('도레이첨단소재', '/Comp/AnalysisCompView?ID=965'),
#   ('삼성전기', '/Comp/AnalysisCompView?ID=977'),
#   ('삼성전자', '/Comp/AnalysisCompView?ID=1065'),
#   ('삼성SDI', '/Comp/AnalysisCompView?ID=890'),
#   ('이수페타시스', '/Comp/AnalysisCompView?ID=536'),
#   ('코오롱인더스트리', '/Comp/AnalysisCompView?ID=915'),
#   ('포스코케미칼', '/Comp/AnalysisCompView?ID=990'),
#   ('한화글로벌에셋', '/Comp/AnalysisCompView?ID=691'),
#   ('한화시스템', '/Comp/AnalysisCompView?ID=562'),
#   ('효성중공업', '/Comp/AnalysisCompView?ID=822'),
#   ('효성첨단소재', '/Comp/AnalysisCompView?ID=823'),
#   ('DB하이텍', '/Comp/AnalysisCompView?ID=1141'),
#   ('LG디스플레이', '/Comp/AnalysisCompView?ID=1150'),
#   ('LG이노텍', '/Comp/AnalysisCompView?ID=861'),
#   ('LG전자', '/Comp/AnalysisCompView?ID=829'),
#   ('SK하이닉스', '/Comp/AnalysisCompView?ID=830'),
#   ('SKC', '/Comp/AnalysisCompView?ID=955')],
#  '석유·화학·에너지': [('금호석유화학', '/Comp/AnalysisCompView?ID=838'),
#   ('동우화인켐', '/Comp/AnalysisCompView?ID=508'),
#   ('롯데정밀화학', '/Comp/AnalysisCompView?ID=969'),
#   ('롯데케미칼', '/Comp/AnalysisCompView?ID=887'),
#   ('이수화학', '/Comp/AnalysisCompView?ID=1143'),
#   ('팜한농', '/Comp/AnalysisCompView?ID=546'),
#   ('포스코에너지', '/Comp/AnalysisCompView?ID=719'),
#   ('한화', '/Comp/AnalysisCompView?ID=925'),
#   ('한화솔루션', '/Comp/AnalysisCompView?ID=927'),
#   ('한화종합화학', '/Comp/AnalysisCompView?ID=564'),
#   ('한화토탈', '/Comp/AnalysisCompView?ID=565'),
#   ('현대엔지니어링', '/Comp/AnalysisCompView?ID=641'),
#   ('현대오일뱅크', '/Comp/AnalysisCompView?ID=933'),
#   ('효성', '/Comp/AnalysisCompView?ID=1135'),
#   ('GS칼텍스', '/Comp/AnalysisCompView?ID=1083'),
#   ('KCC', '/Comp/AnalysisCompView?ID=855'),
#   ('LG화학', '/Comp/AnalysisCompView?ID=1145'),
#   ('LX MMA', '/Comp/AnalysisCompView?ID=530'),
#   ('OCI', '/Comp/AnalysisCompView?ID=954'),
#   ('SK E&S;', '/Comp/AnalysisCompView?ID=714'),
#   ('SK에너지', '/Comp/AnalysisCompView?ID=735'),
#   ('SK이노베이션', '/Comp/AnalysisCompView?ID=867'),
#   ('SK케미칼', '/Comp/AnalysisCompView?ID=736'),
#   ('S-OIL', '/Comp/AnalysisCompView?ID=865')],
#  '화장품·제약': [('광동제약', '/Comp/AnalysisCompView?ID=738'),
#   ('대웅제약', '/Comp/AnalysisCompView?ID=1134'),
#   ('동아제약', '/Comp/AnalysisCompView?ID=749'),
#   ('보령제약', '/Comp/AnalysisCompView?ID=762'),
#   ('삼성바이오로직스', '/Comp/AnalysisCompView?ID=1084'),
#   ('셀트리온', '/Comp/AnalysisCompView?ID=1123'),
#   ('아모레퍼시픽', '/Comp/AnalysisCompView?ID=982'),
#   ('아모레퍼시픽그룹', '/Comp/AnalysisCompView?ID=777'),
#   ('에이치케이이노엔', '/Comp/AnalysisCompView?ID=776'),
#   ('유한양행', '/Comp/AnalysisCompView?ID=1112'),
#   ('종근당', '/Comp/AnalysisCompView?ID=1119'),
#   ('코스맥스', '/Comp/AnalysisCompView?ID=1088'),
#   ('한국콜마', '/Comp/AnalysisCompView?ID=1072'),
#   ('한미약품', '/Comp/AnalysisCompView?ID=843'),
#   ('GC녹십자', '/Comp/AnalysisCompView?ID=1117'),
#   ('JW중외제약', '/Comp/AnalysisCompView?ID=1138'),
#   ('LG생활건강', '/Comp/AnalysisCompView?ID=859')],
#  '생활·렌탈': [('깨끗한나라', '/Comp/AnalysisCompView?ID=743'),
#   ('라인프렌즈', '/Comp/AnalysisCompView?ID=753'),
#   ('롯데렌탈', '/Comp/AnalysisCompView?ID=699'),
#   ('세스코', '/Comp/AnalysisCompView?ID=770'),
#   ('신도리코', '/Comp/AnalysisCompView?ID=585'),
#   ('유한킴벌리', '/Comp/AnalysisCompView?ID=908'),
#   ('코웨이', '/Comp/AnalysisCompView?ID=989'),
#   ('쿠쿠홀딩스', '/Comp/AnalysisCompView?ID=174'),
#   ('한국쓰리엠', '/Comp/AnalysisCompView?ID=666'),
#   ('한국후지필름비즈니스이노베이션', '/Comp/AnalysisCompView?ID=698')],
#  '건설': [('금호건설', '/Comp/AnalysisCompView?ID=500'),
#   ('대우건설', '/Comp/AnalysisCompView?ID=1124'),
#   ('동부건설', '/Comp/AnalysisCompView?ID=1120'),
#   ('두산', '/Comp/AnalysisCompView?ID=966'),
#   ('두산건설', '/Comp/AnalysisCompView?ID=581'),
#   ('디엘', '/Comp/AnalysisCompView?ID=1144'),
#   ('롯데건설', '/Comp/AnalysisCompView?ID=885'),
#   ('부영주택', '/Comp/AnalysisCompView?ID=345'),
#   ('삼성물산', '/Comp/AnalysisCompView?ID=1151'),
#   ('삼성엔지니어링', '/Comp/AnalysisCompView?ID=976'),
#   ('서희건설', '/Comp/AnalysisCompView?ID=769'),
#   ('신세계건설', '/Comp/AnalysisCompView?ID=774'),
#   ('쌍용건설', '/Comp/AnalysisCompView?ID=775'),
#   ('코오롱글로벌', '/Comp/AnalysisCompView?ID=67'),
#   ('포스코건설', '/Comp/AnalysisCompView?ID=916'),
#   ('한라', '/Comp/AnalysisCompView?ID=590'),
#   ('한양', '/Comp/AnalysisCompView?ID=390'),
#   ('한화건설', '/Comp/AnalysisCompView?ID=561'),
#   ('현대건설', '/Comp/AnalysisCompView?ID=824'),
#   ('GS건설', '/Comp/AnalysisCompView?ID=840'),
#   ('HDC현대산업개발', '/Comp/AnalysisCompView?ID=729'),
#   ('LX하우시스', '/Comp/AnalysisCompView?ID=862'),
#   ('SK에코플랜트', '/Comp/AnalysisCompView?ID=1109')],
#  '기계장비': [('두산인프라코어', '/Comp/AnalysisCompView?ID=967'),
#   ('두산중공업', '/Comp/AnalysisCompView?ID=583'),
#   ('에릭슨엘지', '/Comp/AnalysisCompView?ID=780'),
#   ('오스템임플란트', '/Comp/AnalysisCompView?ID=788'),
#   ('캐논코리아비즈니스솔루션', '/Comp/AnalysisCompView?ID=703'),
#   ('포스코ICT', '/Comp/AnalysisCompView?ID=1108'),
#   ('한국항공우주산업', '/Comp/AnalysisCompView?ID=921'),
#   ('현대엘리베이터', '/Comp/AnalysisCompView?ID=932'),
#   ('효성TNS', '/Comp/AnalysisCompView?ID=694'),
#   ('GS엔텍', '/Comp/AnalysisCompView?ID=797'),
#   ('LS일렉트릭', '/Comp/AnalysisCompView?ID=951'),
#   ('LS전선', '/Comp/AnalysisCompView?ID=952')],
#  '철강': [('고려아연', '/Comp/AnalysisCompView?ID=959'),
#   ('동국제강', '/Comp/AnalysisCompView?ID=270'),
#   ('롯데알미늄', '/Comp/AnalysisCompView?ID=711'),
#   ('세아베스틸', '/Comp/AnalysisCompView?ID=51'),
#   ('세아특수강', '/Comp/AnalysisCompView?ID=489'),
#   ('포스코', '/Comp/AnalysisCompView?ID=825'),
#   ('포스코강판', '/Comp/AnalysisCompView?ID=718'),
#   ('풍산', '/Comp/AnalysisCompView?ID=809'),
#   ('현대제철', '/Comp/AnalysisCompView?ID=935'),
#   ('KG동부제철', '/Comp/AnalysisCompView?ID=487')],
#  '여행·항공': [('노랑풍선', '/Comp/AnalysisCompView?ID=746'),
#   ('대한항공', '/Comp/AnalysisCompView?ID=880'),
#   ('모두투어네트워크', '/Comp/AnalysisCompView?ID=972'),
#   ('소노인터내셔널', '/Comp/AnalysisCompView?ID=471'),
#   ('아시아나항공', '/Comp/AnalysisCompView?ID=983'),
#   ('에어부산', '/Comp/AnalysisCompView?ID=784'),
#   ('에어서울', '/Comp/AnalysisCompView?ID=785'),
#   ('이스타항공', '/Comp/AnalysisCompView?ID=794'),
#   ('제주항공', '/Comp/AnalysisCompView?ID=441'),
#   ('조선호텔앤리조트', '/Comp/AnalysisCompView?ID=980'),
#   ('진에어', '/Comp/AnalysisCompView?ID=988'),
#   ('티웨이항공', '/Comp/AnalysisCompView?ID=451'),
#   ('파라다이스', '/Comp/AnalysisCompView?ID=804'),
#   ('퍼시스그룹', '/Comp/AnalysisCompView?ID=1071'),
#   ('하나투어', '/Comp/AnalysisCompView?ID=453'),
#   ('한화호텔앤드리조트', '/Comp/AnalysisCompView?ID=996'),
#   ('호텔롯데', '/Comp/AnalysisCompView?ID=1001'),
#   ('호텔신라', '/Comp/AnalysisCompView?ID=1174')],
#  '교육': [('교보문고', '/Comp/AnalysisCompView?ID=1140'),
#   ('교원', '/Comp/AnalysisCompView?ID=960'),
#   ('대교', '/Comp/AnalysisCompView?ID=578'),
#   ('비상교육', '/Comp/AnalysisCompView?ID=764'),
#   ('웅진씽크빅', '/Comp/AnalysisCompView?ID=599')],
#  '공공기관': [('강원랜드', '/Comp/AnalysisCompView?ID=1002'),
#   ('건강보험심사평가원', '/Comp/AnalysisCompView?ID=1004'),
#   ('공무원연금공단', '/Comp/AnalysisCompView?ID=684'),
#   ('공영홈쇼핑', '/Comp/AnalysisCompView?ID=701'),
#   ('국가철도공단', '/Comp/AnalysisCompView?ID=1056'),
#   ('국립공원공단', '/Comp/AnalysisCompView?ID=411'),
#   ('국립생태원', '/Comp/AnalysisCompView?ID=740'),
#   ('국민건강보험공단', '/Comp/AnalysisCompView?ID=1005'),
#   ('국민연금공단', '/Comp/AnalysisCompView?ID=1006'),
#   ('국토연구원', '/Comp/AnalysisCompView?ID=741'),
#   ('그랜드코리아레저', '/Comp/AnalysisCompView?ID=1007'),
#   ('근로복지공단', '/Comp/AnalysisCompView?ID=1050'),
#   ('기술보증기금', '/Comp/AnalysisCompView?ID=295'),
#   ('대구도시철도공사', '/Comp/AnalysisCompView?ID=309'),
#   ('대한무역투자진흥공사', '/Comp/AnalysisCompView?ID=1008'),
#   ('대한적십자사', '/Comp/AnalysisCompView?ID=664'),
#   ('도로교통공단', '/Comp/AnalysisCompView?ID=651'),
#   ('부산교통공사', '/Comp/AnalysisCompView?ID=646'),
#   ('부산항만공사', '/Comp/AnalysisCompView?ID=1009'),
#   ('삼천리', '/Comp/AnalysisCompView?ID=432'),
#   ('서울교통공사', '/Comp/AnalysisCompView?ID=1051'),
#   ('서울주택도시공사', '/Comp/AnalysisCompView?ID=1010'),
#   ('소상공인시장진흥공단', '/Comp/AnalysisCompView?ID=518'),
#   ('신용보증기금', '/Comp/AnalysisCompView?ID=265'),
#   ('에스알', '/Comp/AnalysisCompView?ID=713'),
#   ('여수광양항만공사', '/Comp/AnalysisCompView?ID=259'),
#   ('예금보험공사', '/Comp/AnalysisCompView?ID=1011'),
#   ('우체국금융개발원', '/Comp/AnalysisCompView?ID=298'),
#   ('울산항만공사', '/Comp/AnalysisCompView?ID=260'),
#   ('인천교통공사', '/Comp/AnalysisCompView?ID=307'),
#   ('인천국제공항공사', '/Comp/AnalysisCompView?ID=1012'),
#   ('인천항만공사', '/Comp/AnalysisCompView?ID=670'),
#   ('정보통신산업진흥원', '/Comp/AnalysisCompView?ID=537'),
#   ('주택관리공단', '/Comp/AnalysisCompView?ID=490'),
#   ('주택도시보증공사', '/Comp/AnalysisCompView?ID=622'),
#   ('중소기업유통센터', '/Comp/AnalysisCompView?ID=538'),
#   ('중소기업은행', '/Comp/AnalysisCompView?ID=118'),
#   ('중소벤처기업진흥공단', '/Comp/AnalysisCompView?ID=1013'),
#   ('코레일관광개발', '/Comp/AnalysisCompView?ID=1052'),
#   ('코레일네트웍스', '/Comp/AnalysisCompView?ID=448'),
#   ('코레일유통', '/Comp/AnalysisCompView?ID=543'),
#   ('코레일테크', '/Comp/AnalysisCompView?ID=1053'),
#   ('한국가스공사', '/Comp/AnalysisCompView?ID=1014'),
#   ('한국가스기술공사', '/Comp/AnalysisCompView?ID=548'),
#   ('한국가스안전공사', '/Comp/AnalysisCompView?ID=1016'),
#   ('한국공항공사', '/Comp/AnalysisCompView?ID=1253'),
#   ('한국과학기술원', '/Comp/AnalysisCompView?ID=810'),
#   ('한국관광공사', '/Comp/AnalysisCompView?ID=1054'),
#   ('한국광물자원공사', '/Comp/AnalysisCompView?ID=721'),
#   ('한국교육과정평가원', '/Comp/AnalysisCompView?ID=811'),
#   ('한국교통안전공단', '/Comp/AnalysisCompView?ID=658'),
#   ('한국국제협력단', '/Comp/AnalysisCompView?ID=302'),
#   ('한국국토정보공사', '/Comp/AnalysisCompView?ID=657'),
#   ('한국남동발전', '/Comp/AnalysisCompView?ID=1018'),
#   ('한국남부발전', '/Comp/AnalysisCompView?ID=1019'),
#   ('한국농수산식품유통공사', '/Comp/AnalysisCompView?ID=653'),
#   ('한국농어촌공사', '/Comp/AnalysisCompView?ID=1020'),
#   ('한국도로공사', '/Comp/AnalysisCompView?ID=1021'),
#   ('한국동서발전', '/Comp/AnalysisCompView?ID=1022'),
#   ('한국마사회', '/Comp/AnalysisCompView?ID=458'),
#   ('한국무역보험공사', '/Comp/AnalysisCompView?ID=204'),
#   ('한국문화정보원', '/Comp/AnalysisCompView?ID=812'),
#   ('한국방송통신전파진흥원', '/Comp/AnalysisCompView?ID=296'),
#   ('한국보훈복지의료공단', '/Comp/AnalysisCompView?ID=291'),
#   ('한국부동산원', '/Comp/AnalysisCompView?ID=549'),
#   ('한국산림복지진흥원', '/Comp/AnalysisCompView?ID=311'),
#   ('한국산업기술시험원', '/Comp/AnalysisCompView?ID=304'),
#   ('한국산업기술진흥원', '/Comp/AnalysisCompView?ID=662'),
#   ('한국산업기술평가관리원', '/Comp/AnalysisCompView?ID=655'),
#   ('한국산업단지공단', '/Comp/AnalysisCompView?ID=723'),
#   ('한국산업안전보건공단', '/Comp/AnalysisCompView?ID=1055'),
#   ('한국산업은행', '/Comp/AnalysisCompView?ID=1025'),
#   ('한국산업인력공단', '/Comp/AnalysisCompView?ID=1026'),
#   ('한국생산기술연구원', '/Comp/AnalysisCompView?ID=813'),
#   ('한국서부발전', '/Comp/AnalysisCompView?ID=1027'),
#   ('한국석유공사', '/Comp/AnalysisCompView?ID=1029'),
#   ('한국소비자원', '/Comp/AnalysisCompView?ID=1031'),
#   ('한국수력원자력', '/Comp/AnalysisCompView?ID=1033'),
#   ('한국수자원공사', '/Comp/AnalysisCompView?ID=1035'),
#   ('한국수출입은행', '/Comp/AnalysisCompView?ID=1036'),
#   ('한국승강기안전공단', '/Comp/AnalysisCompView?ID=659'),
#   ('한국에너지공단', '/Comp/AnalysisCompView?ID=652'),
#   ('한국예탁결제원', '/Comp/AnalysisCompView?ID=625'),
#   ('한국원자력안전기술원', '/Comp/AnalysisCompView?ID=1038'),
#   ('한국인터넷진흥원', '/Comp/AnalysisCompView?ID=1040'),
#   ('한국자산관리공사', '/Comp/AnalysisCompView?ID=1041'),
#   ('한국장애인고용공단', '/Comp/AnalysisCompView?ID=665'),
#   ('한국장학재단', '/Comp/AnalysisCompView?ID=555'),
#   ('한국재정정보원', '/Comp/AnalysisCompView?ID=626'),
#   ('한국전기안전공사', '/Comp/AnalysisCompView?ID=725'),
#   ('한국전력거래소', '/Comp/AnalysisCompView?ID=726'),
#   ('한국전력공사', '/Comp/AnalysisCompView?ID=831'),
#   ('한국전력기술', '/Comp/AnalysisCompView?ID=1042'),
#   ('한국전자통신연구원', '/Comp/AnalysisCompView?ID=815'),
#   ('한국조폐공사', '/Comp/AnalysisCompView?ID=1043'),
#   ('한국주택금융공사', '/Comp/AnalysisCompView?ID=1045'),
#   ('한국중부발전', '/Comp/AnalysisCompView?ID=1046'),
#   ('한국지역난방공사', '/Comp/AnalysisCompView?ID=556'),
#   ('한국철도공사', '/Comp/AnalysisCompView?ID=1252'),
#   ('한국토지주택공사', '/Comp/AnalysisCompView?ID=1049'),
#   ('한국투자공사', '/Comp/AnalysisCompView?ID=213'),
#   ('한국항공우주연구원', '/Comp/AnalysisCompView?ID=817'),
#   ('한국환경공단', '/Comp/AnalysisCompView?ID=217'),
#   ('한국환경정책평가연구원', '/Comp/AnalysisCompView?ID=818'),
#   ('한전KDN', '/Comp/AnalysisCompView?ID=1057'),
#   ('한전KPS', '/Comp/AnalysisCompView?ID=1058'),
#   ('해양환경공단', '/Comp/AnalysisCompView?ID=663')],
#  '한전계열사': [('한국남동발전', '/Comp/AnalysisCompView?ID=1018'),
#   ('한국남부발전', '/Comp/AnalysisCompView?ID=1019'),
#   ('한국동서발전', '/Comp/AnalysisCompView?ID=1022'),
#   ('한국서부발전', '/Comp/AnalysisCompView?ID=1027'),
#   ('한국전력공사', '/Comp/AnalysisCompView?ID=831'),
#   ('한국전력기술', '/Comp/AnalysisCompView?ID=1042'),
#   ('한국중부발전', '/Comp/AnalysisCompView?ID=1046'),
#   ('한전KDN', '/Comp/AnalysisCompView?ID=1057'),
#   ('한전KPS', '/Comp/AnalysisCompView?ID=1058')],
#  '금융공기업': [('신용보증기금', '/Comp/AnalysisCompView?ID=265'),
#   ('예금보험공사', '/Comp/AnalysisCompView?ID=1011'),
#   ('중소기업은행', '/Comp/AnalysisCompView?ID=118'),
#   ('한국산업은행', '/Comp/AnalysisCompView?ID=1025'),
#   ('한국수출입은행', '/Comp/AnalysisCompView?ID=1036'),
#   ('한국예탁결제원', '/Comp/AnalysisCompView?ID=625'),
#   ('한국자산관리공사', '/Comp/AnalysisCompView?ID=1041'),
#   ('한국재정정보원', '/Comp/AnalysisCompView?ID=626'),
#   ('한국조폐공사', '/Comp/AnalysisCompView?ID=1043'),
#   ('한국주택금융공사', '/Comp/AnalysisCompView?ID=1045'),
#   ('한국투자공사', '/Comp/AnalysisCompView?ID=213')]}

# %%
corpsInfo = [corp for corps in list(corpOfCategoryDict.values()) for corp in corps]
# 중복기업 제거
print('중복기업 제거:', len(corpsInfo), '->',len(set(corpsInfo)))
corpsInfo = list(set(corpsInfo))
corpsInfo
# Out:
# 중복기업 제거: 546 -> 453
# [('동부건설', '/Comp/AnalysisCompView?ID=1120'),
#  ('SK에코플랜트', '/Comp/AnalysisCompView?ID=1109'),
#  ('메리츠화재해상보험', '/Comp/AnalysisCompView?ID=336'),
#  ('교보문고', '/Comp/AnalysisCompView?ID=1140'),
#  ('HDC현대산업개발', '/Comp/AnalysisCompView?ID=729'),
#  ('넥센타이어', '/Comp/AnalysisCompView?ID=88'),
#  ('JW중외제약', '/Comp/AnalysisCompView?ID=1138'),
#  ('GS칼텍스', '/Comp/AnalysisCompView?ID=1083'),
#  ('에스엘', '/Comp/AnalysisCompView?ID=901'),
#  ('포스코ICT', '/Comp/AnalysisCompView?ID=1108'),
#  ('코스콤', '/Comp/AnalysisCompView?ID=800'),
#  ('아시아나항공', '/Comp/AnalysisCompView?ID=983'),
#  ('SK플래닛', '/Comp/AnalysisCompView?ID=1092'),
#  ('롯데정밀화학', '/Comp/AnalysisCompView?ID=969'),
#  ('롯데캐피탈', '/Comp/AnalysisCompView?ID=971'),
#  ('현대로템', '/Comp/AnalysisCompView?ID=929'),
#  ('대웅제약', '/Comp/AnalysisCompView?ID=1134'),
#  ('건강보험심사평가원', '/Comp/AnalysisCompView?ID=1004'),
#  ('진에어', '/Comp/AnalysisCompView?ID=988'),
#  ('코카콜라음료', '/Comp/AnalysisCompView?ID=1125'),
#  ('유한킴벌리', '/Comp/AnalysisCompView?ID=908'),
#  ('오비맥주', '/Comp/AnalysisCompView?ID=1128'),
#  ('무신사', '/Comp/AnalysisCompView?ID=1103'),
#  ('한국산업기술진흥원', '/Comp/AnalysisCompView?ID=662'),
#  ('예금보험공사', '/Comp/AnalysisCompView?ID=1011'),
#  ('교원', '/Comp/AnalysisCompView?ID=960'),
#  ('한국수자원공사', '/Comp/AnalysisCompView?ID=1035'),
#  ('한국인터넷진흥원', '/Comp/AnalysisCompView?ID=1040'),
#  ('코리안리재보험', '/Comp/AnalysisCompView?ID=799'),
#  ('하나금융투자', '/Comp/AnalysisCompView?ID=321'),
#  ('공무원연금공단', '/Comp/AnalysisCompView?ID=684'),
#  ('CJ ENM', '/Comp/AnalysisCompView?ID=848'),
#  ('우아한형제들', '/Comp/AnalysisCompView?ID=906'),
#  ('한국쓰리엠', '/Comp/AnalysisCompView?ID=666'),
#  ('SK케미칼', '/Comp/AnalysisCompView?ID=736'),
#  ('삼천리', '/Comp/AnalysisCompView?ID=432'),
#  ('데상트코리아', '/Comp/AnalysisCompView?ID=748'),
#  ('SK E&S;', '/Comp/AnalysisCompView?ID=714'),
#  ('만도', '/Comp/AnalysisCompView?ID=1136'),
#  ('KCC', '/Comp/AnalysisCompView?ID=855'),
#  ('대교', '/Comp/AnalysisCompView?ID=578'),
#  ('한국예탁결제원', '/Comp/AnalysisCompView?ID=625'),
#  ('신세계건설', '/Comp/AnalysisCompView?ID=774'),
#  ('그랜드코리아레저', '/Comp/AnalysisCompView?ID=1007'),
#  ('SK에너지', '/Comp/AnalysisCompView?ID=735'),
#  ('한국남동발전', '/Comp/AnalysisCompView?ID=1018'),
#  ('효성첨단소재', '/Comp/AnalysisCompView?ID=823'),
#  ('한국에너지공단', '/Comp/AnalysisCompView?ID=652'),
#  ('한국국토정보공사', '/Comp/AnalysisCompView?ID=657'),
#  ('국민연금공단', '/Comp/AnalysisCompView?ID=1006'),
#  ('신한카드', '/Comp/AnalysisCompView?ID=617'),
#  ('한국증권금융', '/Comp/AnalysisCompView?ID=994'),
#  ('한전KPS', '/Comp/AnalysisCompView?ID=1058'),
#  ('LG헬로비전', '/Comp/AnalysisCompView?ID=413'),
#  ('부산항만공사', '/Comp/AnalysisCompView?ID=1009'),
#  ('GS리테일', '/Comp/AnalysisCompView?ID=853'),
#  ('한국장애인고용공단', '/Comp/AnalysisCompView?ID=665'),
#  ('삼성전자로지텍', '/Comp/AnalysisCompView?ID=978'),
#  ('삼성중공업', '/Comp/AnalysisCompView?ID=515'),
#  ('한국자산관리공사', '/Comp/AnalysisCompView?ID=1041'),
#  ('한국후지필름비즈니스이노베이션', '/Comp/AnalysisCompView?ID=698'),
#  ('서울주택도시공사', '/Comp/AnalysisCompView?ID=1010'),
#  ('대우건설', '/Comp/AnalysisCompView?ID=1124'),
#  ('CJ CGV', '/Comp/AnalysisCompView?ID=1129'),
#  ('한국씨티은행', '/Comp/AnalysisCompView?ID=122'),
#  ('신한금융투자', '/Comp/AnalysisCompView?ID=836'),
#  ('현대제철', '/Comp/AnalysisCompView?ID=935'),
#  ('농협사료', '/Comp/AnalysisCompView?ID=395'),
#  ('KB증권', '/Comp/AnalysisCompView?ID=732'),
#  ('삼성물산', '/Comp/AnalysisCompView?ID=1151'),
#  ('애경산업', '/Comp/AnalysisCompView?ID=779'),
#  ('LG CNS', '/Comp/AnalysisCompView?ID=1067'),
#  ('한화갤러리아', '/Comp/AnalysisCompView?ID=926'),
#  ('한국산업기술시험원', '/Comp/AnalysisCompView?ID=304'),
#  ('GS홈쇼핑', '/Comp/AnalysisCompView?ID=1086'),
#  ('LS전선', '/Comp/AnalysisCompView?ID=952'),
#  ('파리크라상', '/Comp/AnalysisCompView?ID=805'),
#  ('대상', '/Comp/AnalysisCompView?ID=1115'),
#  ('마이다스아이티', '/Comp/AnalysisCompView?ID=1073'),
#  ('SKC', '/Comp/AnalysisCompView?ID=955'),
#  ('키움증권', '/Comp/AnalysisCompView?ID=1097'),
#  ('한국서부발전', '/Comp/AnalysisCompView?ID=1027'),
#  ('코오롱인더스트리', '/Comp/AnalysisCompView?ID=915'),
#  ('한국수출입은행', '/Comp/AnalysisCompView?ID=1036'),
#  ('금호타이어', '/Comp/AnalysisCompView?ID=961'),
#  ('한화에어로스페이스', '/Comp/AnalysisCompView?ID=563'),
#  ('효성', '/Comp/AnalysisCompView?ID=1135'),
#  ('영원무역', '/Comp/AnalysisCompView?ID=787'),
#  ('대신증권', '/Comp/AnalysisCompView?ID=608'),
#  ('금호석유화학', '/Comp/AnalysisCompView?ID=838'),
#  ('동원F&B;', '/Comp/AnalysisCompView?ID=882'),
#  ('한국산업안전보건공단', '/Comp/AnalysisCompView?ID=1055'),
#  ('롯데알미늄', '/Comp/AnalysisCompView?ID=711'),
#  ('CJ푸드빌', '/Comp/AnalysisCompView?ID=494'),
#  ('신영증권', '/Comp/AnalysisCompView?ID=1121'),
#  ('대한무역투자진흥공사', '/Comp/AnalysisCompView?ID=1008'),
#  ('스마트스터디', '/Comp/AnalysisCompView?ID=772'),
#  ('도로교통공단', '/Comp/AnalysisCompView?ID=651'),
#  ('세아베스틸', '/Comp/AnalysisCompView?ID=51'),
#  ('쿠쿠홀딩스', '/Comp/AnalysisCompView?ID=174'),
#  ('한국지역난방공사', '/Comp/AnalysisCompView?ID=556'),
#  ('비테스코테크놀로지스코리아', '/Comp/AnalysisCompView?ID=639'),
#  ('DB생명보험', '/Comp/AnalysisCompView?ID=376'),
#  ('에이치케이이노엔', '/Comp/AnalysisCompView?ID=776'),
#  ('에어서울', '/Comp/AnalysisCompView?ID=785'),
#  ('한국부동산원', '/Comp/AnalysisCompView?ID=549'),
#  ('미래에셋증권', '/Comp/AnalysisCompView?ID=888'),
#  ('삼성엔지니어링', '/Comp/AnalysisCompView?ID=976'),
#  ('해양환경공단', '/Comp/AnalysisCompView?ID=663'),
#  ('E1', '/Comp/AnalysisCompView?ID=942'),
#  ('한화종합화학', '/Comp/AnalysisCompView?ID=564'),
#  ('KT', '/Comp/AnalysisCompView?ID=857'),
#  ('풀무원', '/Comp/AnalysisCompView?ID=1142'),
#  ('메리츠증권', '/Comp/AnalysisCompView?ID=759'),
#  ('효성중공업', '/Comp/AnalysisCompView?ID=822'),
#  ('인천교통공사', '/Comp/AnalysisCompView?ID=307'),
#  ('풍산', '/Comp/AnalysisCompView?ID=809'),
#  ('르노삼성자동차', '/Comp/AnalysisCompView?ID=511'),
#  ('아성다이소', '/Comp/AnalysisCompView?ID=1100'),
#  ('한국타이어앤테크놀로지', '/Comp/AnalysisCompView?ID=79'),
#  ('동아제약', '/Comp/AnalysisCompView?ID=749'),
#  ('포스코', '/Comp/AnalysisCompView?ID=825'),
#  ('한국교육과정평가원', '/Comp/AnalysisCompView?ID=811'),
#  ('한화', '/Comp/AnalysisCompView?ID=925'),
#  ('현대차증권', '/Comp/AnalysisCompView?ID=820'),
#  ('공영홈쇼핑', '/Comp/AnalysisCompView?ID=701'),
#  ('국립생태원', '/Comp/AnalysisCompView?ID=740'),
#  ('S-OIL', '/Comp/AnalysisCompView?ID=865'),
#  ('신도리코', '/Comp/AnalysisCompView?ID=585'),
#  ('한국재정정보원', '/Comp/AnalysisCompView?ID=626'),
#  ('경남은행', '/Comp/AnalysisCompView?ID=101'),
#  ('CJ대한통운', '/Comp/AnalysisCompView?ID=849'),
#  ('한국교통안전공단', '/Comp/AnalysisCompView?ID=658'),
#  ('이베이코리아', '/Comp/AnalysisCompView?ID=987'),
#  ('멀티캠퍼스', '/Comp/AnalysisCompView?ID=758'),
#  ('한국장학재단', '/Comp/AnalysisCompView?ID=555'),
#  ('한국환경정책평가연구원', '/Comp/AnalysisCompView?ID=818'),
#  ('깨끗한나라', '/Comp/AnalysisCompView?ID=743'),
#  ('한국투자증권', '/Comp/AnalysisCompView?ID=920'),
#  ('여수광양항만공사', '/Comp/AnalysisCompView?ID=259'),
#  ('서진산업', '/Comp/AnalysisCompView?ID=382'),
#  ('롯데건설', '/Comp/AnalysisCompView?ID=885'),
#  ('LG유플러스', '/Comp/AnalysisCompView?ID=860'),
#  ('LX하우시스', '/Comp/AnalysisCompView?ID=862'),
#  ('삼성바이오로직스', '/Comp/AnalysisCompView?ID=1084'),
#  ('LX판토스', '/Comp/AnalysisCompView?ID=806'),
#  ('코레일유통', '/Comp/AnalysisCompView?ID=543'),
#  ('한화건설', '/Comp/AnalysisCompView?ID=561'),
#  ('롯데케미칼', '/Comp/AnalysisCompView?ID=887'),
#  ('한국교육방송공사', '/Comp/AnalysisCompView?ID=644'),
#  ('종근당', '/Comp/AnalysisCompView?ID=1119'),
#  ('한섬', '/Comp/AnalysisCompView?ID=1133'),
#  ('유진투자증권', '/Comp/AnalysisCompView?ID=1127'),
#  ('한국전력기술', '/Comp/AnalysisCompView?ID=1042'),
#  ('한국수력원자력', '/Comp/AnalysisCompView?ID=1033'),
#  ('셀트리온', '/Comp/AnalysisCompView?ID=1123'),
#  ('스타벅스커피코리아', '/Comp/AnalysisCompView?ID=896'),
#  ('GS건설', '/Comp/AnalysisCompView?ID=840'),
#  ('라인프렌즈', '/Comp/AnalysisCompView?ID=753'),
#  ('SK텔레콤', '/Comp/AnalysisCompView?ID=868'),
#  ('오렌지라이프생명보험', '/Comp/AnalysisCompView?ID=365'),
#  ('한국토지주택공사', '/Comp/AnalysisCompView?ID=1049'),
#  ('현대해상화재보험', '/Comp/AnalysisCompView?ID=631'),
#  ('딜리버리히어로코리아', '/Comp/AnalysisCompView?ID=883'),
#  ('크라운제과', '/Comp/AnalysisCompView?ID=802'),
#  ('인천항만공사', '/Comp/AnalysisCompView?ID=670'),
#  ('현대홈쇼핑', '/Comp/AnalysisCompView?ID=937'),
#  ('유한양행', '/Comp/AnalysisCompView?ID=1112'),
#  ('제이티비씨', '/Comp/AnalysisCompView?ID=795'),
#  ('도레이첨단소재', '/Comp/AnalysisCompView?ID=965'),
#  ('한국농어촌공사', '/Comp/AnalysisCompView?ID=1020'),
#  ('두산', '/Comp/AnalysisCompView?ID=966'),
#  ('웅진씽크빅', '/Comp/AnalysisCompView?ID=599'),
#  ('삼성웰스토리', '/Comp/AnalysisCompView?ID=1152'),
#  ('카카오뱅크', '/Comp/AnalysisCompView?ID=1094'),
#  ('한국마사회', '/Comp/AnalysisCompView?ID=458'),
#  ('수협은행', '/Comp/AnalysisCompView?ID=771'),
#  ('세아상역', '/Comp/AnalysisCompView?ID=894'),
#  ('롯데렌탈', '/Comp/AnalysisCompView?ID=699'),
#  ('코레일테크', '/Comp/AnalysisCompView?ID=1053'),
#  ('삼성증권', '/Comp/AnalysisCompView?ID=1113'),
#  ('국립공원공단', '/Comp/AnalysisCompView?ID=411'),
#  ('비상교육', '/Comp/AnalysisCompView?ID=764'),
#  ('한국승강기안전공단', '/Comp/AnalysisCompView?ID=659'),
#  ('광주은행', '/Comp/AnalysisCompView?ID=352'),
#  ('중소벤처기업진흥공단', '/Comp/AnalysisCompView?ID=1013'),
#  ('한국방송공사', '/Comp/AnalysisCompView?ID=1024'),
#  ('신한라이프생명보험', '/Comp/AnalysisCompView?ID=677'),
#  ('신용보증기금', '/Comp/AnalysisCompView?ID=265'),
#  ('골프존', '/Comp/AnalysisCompView?ID=737'),
#  ('한국가스안전공사', '/Comp/AnalysisCompView?ID=1016'),
#  ('한화손해보험', '/Comp/AnalysisCompView?ID=628'),
#  ('에릭슨엘지', '/Comp/AnalysisCompView?ID=780'),
#  ('동서식품', '/Comp/AnalysisCompView?ID=881'),
#  ('한국소비자원', '/Comp/AnalysisCompView?ID=1031'),
#  ('샘표식품', '/Comp/AnalysisCompView?ID=1132'),
#  ('하이투자증권', '/Comp/AnalysisCompView?ID=354'),
#  ('현대그린푸드', '/Comp/AnalysisCompView?ID=928'),
#  ('비씨카드', '/Comp/AnalysisCompView?ID=611'),
#  ('한국무역보험공사', '/Comp/AnalysisCompView?ID=204'),
#  ('한국산업인력공단', '/Comp/AnalysisCompView?ID=1026'),
#  ('한국과학기술원', '/Comp/AnalysisCompView?ID=810'),
#  ('한성자동차', '/Comp/AnalysisCompView?ID=383'),
#  ('광동제약', '/Comp/AnalysisCompView?ID=738'),
#  ('S&I;', '/Comp/AnalysisCompView?ID=1114'),
#  ('한국산업은행', '/Comp/AnalysisCompView?ID=1025'),
#  ('현대모비스', '/Comp/AnalysisCompView?ID=930'),
#  ('이수페타시스', '/Comp/AnalysisCompView?ID=536'),
#  ('매일홀딩스', '/Comp/AnalysisCompView?ID=682'),
#  ('한국투자공사', '/Comp/AnalysisCompView?ID=213'),
#  ('롯데쇼핑', '/Comp/AnalysisCompView?ID=1095'),
#  ('쌍용건설', '/Comp/AnalysisCompView?ID=775'),
#  ('동우화인켐', '/Comp/AnalysisCompView?ID=508'),
#  ('티웨이항공', '/Comp/AnalysisCompView?ID=451'),
#  ('한국원자력안전기술원', '/Comp/AnalysisCompView?ID=1038'),
#  ('엔씨소프트', '/Comp/AnalysisCompView?ID=1080'),
#  ('서울교통공사', '/Comp/AnalysisCompView?ID=1051'),
#  ('한국석유공사', '/Comp/AnalysisCompView?ID=1029'),
#  ('현대트랜시스', '/Comp/AnalysisCompView?ID=1170'),
#  ('코리아세븐', '/Comp/AnalysisCompView?ID=913'),
#  ('한국도로공사', '/Comp/AnalysisCompView?ID=1021'),
#  ('흥국화재해상보험', '/Comp/AnalysisCompView?ID=339'),
#  ('비바리퍼블리카', '/Comp/AnalysisCompView?ID=763'),
#  ('네오위즈', '/Comp/AnalysisCompView?ID=744'),
#  ('코스맥스', '/Comp/AnalysisCompView?ID=1088'),
#  ('NHN', '/Comp/AnalysisCompView?ID=1098'),
#  ('팜한농', '/Comp/AnalysisCompView?ID=546'),
#  ('한국가스기술공사', '/Comp/AnalysisCompView?ID=548'),
#  ('노랑풍선', '/Comp/AnalysisCompView?ID=746'),
#  ('국토연구원', '/Comp/AnalysisCompView?ID=741'),
#  ('한국산업기술평가관리원', '/Comp/AnalysisCompView?ID=655'),
#  ('HDC신라면세점', '/Comp/AnalysisCompView?ID=786'),
#  ('인천국제공항공사', '/Comp/AnalysisCompView?ID=1012'),
#  ('정보통신산업진흥원', '/Comp/AnalysisCompView?ID=537'),
#  ('DB금융투자', '/Comp/AnalysisCompView?ID=604'),
#  ('한국인삼공사', '/Comp/AnalysisCompView?ID=814'),
#  ('신세계푸드', '/Comp/AnalysisCompView?ID=981'),
#  ('세스코', '/Comp/AnalysisCompView?ID=770'),
#  ('한국보훈복지의료공단', '/Comp/AnalysisCompView?ID=291'),
#  ('한국생산기술연구원', '/Comp/AnalysisCompView?ID=813'),
#  ('한화호텔앤드리조트', '/Comp/AnalysisCompView?ID=996'),
#  ('금호건설', '/Comp/AnalysisCompView?ID=500'),
#  ('한국농수산식품유통공사', '/Comp/AnalysisCompView?ID=653'),
#  ('한국조폐공사', '/Comp/AnalysisCompView?ID=1043'),
#  ('현대건설', '/Comp/AnalysisCompView?ID=824'),
#  ('삼성SDI', '/Comp/AnalysisCompView?ID=890'),
#  ('한양', '/Comp/AnalysisCompView?ID=390'),
#  ('한국남부발전', '/Comp/AnalysisCompView?ID=1019'),
#  ('삼성전자', '/Comp/AnalysisCompView?ID=1065'),
#  ('메트라이프생명보험', '/Comp/AnalysisCompView?ID=375'),
#  ('한화솔루션', '/Comp/AnalysisCompView?ID=927'),
#  ('중소기업유통센터', '/Comp/AnalysisCompView?ID=538'),
#  ('비알코리아', '/Comp/AnalysisCompView?ID=973'),
#  ('고려아연', '/Comp/AnalysisCompView?ID=959'),
#  ('아모레퍼시픽', '/Comp/AnalysisCompView?ID=982'),
#  ('삼성디스플레이', '/Comp/AnalysisCompView?ID=975'),
#  ('코레일네트웍스', '/Comp/AnalysisCompView?ID=448'),
#  ('국민건강보험공단', '/Comp/AnalysisCompView?ID=1005'),
#  ('근로복지공단', '/Comp/AnalysisCompView?ID=1050'),
#  ('DB손해보험', '/Comp/AnalysisCompView?ID=680'),
#  ('악사손해보험', '/Comp/AnalysisCompView?ID=619'),
#  ('효성TNS', '/Comp/AnalysisCompView?ID=694'),
#  ('중앙일보', '/Comp/AnalysisCompView?ID=796'),
#  ('웹젠', '/Comp/AnalysisCompView?ID=790'),
#  ('현대백화점', '/Comp/AnalysisCompView?ID=931'),
#  ('한전KDN', '/Comp/AnalysisCompView?ID=1057'),
#  ('파라다이스', '/Comp/AnalysisCompView?ID=804'),
#  ('현대카드', '/Comp/AnalysisCompView?ID=1093'),
#  ('우리카드', '/Comp/AnalysisCompView?ID=356'),
#  ('하나투어', '/Comp/AnalysisCompView?ID=453'),
#  ('현대케피코', '/Comp/AnalysisCompView?ID=572'),
#  ('서희건설', '/Comp/AnalysisCompView?ID=769'),
#  ('한국국제협력단', '/Comp/AnalysisCompView?ID=302'),
#  ('카카오', '/Comp/AnalysisCompView?ID=1076'),
#  ('한독모터스', '/Comp/AnalysisCompView?ID=384'),
#  ('한국항공우주산업', '/Comp/AnalysisCompView?ID=921'),
#  ('대학내일', '/Comp/AnalysisCompView?ID=747'),
#  ('LX MMA', '/Comp/AnalysisCompView?ID=530'),
#  ('이마트24', '/Comp/AnalysisCompView?ID=793'),
#  ('포스코에너지', '/Comp/AnalysisCompView?ID=719'),
#  ('국가철도공단', '/Comp/AnalysisCompView?ID=1056'),
#  ('현대엔지니어링', '/Comp/AnalysisCompView?ID=641'),
#  ('SK브로드밴드', '/Comp/AnalysisCompView?ID=866'),
#  ('현대글로비스', '/Comp/AnalysisCompView?ID=1130'),
#  ('롯데제과', '/Comp/AnalysisCompView?ID=755'),
#  ('한국광물자원공사', '/Comp/AnalysisCompView?ID=721'),
#  ('한국관광공사', '/Comp/AnalysisCompView?ID=1054'),
#  ('퍼시스그룹', '/Comp/AnalysisCompView?ID=1071'),
#  ('한국산업단지공단', '/Comp/AnalysisCompView?ID=723'),
#  ('농심', '/Comp/AnalysisCompView?ID=1126'),
#  ('현대위아', '/Comp/AnalysisCompView?ID=999'),
#  ('울산항만공사', '/Comp/AnalysisCompView?ID=260'),
#  ('한국철도공사', '/Comp/AnalysisCompView?ID=1252'),
#  ('포스코케미칼', '/Comp/AnalysisCompView?ID=990'),
#  ('GS엔텍', '/Comp/AnalysisCompView?ID=797'),
#  ('현대오토에버', '/Comp/AnalysisCompView?ID=998'),
#  ('기아', '/Comp/AnalysisCompView?ID=871'),
#  ('제이와이피엔터테인먼트', '/Comp/AnalysisCompView?ID=731'),
#  ('국민은행', '/Comp/AnalysisCompView?ID=869'),
#  ('하나카드', '/Comp/AnalysisCompView?ID=374'),
#  ('푸본현대생명보험', '/Comp/AnalysisCompView?ID=807'),
#  ('대한항공', '/Comp/AnalysisCompView?ID=880'),
#  ('LF', '/Comp/AnalysisCompView?ID=1131'),
#  ('두산인프라코어', '/Comp/AnalysisCompView?ID=967'),
#  ('한국가스공사', '/Comp/AnalysisCompView?ID=1014'),
#  ('현대파워텍', '/Comp/AnalysisCompView?ID=120'),
#  ('풀무원식품', '/Comp/AnalysisCompView?ID=808'),
#  ('이랜드월드', '/Comp/AnalysisCompView?ID=1148'),
#  ('코레일관광개발', '/Comp/AnalysisCompView?ID=1052'),
#  ('현대엘리베이터', '/Comp/AnalysisCompView?ID=932'),
#  ('컴투스', '/Comp/AnalysisCompView?ID=912'),
#  ('신성통상', '/Comp/AnalysisCompView?ID=773'),
#  ('야놀자', '/Comp/AnalysisCompView?ID=984'),
#  ('라인플러스', '/Comp/AnalysisCompView?ID=968'),
#  ('SK하이닉스', '/Comp/AnalysisCompView?ID=830'),
#  ('한국전기안전공사', '/Comp/AnalysisCompView?ID=725'),
#  ('한국산림복지진흥원', '/Comp/AnalysisCompView?ID=311'),
#  ('SK네트웍스', '/Comp/AnalysisCompView?ID=956'),
#  ('티캐스트', '/Comp/AnalysisCompView?ID=803'),
#  ('이수화학', '/Comp/AnalysisCompView?ID=1143'),
#  ('농협은행', '/Comp/AnalysisCompView?ID=1118'),
#  ('한국문화정보원', '/Comp/AnalysisCompView?ID=812'),
#  ('KG동부제철', '/Comp/AnalysisCompView?ID=487'),
#  ('이랜드리테일', '/Comp/AnalysisCompView?ID=1091'),
#  ('새마을금고중앙회', '/Comp/AnalysisCompView?ID=137'),
#  ('한국공항공사', '/Comp/AnalysisCompView?ID=1253'),
#  ('하나은행', '/Comp/AnalysisCompView?ID=917'),
#  ('부산교통공사', '/Comp/AnalysisCompView?ID=646'),
#  ('나스미디어', '/Comp/AnalysisCompView?ID=1110'),
#  ('삼성생명보험', '/Comp/AnalysisCompView?ID=891'),
#  ('삼성전기', '/Comp/AnalysisCompView?ID=977'),
#  ('한국전자통신연구원', '/Comp/AnalysisCompView?ID=815'),
#  ('주택관리공단', '/Comp/AnalysisCompView?ID=490'),
#  ('한국동서발전', '/Comp/AnalysisCompView?ID=1022'),
#  ('한세실업', '/Comp/AnalysisCompView?ID=819'),
#  ('한화글로벌에셋', '/Comp/AnalysisCompView?ID=691'),
#  ('빙그레', '/Comp/AnalysisCompView?ID=889'),
#  ('한국필립모리스', '/Comp/AnalysisCompView?ID=671'),
#  ('하이트진로', '/Comp/AnalysisCompView?ID=918'),
#  ('롯데손해보험', '/Comp/AnalysisCompView?ID=338'),
#  ('한라', '/Comp/AnalysisCompView?ID=590'),
#  ('KB손해보험', '/Comp/AnalysisCompView?ID=1105'),
#  ('동국제강', '/Comp/AnalysisCompView?ID=270'),
#  ('이스타항공', '/Comp/AnalysisCompView?ID=794'),
#  ('LG이노텍', '/Comp/AnalysisCompView?ID=861'),
#  ('기술보증기금', '/Comp/AnalysisCompView?ID=295'),
#  ('삼양식품', '/Comp/AnalysisCompView?ID=766'),
#  ('미래에셋생명보험', '/Comp/AnalysisCompView?ID=364'),
#  ('제일기획', '/Comp/AnalysisCompView?ID=1068'),
#  ('한국아이비엠', '/Comp/AnalysisCompView?ID=992'),
#  ('신한은행', '/Comp/AnalysisCompView?ID=1082'),
#  ('CJ프레시웨이', '/Comp/AnalysisCompView?ID=851'),
#  ('한국항공우주연구원', '/Comp/AnalysisCompView?ID=817'),
#  ('주택도시보증공사', '/Comp/AnalysisCompView?ID=622'),
#  ('SBS', '/Comp/AnalysisCompView?ID=1087'),
#  ('LG생활건강', '/Comp/AnalysisCompView?ID=859'),
#  ('대구도시철도공사', '/Comp/AnalysisCompView?ID=309'),
#  ('현대미포조선', '/Comp/AnalysisCompView?ID=640'),
#  ('제주항공', '/Comp/AnalysisCompView?ID=441'),
#  ('디엘', '/Comp/AnalysisCompView?ID=1144'),
#  ('카카오게임즈', '/Comp/AnalysisCompView?ID=798'),
#  ('롯데글로벌로지스', '/Comp/AnalysisCompView?ID=754'),
#  ('우리은행', '/Comp/AnalysisCompView?ID=1107'),
#  ('넷마블', '/Comp/AnalysisCompView?ID=1101'),
#  ('캐논코리아비즈니스솔루션', '/Comp/AnalysisCompView?ID=703'),
#  ('삼양사', '/Comp/AnalysisCompView?ID=151'),
#  ('현대오일뱅크', '/Comp/AnalysisCompView?ID=933'),
#  ('SPC삼립', '/Comp/AnalysisCompView?ID=957'),
#  ('DB하이텍', '/Comp/AnalysisCompView?ID=1141'),
#  ('NH투자증권', '/Comp/AnalysisCompView?ID=620'),
#  ('두산건설', '/Comp/AnalysisCompView?ID=581'),
#  ('롯데카드', '/Comp/AnalysisCompView?ID=609'),
#  ('신세계', '/Comp/AnalysisCompView?ID=897'),
#  ('hy', '/Comp/AnalysisCompView?ID=919'),
#  ('대구은행', '/Comp/AnalysisCompView?ID=107'),
#  ('OCI', '/Comp/AnalysisCompView?ID=954'),
#  ('삼성카드', '/Comp/AnalysisCompView?ID=613'),
#  ('한화투자증권', '/Comp/AnalysisCompView?ID=629'),
#  ('CJ제일제당', '/Comp/AnalysisCompView?ID=1122'),
#  ('한국중부발전', '/Comp/AnalysisCompView?ID=1046'),
#  ('강원랜드', '/Comp/AnalysisCompView?ID=1002'),
#  ('삼성SDS', '/Comp/AnalysisCompView?ID=974'),
#  ('한진', '/Comp/AnalysisCompView?ID=924'),
#  ('넥슨코리아', '/Comp/AnalysisCompView?ID=963'),
#  ('에프알엘코리아', '/Comp/AnalysisCompView?ID=527'),
#  ('네오플', '/Comp/AnalysisCompView?ID=1102'),
#  ('호텔신라', '/Comp/AnalysisCompView?ID=1174'),
#  ('오스템임플란트', '/Comp/AnalysisCompView?ID=788'),
#  ('SK이노베이션', '/Comp/AnalysisCompView?ID=867'),
#  ('호텔롯데', '/Comp/AnalysisCompView?ID=1001'),
#  ('오뚜기', '/Comp/AnalysisCompView?ID=1081'),
#  ('삼성화재해상보험', '/Comp/AnalysisCompView?ID=614'),
#  ('효성ITX', '/Comp/AnalysisCompView?ID=700'),
#  ('세아특수강', '/Comp/AnalysisCompView?ID=489'),
#  ('포스코강판', '/Comp/AnalysisCompView?ID=718'),
#  ('매일유업', '/Comp/AnalysisCompView?ID=1139'),
#  ('한국콜마', '/Comp/AnalysisCompView?ID=1072'),
#  ('한국주택금융공사', '/Comp/AnalysisCompView?ID=1045'),
#  ('에스알', '/Comp/AnalysisCompView?ID=713'),
#  ('네이버', '/Comp/AnalysisCompView?ID=1147'),
#  ('한화토탈', '/Comp/AnalysisCompView?ID=565'),
#  ('한국스탠다드차타드은행', '/Comp/AnalysisCompView?ID=278'),
#  ('농협하나로유통', '/Comp/AnalysisCompView?ID=835'),
#  ('소상공인시장진흥공단', '/Comp/AnalysisCompView?ID=518'),
#  ('푸르덴셜생명보험', '/Comp/AnalysisCompView?ID=1061'),
#  ('한화시스템', '/Comp/AnalysisCompView?ID=562'),
#  ('이노션', '/Comp/AnalysisCompView?ID=1116'),
#  ('한국환경공단', '/Comp/AnalysisCompView?ID=217'),
#  ('이마트', '/Comp/AnalysisCompView?ID=909'),
#  ('LS일렉트릭', '/Comp/AnalysisCompView?ID=951'),
#  ('보령제약', '/Comp/AnalysisCompView?ID=762'),
#  ('CJ올리브네트웍스', '/Comp/AnalysisCompView?ID=1104'),
#  ('에어부산', '/Comp/AnalysisCompView?ID=784'),
#  ('한미약품', '/Comp/AnalysisCompView?ID=843'),
#  ('삼천리자전거', '/Comp/AnalysisCompView?ID=516'),
#  ('BGF리테일', '/Comp/AnalysisCompView?ID=1085'),
#  ('미래에셋자산운용', '/Comp/AnalysisCompView?ID=761'),
#  ('현대자동차', '/Comp/AnalysisCompView?ID=1075'),
#  ('흥국생명보험', '/Comp/AnalysisCompView?ID=633'),
#  ('홈플러스', '/Comp/AnalysisCompView?ID=574'),
#  ('교보생명보험', '/Comp/AnalysisCompView?ID=1137'),
#  ('디에이치엘코리아', '/Comp/AnalysisCompView?ID=752'),
#  ('한국전력공사', '/Comp/AnalysisCompView?ID=831'),
#  ('KB캐피탈', '/Comp/AnalysisCompView?ID=351'),
#  ('한국방송통신전파진흥원', '/Comp/AnalysisCompView?ID=296'),
#  ('포스코건설', '/Comp/AnalysisCompView?ID=916'),
#  ('대한적십자사', '/Comp/AnalysisCompView?ID=664'),
#  ('GC녹십자', '/Comp/AnalysisCompView?ID=1117'),
#  ('LG디스플레이', '/Comp/AnalysisCompView?ID=1150'),
#  ('소노인터내셔널', '/Comp/AnalysisCompView?ID=471'),
#  ('부영주택', '/Comp/AnalysisCompView?ID=345'),
#  ('우체국금융개발원', '/Comp/AnalysisCompView?ID=298'),
#  ('현대캐피탈', '/Comp/AnalysisCompView?ID=821'),
#  ('모두투어네트워크', '/Comp/AnalysisCompView?ID=972'),
#  ('신세계인터내셔날', '/Comp/AnalysisCompView?ID=979'),
#  ('에스엠엔터테인먼트', '/Comp/AnalysisCompView?ID=1106'),
#  ('코웨이', '/Comp/AnalysisCompView?ID=989'),
#  ('부산은행', '/Comp/AnalysisCompView?ID=108'),
#  ('한국전력거래소', '/Comp/AnalysisCompView?ID=726'),
#  ('KT&G;', '/Comp/AnalysisCompView?ID=856'),
#  ('아모레퍼시픽그룹', '/Comp/AnalysisCompView?ID=777'),
#  ('LX인터내셔널', '/Comp/AnalysisCompView?ID=858'),
#  ('LG화학', '/Comp/AnalysisCompView?ID=1145'),
#  ('코오롱글로벌', '/Comp/AnalysisCompView?ID=67'),
#  ('한화생명보험', '/Comp/AnalysisCompView?ID=1111'),
#  ('두산중공업', '/Comp/AnalysisCompView?ID=583'),
#  ('중소기업은행', '/Comp/AnalysisCompView?ID=118'),
#  ('포스코인터내셔널', '/Comp/AnalysisCompView?ID=826'),
#  ('교보증권', '/Comp/AnalysisCompView?ID=342'),
#  ('조선호텔앤리조트', '/Comp/AnalysisCompView?ID=980'),
#  ('쿠팡', '/Comp/AnalysisCompView?ID=1074'),
#  ('LG전자', '/Comp/AnalysisCompView?ID=829'),
#  ('롯데칠성음료', '/Comp/AnalysisCompView?ID=970')]

# %% [markdown]
# ## 기업별 인재상 데이터 추출

# %% [markdown]
# **get_data()함수에서 사용된 case 종류**
# * 2개의 타입의 데이터가 있음 1. 테이블, 2. 동그라미 표
# * 1. 테이블 타입
#     * 제목이 인재상이고 소제목이 인재상 내용 (테이블자체가 인재상) - **case 1**
#     * 소제목에 인재상이 있고 소제목 오른쪽 내용에 인재상 내용이 적힌경우
#         * 인재상 내용이 dt dd 속성으로 이루어진 경우 - **case 2**
#         * p 속성으로 이루어진 경우 - (class:kind) - **case 3**
# * 2. 동그라미 표 타입
#     * 제목에 인재상이 적혀있는 경우 - **case 4**
#     * 제목에 인재상이 없지만 tag로 인재상이 적혀 있는 경우 - **case 5**
#     * 모두 div(class:subj) dd로 이루어짐

# %%
url2 = "https://www.catch.co.kr/Comp/AnalysisCompView?ID=975"
p = re.compile("#[^#]*")

# 기업분석의 기업 추구 가치 부분에서 사용된 주제 추출
def check_data(name, url):
    response = requests.get(url)
    question1 = []  # 큰 주제의 제목 (h4)
    question2 = []  # 소주제의 제목
    tagList = []
    
    if response.status_code == 200:
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        wantPeople = soup.find("div",{"id": "step41"})
        
        try:
            corpAnalysis = wantPeople.find_all("div", {"class":"anal_ht"})
            
        except:
            print("기업 문화는 어떨까? 부분이 없음", name)
            return name, None, None, -1

        for analysis in corpAnalysis:
            # 큰 주제 (h4에 해당)
            subject4 = analysis.find("h4")
            main_subject = p.sub('', subject4.get_text())
            tags = p.findall(subject4.get_text())
            
            question1.append(main_subject)
            tagList.extend([tag.strip() for tag in tags])


            # 작은 주제 TypeA처럼 table형식에서의 소주제
            table = analysis.find("tbody")

            try:
                contents = table.find_all("tr")
            except:
                contents = ""

            for content in contents:
                subSubject = content.find("span", {"class":"txt"})
                question2.append(subSubject.get_text())
                   
    else : 
        print(response.status_code)
    
    return question1, question2, tagList, 1

# 기업분석의 기업 추구 가치부분에서 특정 주제에 대한 내용 추출 - "인재"
def get_data(name, url, questions, tagList):
    response = requests.get(url)
    wantPeopleList = []
    wantPeopleList_b = []
    infoInTable = False    
    
    if response.status_code == 200:
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        wantPeople = soup.find("div",{"id": "step41"})
        
        try:
            corpAnalysis = wantPeople.find_all("div", {"class":"anal_ht"})
            
        except:
            print("기업 문화는 어떨까? 부분이 없음", name)
            return name, None, -1
        
        
        for analysis in corpAnalysis:
            tableFlag = False
            tagFlag = False
            
            # 작은 주제 TypeA처럼 table형식에서의 소주제
            table = analysis.find("tbody")
            if table is not None:
                tableFlag = True
                contents = table.find_all("tr")

                for content in contents:
                    subSubject = content.find("span", {"class":"txt"})

                    if subSubject.get_text() in questions:
                        infoInTable = True
                        TypeB_keyword = content.find_all("dt")
                        keywordB_describe = content.find_all("dd")
                        
                        # ********************* case 3 *********************
                        if len(TypeB_keyword) == 0 or len(keywordB_describe) == 0:
                            kind = content.find("div", {"class":"kind"})
                            if kind is not None:
                                kindList = kind.find_all("p")
                                for k in kindList:
                                    wantPeopleList_b.append(k.get_text())
                            else:
                                print("다른 경우 <1>({}) - {}".format(name, url))
                                
                        # ********************* case 2 *********************
                        for key, value in zip(TypeB_keyword, keywordB_describe):
                            wantPeopleList.append((key.get_text(), value.get_text()))
            
            
            # 큰 주제 (h4에 해당)
            subject4 = analysis.find("h4")
            main_subject = p.sub('', subject4.get_text())
            tags = p.findall(subject4.get_text())
            
            for tag in [tag.strip() for tag in tags]:
                if tag in tagList: 
                    tagFlag = True
                    
            if main_subject in questions:
                # ********************* case 1 *********************
                if tableFlag == True:
                    for content in contents:
                        kindList = content.find_all("div", {"class":"kind"})
                        for k in kindList:
                            attrPs = k.find_all("p")
                            for attrP in attrPs:
                                wantPeopleList_b.append(attrP.get_text())
                # ********************* case 4 *********************
                else:
                    TypeA_keyword = analysis.find_all("div", {"class":"subj"})
                    keywordA_describe = analysis.find_all("dd")
                    if len(TypeA_keyword) == 0 or len(keywordA_describe) == 0:
                        print("다른 경우 <2>({}) - {}".format(name, url))
                        
                    for key, value in zip(TypeA_keyword, keywordA_describe):
                            wantPeopleList.append((key.get_text(), value.get_text()))
            # ********************* case 5 *********************                
            elif tagFlag:
                if tableFlag != True:
                    TypeA_keyword = analysis.find_all("div", {"class":"subj"})
                    keywordA_describe = analysis.find_all("dd")
                    if len(TypeA_keyword) == 0 or len(keywordA_describe) == 0:
                        print("다른 경우 <3>({}) - {}".format(name, url))
                        
                    for key, value in zip(TypeA_keyword, keywordA_describe):
                            wantPeopleList.append((key.get_text(), value.get_text()))
                
    else : 
        print(response.status_code)
    
    return wantPeopleList, wantPeopleList_b, 1

# %%
noDataCorp = []
questions1 = []
questions2 = []
tagList = []

for name, url in corpsInfo:
    url = "https://www.catch.co.kr" + url
    q1, q2, tags, state = check_data(name, url)
    if state == -1:
        # 기업분석이 없는 기업이름 저장
        noDataCorp.append(q1)
    else:
        questions1.extend(q1)
        questions2.extend(q2)
        tagList.extend(tags)
# Out:
# 기업 문화는 어떨까? 부분이 없음 메리츠화재해상보험
# 기업 문화는 어떨까? 부분이 없음 현대로템
# 기업 문화는 어떨까? 부분이 없음 한국산업기술진흥원
# 기업 문화는 어떨까? 부분이 없음 하나금융투자
# 기업 문화는 어떨까? 부분이 없음 한국쓰리엠
# 기업 문화는 어떨까? 부분이 없음 그랜드코리아레저
# 기업 문화는 어떨까? 부분이 없음 한전KPS
# 기업 문화는 어떨까? 부분이 없음 삼성중공업
# 기업 문화는 어떨까? 부분이 없음 한국자산관리공사
# 기업 문화는 어떨까? 부분이 없음 신한금융투자
# 기업 문화는 어떨까? 부분이 없음 한화에어로스페이스
# 기업 문화는 어떨까? 부분이 없음 동원F&B;
# 기업 문화는 어떨까? 부분이 없음 스마트스터디
# 기업 문화는 어떨까? 부분이 없음 도로교통공단
# 기업 문화는 어떨까? 부분이 없음 한국지역난방공사
# 기업 문화는 어떨까? 부분이 없음 비테스코테크놀로지스코리아
# 기업 문화는 어떨까? 부분이 없음 미래에셋증권
# 기업 문화는 어떨까? 부분이 없음 인천교통공사
# 기업 문화는 어떨까? 부분이 없음 S-OIL
# 기업 문화는 어떨까? 부분이 없음 한국장학재단
# 기업 문화는 어떨까? 부분이 없음 한국투자증권
# 기업 문화는 어떨까? 부분이 없음 LX하우시스
# 기업 문화는 어떨까? 부분이 없음 코레일유통
# 기업 문화는 어떨까? 부분이 없음 한화건설
# 기업 문화는 어떨까? 부분이 없음 롯데케미칼
# 기업 문화는 어떨까? 부분이 없음 한국승강기안전공단
# 기업 문화는 어떨까? 부분이 없음 광주은행
# 기업 문화는 어떨까? 부분이 없음 한국가스안전공사
# 기업 문화는 어떨까? 부분이 없음 에릭슨엘지
# 기업 문화는 어떨까? 부분이 없음 동서식품
# 기업 문화는 어떨까? 부분이 없음 하이투자증권
# 기업 문화는 어떨까? 부분이 없음 한국산업은행
# 기업 문화는 어떨까? 부분이 없음 한국도로공사
# 기업 문화는 어떨까? 부분이 없음 네오위즈
# 기업 문화는 어떨까? 부분이 없음 팜한농
# 기업 문화는 어떨까? 부분이 없음 한국가스기술공사
# 기업 문화는 어떨까? 부분이 없음 정보통신산업진흥원
# 기업 문화는 어떨까? 부분이 없음 삼성SDI
# 기업 문화는 어떨까? 부분이 없음 중소기업유통센터
# 기업 문화는 어떨까? 부분이 없음 현대케피코
# 기업 문화는 어떨까? 부분이 없음 한국국제협력단
# 기업 문화는 어떨까? 부분이 없음 한국항공우주산업
# 기업 문화는 어떨까? 부분이 없음 SK브로드밴드
# 기업 문화는 어떨까? 부분이 없음 제이와이피엔터테인먼트
# 기업 문화는 어떨까? 부분이 없음 국민은행
# 기업 문화는 어떨까? 부분이 없음 푸본현대생명보험
# 기업 문화는 어떨까? 부분이 없음 현대엘리베이터
# 기업 문화는 어떨까? 부분이 없음 SK하이닉스
# 기업 문화는 어떨까? 부분이 없음 KG동부제철
# 기업 문화는 어떨까? 부분이 없음 하나은행
# 기업 문화는 어떨까? 부분이 없음 삼성전기
# 기업 문화는 어떨까? 부분이 없음 롯데손해보험
# 기업 문화는 어떨까? 부분이 없음 LG이노텍
# 기업 문화는 어떨까? 부분이 없음 LG생활건강
# 기업 문화는 어떨까? 부분이 없음 캐논코리아비즈니스솔루션
# 기업 문화는 어떨까? 부분이 없음 두산건설
# 기업 문화는 어떨까? 부분이 없음 한진
# 기업 문화는 어떨까? 부분이 없음 에프알엘코리아
# 기업 문화는 어떨까? 부분이 없음 SK이노베이션
# 기업 문화는 어떨까? 부분이 없음 포스코강판
# 기업 문화는 어떨까? 부분이 없음 한국스탠다드차타드은행
# 기업 문화는 어떨까? 부분이 없음 농협하나로유통
# 기업 문화는 어떨까? 부분이 없음 소상공인시장진흥공단
# 기업 문화는 어떨까? 부분이 없음 한화시스템
# 기업 문화는 어떨까? 부분이 없음 한국환경공단
# 기업 문화는 어떨까? 부분이 없음 홈플러스
# 기업 문화는 어떨까? 부분이 없음 KB캐피탈
# 기업 문화는 어떨까? 부분이 없음 한국방송통신전파진흥원
# 기업 문화는 어떨까? 부분이 없음 포스코건설
# 기업 문화는 어떨까? 부분이 없음 대한적십자사
# 기업 문화는 어떨까? 부분이 없음 현대캐피탈
# 기업 문화는 어떨까? 부분이 없음 KT&G;
# 기업 문화는 어떨까? 부분이 없음 LX인터내셔널
# 기업 문화는 어떨까? 부분이 없음 코오롱글로벌
# 기업 문화는 어떨까? 부분이 없음 두산중공업
# 기업 문화는 어떨까? 부분이 없음 교보증권

# %% [markdown]
# * 인재상 특이 문항
#     * 삼천리 : 어떤 인재를 원할까?'사랑'을 품은 열정인
#     * 코카콜라음료 : we want THIS

# %%
# 기업 분석이 있는 기업들만 저장
yesDataCorp = []
for corp in corpsInfo:
    if not (corp[0] in noDataCorp):
        yesDataCorp.append(corp)

# %%
questions1 = list(set(questions1))
questions2 = list(set(questions2))
tagList = list(set(tagList))
print("큰주제의 종류 개수: ", len(questions1))
print("소주제의 종류 개수: ", len(questions2))
print("tag의 종류 개수: ", len(questions2))
# Out:
# 큰주제의 종류 개수:  29
# 소주제의 종류 개수:  174
# tag의 종류 개수:  174

# %%
wantQ1 = [i for i in questions1 if ('인재' in i) or ('want' in i)]
wantQ2 = [i for i in questions2 if '인재' in i]
wantTag = [i for i in tagList if '인재' in i]
print(wantQ1)
print(wantQ2)
print(wantTag)
# Out:
# ['어떤 인재를 원할까?', "어떤 인재를 원할까?'사랑'을 품은 열정인", 'We want THIS', '인재상']
# ['인재상', '어떤 인재를 원할까?']
# ['#인재상', '#신통한인재', '#현대백화점그룹 인재상', '#상사부문_인재상', '#배려와 존중으로 상대방을 먼저 생각하는 창조적인 전문가형 인재']

# %%
wantQuestions = wantQ1 + wantQ2
wantQuestions = list(set(wantQuestions))
wantQuestions
# Out:
# ["어떤 인재를 원할까?'사랑'을 품은 열정인", '인재상', 'We want THIS', '어떤 인재를 원할까?']

# %%
wantPeopleList = []
wantPeopleList_b = []
wantPeople_dic = {}
wantPeople_b_dic = {}

for name, url in yesDataCorp:
    data, data_b = [], []
    url = "https://www.catch.co.kr" + url
    data, data_b, state = get_data(name, url, wantQuestions, wantTag)
    if state == -1:
        # 기업분석이 없는 기업이름 저장
        noDataCorp.append(data)
    else:
        #### data_b를 처리해야 됨
        wantPeopleList.extend(data)
        wantPeopleList_b.extend(data_b)
        if len(data_b) != 0:
            wantPeople_b_dic[name] = data_b
            
        wantPeople_dic[name] = data

# %% [markdown]
# ### 이상한 데이터 처리
# * p속성으로 추출한 데이터

# %%
# 이상한 데이터 확인
for name, value in wantPeople_b_dic.items():
    print(name)
    print(value)
    print()
# Out:
# JW중외제약
# ['Hi-Focuser', '생명존중과 개척정신을 계승한 Hi-Focuser는 환자 중심의 사고를 바탕으로 변화, 성장, 도전에 Focus하여 우리의 독보적 가치와 존재의 이유를 높이는 JW그룹의 인재상입니다.']
#
# SK플래닛
# ['', '1. 포장하지 말고, 본질가치에 집중하자.2. 현장에서 답을 찾고 실행한다.3. 주인의식으로 업무에 임한다.4. 고객보다 앞서 생각하고 제안한다.5. 기탄없이 비판하고 토론한다.']
#
# 삼성바이오로직스
# ['바이오 인재상', '회사 비전과 목표를 공유하며, 강한 열정과 책임감으로 해당분야 최고의 전문성과 실행력을 통해 성과창출을 극대화하고, 협업으로 집단지성을 추구하는 T자형 글로벌 인재']
#
# 셀트리온
# ['', '· 창의적인 사고와 발상의 전환을 통해 새로운 아이디어를 도출하고 문제를 해결하는 인재를 원합니다.· 생명을 중시하며 엄정한 책임의식을 바탕으로 원칙을 준수하는 인재를 원합니다.· 불굴의 도전정신을 가지고 업무에 임하며, 변화와 실패에 대한 두려움이 없는 인재를 원합니다.· 세계 시장을 무대로 경쟁하고, 셀트리온의 Vision을 실현할 수 있는 열정이 있는 인재를 원합니다.']
#
# 두산
# ['세계 속의 자랑스러운 두산두산 Credo의 아홉 가지 핵심 가치', '자랑스러운 두산이란, 임직원을 포함한 모든 이해관계자들이 두산을 통해 자부심과 자랑스러움을 느낀다는 의미입니다.']
#
# 삼성증권
# ['7 Pinciples : 성장과 행복을 위한 우리의 약속', '1. 우리는 형식보다 내용을 더 중요하게 생각합니다.2. 우리는 작은 것부터 변화를 시도합니다.3. 우리는 스스로 질문하며 더 나음을 고민합니다.4. 우리는 무엇이든 제대로 하기 위해 노력합니다.5. 우리는 권위의식 없이 소통하며 서로를 배려합니다.6. 우리는 안되는 이유 대신 되는 방법을 함께 찾습니다.7. 우리는 가족에게 부끄러운 일은 하지 않습니다.']
#
# 농심
# ['', '1. 충직農心은 天心충성스럽고 정직하게 자신의 업무를 수행하는 사람2. 도전最高로 큰 目標를 세워라실패를 두려워하지 않고 스스로를 극복하여 해내는 사람3. 창조"따라 하면 망한다."유연한 사고를 숙고하여 근본부터 뒤집어 볼 수 있는 사람', '', '1. 업무 전문가"구매, 개발, 생산 등 업무분야별 전문가"맡은 분야의 업무지식과 핵심역량을 갖추어 최고를 지향하는 사람2. 사업 전문가"면, 스낵, 음료, 상품 등 사업별 전문가"시장 통찰력과 올바른 전략으로 사업을 성공적으로 추진하는 사람3. Global 전문가"미국, 중국, 일본, 유럽 등 해외국가별 전문가"글로벌 업무 경쟁력을 바탕으로 글로벌 시장을 개척해내는 사람']
#
# 이수화학
# ['', '· 기본적인 생활과 업무수행에 있어서 조직의 핵심가치가 제시하는 원칙을 바탕으로 행동하는 이수인· 창의적이고 능동적인 이수인· 현재에 안주하지 않고, 늘 새로운 것에 대한 고민으로 창의적 열정이 가득한 이수인· 새로운 것을 적극적으로 제안하고 실행할 수 있는 추진력을 보유한 이수인· 언제나 성장하고 변화하는 이수인· 스스로의 성장하고자 하는 노력을 통해 개인과 조직의 발전에 기여하는 이수인· 개인의 혁신과 변화를 통해 조직의 변화를 주도하는 이수인']
#
# 디엘
# ['한숲人상', '· 새로운 것을 찾는다· 자기 일에 으뜸이 된다· 팀웍을 이룬다· 멀리 내려다본다· 고객을 잘안다· 약속을 지킨다· 근검절약을 한다']
#
# 우리은행
# ['올바른 품성을 가진, 도전적이고 창의적인 최고의 금융전문가', '']
#
# OCI
# ['OUR VALUES', '도전정신을 가지고 철저한 준비를 통해 기회를 포착하여 더 나은 미래를 위해 끊임없이 변화']
#
# LS일렉트릭
# ['Great Company', '고객에게 사랑받는 최고의 회사가 되어']
#
# LG화학
# ['꿈과 열정을 가지고 세계 최고에 도전하는 사람;팀웍을 이루며 자율적이고 창의적으로 일하는 사람;고객을 최우선으로 생각하고 끊임없이 혁신하는 사람;꾸준히 실력을 배양하여 정정당당하게 경쟁하는 사람', '']

# %%
# 이상한 데이터 수작업으로 진행
wantPeople_b_dic['LG화학'] = [("", "꿈과 열정을 가지고 세계 최고에 도전하는 사람"), 
                    ("", "팀웍을 이루며 자율적이고 창의적으로 일하는 사람"),
                    ("", "고객을 최우선으로 생각하고 끊임없이 혁신하는 사람"),
                    ("", "꾸준히 실력을 배양하여 정정당당하게 경쟁하는 사람")]

wantPeople_b_dic['셀트리온'] = [("", "창의적인 사고와 발상의 전환을 통해 새로운 아이디어를 도출하고 문제를 해결하는 인재"), 
                        ("", "생명을 중시하며 엄정한 책임의식을 바탕으로 원칙을 준수하는 인재"),
                        ("", "불굴의 도전정신을 가지고 업무에 임하며, 변화와 실패에 대한 두려움이 없는 인재"),
                        ("", "세계 시장을 무대로 경쟁하고, 셀트리온의 Vision을 실현할 수 있는 열정이 있는 인재")]

wantPeople_b_dic['농심'] = [('충직','충성스럽고 정직하게 자신의 업무를 수행하는 사람'),
                    ('도전','실패를 두려워하지 않고 스스로를 극복하여 해내는 사람'),
                    ('창조','유연한 사고를 숙고하여 근본부터 뒤집어 볼 수 있는 사람'),
                    ('업무 전문가','맡은 분야의 업무지식과 핵심역량을 갖추어 최고를 지향하는 사람'),
                    ('사업 전문가','시장 통찰력과 올바른 전략으로 사업을 성공적으로 추진하는 사람'),
                    ('Global 전문가','글로벌 업무 경쟁력을 바탕으로 글로벌 시장을 개척해내는 사람')]

wantPeople_b_dic['삼성바이오로직스'] = [('바이오 인재상','회사 비전과 목표를 공유하며, 강한 열정과 책임감으로 해당분야 최고의 전문성과 실행력을 통해 성과창출을 극대화하고, 협업으로 집단지성을 추구하는 T자형 글로벌 인재')]

wantPeople_b_dic['두산'] = [('','세계 속의 자랑스러운 두산두산 Credo의 아홉 가지 핵심 가치'),
                    ('','자랑스러운 두산이란, 임직원을 포함한 모든 이해관계자들이 두산을 통해 자부심과 자랑스러움을 느낀다는 의미입니다.')]

wantPeople_b_dic['JW중외제약'] = [('Hi-Focuser', '생명존중과 개척정신을 계승한 Hi-Focuser는 환자 중심의 사고를 바탕으로 변화, 성장, 도전에 Focus하여 우리의 독보적 가치와 존재의 이유를 높이는 JW그룹의 인재상입니다.')]

wantPeople_b_dic['SK플래닛'] = [("", "포장하지 말고, 본질가치에 집중"), 
                        ("", "현장에서 답을 찾고 실행"),
                        ("", "주인의식으로 업무에 임한다"),
                        ("", "고객보다 앞서 생각하고 제안한다"),
                        ("", "기탄없이 비판하고 토론한다")]

wantPeople_b_dic['LS일렉트릭'] = [('Great Company', '고객에게 사랑받는 최고의 회사가 되어')]

wantPeople_b_dic['이수화학'] = [("", "기본적인 생활과 업무수행에 있어서 조직의 핵심가치가 제시하는 원칙을 바탕으로 행동하는 이수인"), 
                        ("", "창의적이고 능동적인 이수인"),
                        ("", "현재에 안주하지 않고, 늘 새로운 것에 대한 고민으로 창의적 열정이 가득한 이수인"),
                        ("", "새로운 것을 적극적으로 제안하고 실행할 수 있는 추진력을 보유한 이수인"),
                        ("", "언제나 성장하고 변화하는 이수인"),
                        ("", "스스로의 성장하고자 하는 노력을 통해 개인과 조직의 발전에 기여하는 이수인"),
                        ("", "개인의 혁신과 변화를 통해 조직의 변화를 주도하는 이수인")]

wantPeople_b_dic['우리은행'] = [("", "올바른 품성을 가진, 도전적이고 창의적인 최고의 금융전문가")]

wantPeople_b_dic['디엘'] = [("", "새로운 것을 찾는다"), 
                    ("", "자기 일에 으뜸이 된다"),
                    ("", "팀웍을 이룬다"),
                    ("", "멀리 내려다본다"),
                    ("", "고객을 잘안다"),
                    ("", "약속을 지킨다"),
                    ("", "근검절약을 한다")]

wantPeople_b_dic['삼성증권'] = [("", "우리는 형식보다 내용을 더 중요하게 생각합니다"), 
                    ("", "우리는 작은 것부터 변화를 시도합니다"),
                    ("", "우리는 스스로 질문하며 더 나음을 고민합니다"),
                    ("", "우리는 무엇이든 제대로 하기 위해 노력합니다"),
                    ("", "우리는 권위의식 없이 소통하며 서로를 배려합니다"),
                    ("", "우리는 안되는 이유 대신 되는 방법을 함께 찾습니다"),
                    ("", "우리는 가족에게 부끄러운 일은 하지 않습니다")]

wantPeople_b_dic['OCI'] = [("OUR VALUES", "도전정신을 가지고 철저한 준비를 통해 기회를 포착하여 더 나은 미래를 위해 끊임없이 변화")]

# %%
for v in wantPeople_b_dic.values():
    wantPeopleList.extend(v)

for name, values in wantPeople_b_dic.items():
    wantPeople_dic[name].extend(values)
    print(wantPeople_dic[name])
    print()
# Out:
# [('Hi-Focuser', '생명존중과 개척정신을 계승한 Hi-Focuser는 환자 중심의 사고를 바탕으로 변화, 성장, 도전에 Focus하여 우리의 독보적 가치와 존재의 이유를 높이는 JW그룹의 인재상입니다.')]
#
# [('', '포장하지 말고, 본질가치에 집중'), ('', '현장에서 답을 찾고 실행'), ('', '주인의식으로 업무에 임한다'), ('', '고객보다 앞서 생각하고 제안한다'), ('', '기탄없이 비판하고 토론한다')]
#
# [('바이오 인재상', '회사 비전과 목표를 공유하며, 강한 열정과 책임감으로 해당분야 최고의 전문성과 실행력을 통해 성과창출을 극대화하고, 협업으로 집단지성을 추구하는 T자형 글로벌 인재')]
#
# [('', '창의적인 사고와 발상의 전환을 통해 새로운 아이디어를 도출하고 문제를 해결하는 인재'), ('', '생명을 중시하며 엄정한 책임의식을 바탕으로 원칙을 준수하는 인재'), ('', '불굴의 도전정신을 가지고 업무에 임하며, 변화와 실패에 대한 두려움이 없는 인재'), ('', '세계 시장을 무대로 경쟁하고, 셀트리온의 Vision을 실현할 수 있는 열정이 있는 인재')]
#
# [('육성인화', '두산인은 사람을 성과의 도구로 생각하지 않으며, 하나의 인격체로 존중합니다.두산인은 조직 공동의 하나된 목표달성을 위해 자발적으로 합심하는 팀워크를 중시하고 실천합니다'), ('눈높이소통', '두산인은 무조건 1등만을 목표로 삼기보다 성취하였을 때 스스로 큰 자부심을 가질 만한 목표를 세웁니다.두산인은 언제든지 자신 있게 자신의 생각과 합리적 근거를 표현하고 다른 사람의 의견을 경청합니다.'), ('근성집중', '두산인은 문제의 해법을 찾을 때까지 포기하지 않고 모든 종류의 가능성을 시도하여 돌파구를 찾습니다.두산인은 가장 중요한 것을 찾아내고 이를 실행하는 데 집중합니다. 중요한 것을 찾아내면, 모든 가용자원을 총동원하여 이를 확실하게 먼저 해결해냅니다.'), ('', '세계 속의 자랑스러운 두산두산 Credo의 아홉 가지 핵심 가치'), ('', '자랑스러운 두산이란, 임직원을 포함한 모든 이해관계자들이 두산을 통해 자부심과 자랑스러움을 느낀다는 의미입니다.')]
#
# [('', '우리는 형식보다 내용을 더 중요하게 생각합니다'), ('', '우리는 작은 것부터 변화를 시도합니다'), ('', '우리는 스스로 질문하며 더 나음을 고민합니다'), ('', '우리는 무엇이든 제대로 하기 위해 노력합니다'), ('', '우리는 권위의식 없이 소통하며 서로를 배려합니다'), ('', '우리는 안되는 이유 대신 되는 방법을 함께 찾습니다'), ('', '우리는 가족에게 부끄러운 일은 하지 않습니다')]
#
# [('충직', '충성스럽고 정직하게 자신의 업무를 수행하는 사람'), ('도전', '실패를 두려워하지 않고 스스로를 극복하여 해내는 사람'), ('창조', '유연한 사고를 숙고하여 근본부터 뒤집어 볼 수 있는 사람'), ('업무 전문가', '맡은 분야의 업무지식과 핵심역량을 갖추어 최고를 지향하는 사람'), ('사업 전문가', '시장 통찰력과 올바른 전략으로 사업을 성공적으로 추진하는 사람'), ('Global 전문가', '글로벌 업무 경쟁력을 바탕으로 글로벌 시장을 개척해내는 사람')]
#
# [('', '기본적인 생활과 업무수행에 있어서 조직의 핵심가치가 제시하는 원칙을 바탕으로 행동하는 이수인'), ('', '창의적이고 능동적인 이수인'), ('', '현재에 안주하지 않고, 늘 새로운 것에 대한 고민으로 창의적 열정이 가득한 이수인'), ('', '새로운 것을 적극적으로 제안하고 실행할 수 있는 추진력을 보유한 이수인'), ('', '언제나 성장하고 변화하는 이수인'), ('', '스스로의 성장하고자 하는 노력을 통해 개인과 조직의 발전에 기여하는 이수인'), ('', '개인의 혁신과 변화를 통해 조직의 변화를 주도하는 이수인')]
#
# [('', '새로운 것을 찾는다'), ('', '자기 일에 으뜸이 된다'), ('', '팀웍을 이룬다'), ('', '멀리 내려다본다'), ('', '고객을 잘안다'), ('', '약속을 지킨다'), ('', '근검절약을 한다')]
#
# [('', '올바른 품성을 가진, 도전적이고 창의적인 최고의 금융전문가')]
#
# [('CHANCE', 'Seize Emerging Opportunities잠재적인 기회를 찾아내기 위해 관심을 보이고, 새로운 기회를 포착하면 신속히 결단하여 경쟁력 확보에 힘쓴다.Faster Than Market Change빠르게 변화하는 시장에 대한 정보를 신속히 파악 하여 시의 적절히 대응한다.'), ('CHALLENGE', 'Innovative Solution도전과 실패를 두려워하지 않으며, 문제 처리에 있어 관행적인 방식보다는 새로운 방식을 선호 하고 능동적으로 행동한다.Entrepreneurial Thinking지속가능한 가치를 추구하고, 고객의 니즈 충족과 회사 이익에 부합되는 대안을 효과적으로 제시한다.'), ('CHANGE', 'Global Outlook국제동향에 주의를 기울이며, 외부시장 변화에 주도적으로 대처한다.Flexible Open Mind다양한 문화와 사고방식에 대해 이해하고 공감 하는 자세를 가진다.'), ('OUR VALUES', '도전정신을 가지고 철저한 준비를 통해 기회를 포착하여 더 나은 미래를 위해 끊임없이 변화')]
#
# [('Pride', '일과 회사에 자부심을 갖고'), ('Technology', '기술에 대한 이해'), ('Global', '글로벌 역량으로'), ('Dream', '스마트 에너지의 미래를 꿈꾸며'), ('Partnership', '함께 더 큰 성과를 내는IMAGINEER(Imagine+Engineer)'), ('Great Company', '고객에게 사랑받는 최고의 회사가 되어')]
#
# [('', '꿈과 열정을 가지고 세계 최고에 도전하는 사람'), ('', '팀웍을 이루며 자율적이고 창의적으로 일하는 사람'), ('', '고객을 최우선으로 생각하고 끊임없이 혁신하는 사람'), ('', '꾸준히 실력을 배양하여 정정당당하게 경쟁하는 사람')]

# %%
wantPeople_dic['OCI']
# Out:
# [('CHANCE',
#   'Seize Emerging Opportunities잠재적인 기회를 찾아내기 위해 관심을 보이고, 새로운 기회를 포착하면 신속히 결단하여 경쟁력 확보에 힘쓴다.Faster Than Market Change빠르게 변화하는 시장에 대한 정보를 신속히 파악 하여 시의 적절히 대응한다.'),
#  ('CHALLENGE',
#   'Innovative Solution도전과 실패를 두려워하지 않으며, 문제 처리에 있어 관행적인 방식보다는 새로운 방식을 선호 하고 능동적으로 행동한다.Entrepreneurial Thinking지속가능한 가치를 추구하고, 고객의 니즈 충족과 회사 이익에 부합되는 대안을 효과적으로 제시한다.'),
#  ('CHANGE',
#   'Global Outlook국제동향에 주의를 기울이며, 외부시장 변화에 주도적으로 대처한다.Flexible Open Mind다양한 문화와 사고방식에 대해 이해하고 공감 하는 자세를 가진다.'),
#  ('OUR VALUES', '도전정신을 가지고 철저한 준비를 통해 기회를 포착하여 더 나은 미래를 위해 끊임없이 변화')]

# %%
print(len(wantPeopleList))
print(len(wantPeople_dic.keys()))
# Out:
# 1127
# 377

# %% [markdown]
# **유형**
# * ("키워드", "설명")
# * ("", "설명")
# * ("키워드", "")
# * ("큰범주", "설명(키워드, 설명)") - OCI

# %% [markdown]
# ### 없는 데이터 처리
# * 인재상에 대한 데이터가 없는 경우
# * 인재상의 정보가 핵심 가치에 적혀있는 경우

# %%
for name, values in wantPeople_dic.items():
    if len(values) == 0:
        print(name)
# Out:
# 교보문고
# HDC현대산업개발
# 에스엘
# 롯데정밀화학
# 진에어
# 오비맥주
# 무신사
# 한국수자원공사
# 한국인터넷진흥원
# CJ ENM
# 데상트코리아
# KCC
# 대교
# SK에너지
# 국민연금공단
# 신한카드
# 서울주택도시공사
# 대우건설
# CJ CGV
# 한국씨티은행
# KB증권
# LG CNS
# LS전선
# 마이다스아이티
# 한국수출입은행
# 금호타이어
# 신영증권
# DB생명보험
# 에이치케이이노엔
# 에어서울
# 삼성엔지니어링
# KT
# 현대차증권
# 국립생태원
# CJ대한통운
# 한국환경정책평가연구원
# 유진투자증권
# 라인프렌즈
# 오렌지라이프생명보험
# 딜리버리히어로코리아
# 웅진씽크빅
# 카카오뱅크
# 코레일테크
# 한국방송공사
# 한국과학기술원
# 현대모비스
# 동우화인켐
# 티웨이항공
# 한국원자력안전기술원
# 엔씨소프트
# 비바리퍼블리카
# NHN
# 국토연구원
# 금호건설
# 한국조폐공사
# 한양
# 국민건강보험공단
# 근로복지공단
# 악사손해보험
# 현대백화점
# 현대카드
# 우리카드
# 현대글로비스
# 대한항공
# 두산인프라코어
# 한국가스공사
# 이랜드월드
# 야놀자
# 라인플러스
# 한국문화정보원
# 나스미디어
# 한국아이비엠
# SBS
# 카카오게임즈
# 현대오일뱅크
# NH투자증권
# hy
# CJ제일제당
# 오뚜기
# 매일유업
# 한국콜마
# 네이버
# 이노션
# 이마트
# 한미약품
# BGF리테일
# 미래에셋자산운용
# 현대자동차
# 한국전력공사
# LG디스플레이
# 신세계인터내셔날
# 에스엠엔터테인먼트
# 코웨이
# 쿠팡

# %% [markdown]
# ### 카테고리 분류

# %% [markdown]
# #### 확인한 것 분류

# %%
def categorize(keyword, data_li):
    group = []
    
    for f in data_li[:]:
        if keyword in f[0]:
            data_li.pop(data_li.index(f))
            group.append(f)
        
    print('남은 데이터 개수: ', len(data_li))
    
    return group

# %%
wantPeople_copy = wantPeopleList[:]
wantCategoryDic = {}
keywords = ['혁신', '도전', '창의', '전문', '신뢰', '변화', '고객', '팀워크', '팀웍', '책임', '소통', '성실', '열심']

for w in keywords:
    wantCategoryDic[w] = categorize(w, wantPeople_copy)
# Out:
# 남은 데이터 개수:  1071
# 남은 데이터 개수:  994
# 남은 데이터 개수:  955
# 남은 데이터 개수:  876
# 남은 데이터 개수:  838
# 남은 데이터 개수:  825
# 남은 데이터 개수:  788
# 남은 데이터 개수:  779
# 남은 데이터 개수:  777
# 남은 데이터 개수:  757
# 남은 데이터 개수:  723
# 남은 데이터 개수:  718
# 남은 데이터 개수:  717

# %%
import pickle

f = open("wantPeople_dic.pickle", "wb")
pickle.dump(wantPeople_dic, f)
f.close()
f = open("wantPeopleList.pickle", "wb")
pickle.dump(wantPeopleList, f)
f.close()
