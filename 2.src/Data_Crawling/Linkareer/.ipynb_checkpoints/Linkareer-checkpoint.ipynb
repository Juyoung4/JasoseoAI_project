# %% [markdown]
# ## Linkareer crawling

# %% [markdown]
# ### [1] 크롤링
# [1] main url : https://linkareer.com/cover-letter/search?page=1&sort=PASSED_AT&tab=all
# * sort = 최신순
# * 한 페이지 당 20개, 총 자소서 14989

# %%
* 중간에 div 선분 있음 (짝수) / 그러므로 홀수 번호만 가져와야 함!
//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[1]/div[1]/a/div/p[1]
//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[1]/div[1]/a
//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[3]/div[1]/a
//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[5]/div[1]/a
....
//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[39]/div[1]/a

# %%
* 아래 내용들 크롤링 

현대엔지니어링 / 자산관리 자산설비 / 2021 상반기 : //*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[1]/h1
한양대 ERICA / 기계공학과 / 학점 3.78/4.5 /  : //*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[2]/p
내용 : //*[@id="coverLetterContent"]/main

# %% [markdown]
# * 전처리 해서 지금 못가져감 일단 다 저장한 다음 한번에 전처리 처리

# %%
from selenium import webdriver
    
import requests
import re
from multiprocessing import Process
import json
import os
from time import sleep

import csv
import platform

import traceback

import time

# %%
class Writer(object):
    def __init__(self, num, edit):
        self.file = None
        self.initializer_file(edit)
        self.csv_writer = csv.writer(self.file)
        if num == 1:
            self.csv_writer.writerow(['CompanyName', 'CompanyCareer', 'CompanyDate', 'UserInfos', 'Score', 'Content', 'URL'])
        else:
            self.csv_writer.writerow(['Company', 'UserInfos', 'Content', 'URL'])
    
    def initializer_file(self, edit):
        output_path = 'G:\내 드라이브\web_crawling'

        file_name = f'{output_path}/linkareer'+'.csv'

        if os.path.isfile(file_name):
            print("@@@@@@@ this file is remove and restart crawling! @@@@@@@")
        
        user_os = str(platform.system())
        if user_os == "Windows":
            if not edit:
                self.file = open(file_name, 'w', encoding='utf-8', newline='')
            else:
                self.file = open(file_name, 'a', encoding='utf-8', newline='')
        
    def write_row(self, row):
        self.csv_writer.writerow(row)
    
    def close(self):
        self.file.close()

# %%
class Linkareer(object):
    def __init__(self):
        self.main_url = f'https://linkareer.com/cover-letter/search?page='
        self.driver = webdriver.Chrome('C:/Users/msi/Downloads/chromedriver_win32/chromedriver.exe')
        self.links = []
        self.error_urls = []
        
    def get_links(self): # get 각 페이지에 있는 list들
        for page in range(1, 495): # 최대 494page임
            self.driver.get(self.main_url+str(page)+'&sort=PASSED_AT&tab=all')
            for i in range(1, 40, 2): # 한 페이지당 href 최대 개수는 20개
                self.links.append(self.driver.find_element_by_xpath(f'//*[@id="__next"]/div[1]/div/div[3]/div[2]/div/div[3]/div[1]/div[{i}]/div[1]/a').get_attribute("href"))  
                if page == 494 and i == 37: return
        return 
    
    def ErrorLog(self, url, error: str): 
        with open("Log.txt", "w") as f:
            f.write(f"[{url}] - {error}\n")
        
    def crawling1(self, check):
        writer = Writer(1, check)
        
        for link in self.links:
            self.driver.get(link)
            print("@@@ current url : ", self.driver.current_url)
            
            title = self.driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[1]/h1').text
            title = title.split("/")
            if len(title) < 3: title += []*(3-len(title))
            print("@@@@ title : ", [t.strip() for t in title])
            
            contents = self.driver.find_element_by_xpath('//*[@id="coverLetterContent"]/main').text
            #print("@@@@ content : ", contents[:15])

            try:
                if '학점' in user_info:
                    user_info = self.driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[2]/p').text
                    score = re.search('학점(.?)\d*(\.?\d*)(./)\d*(\.?\d*)(.)/', user_info)
                    if not score:
                        score = re.search('학점(.?)\d*(\.?\d*)', user_info).group()[0]
                    
                    user_info = user_info.replace(score, '')
                    score = score[2:].split('/')[0]
                else: score = ''
                print("@@@@ user info : ", score, user_info)
                
                # CSV파일에 작성
                writer.write_row([title[0], title[1], title[2], user_info, score, contents, link])

                del title
                del user_info
            except: # user info 없는 경우
                # 에러 났으면, 해당 url이랑 log 적고 넘기기
                err = traceback.format_exc()
                self.ErrorLog(link, str(err))
                self.error_urls.append(link)
                continue
            self.driver.implicitly_wait(0.1)
        writer.close()
    
    def crawling2(self, check):
        writer = Writer(2, check)
        
        for link in self.links:
            self.driver.get(link)
            print("@@@ current url : ", self.driver.current_url)
            
            try:
                title = self.driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[1]/h1').text
                user_info = self.driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[2]/p').text
                contents = self.driver.find_element_by_xpath('//*[@id="coverLetterContent"]/main').text
                writer.write_row([title, user_info, contents, link])
                del title
                del user_info
            except: # user info 없는 경우
                title = self.driver.find_element_by_xpath('//*[@id="__next"]/div[1]/div[1]/div/div/div[3]/div[1]/div/div/div[1]/h1').text
                contents = self.driver.find_element_by_xpath('//*[@id="coverLetterContent"]/main').text
                writer.write_row([title, '', contents, link])
                self.error_urls.append(link)
                continue
            self.driver.implicitly_wait(0.1)
        writer.close()
        
    def main(self):
        self.get_links()
        print("##### Total links : ", len(self.links))
        
        self.crawling()

# %%
links
# Out:
# ['https://linkareer.com/cover-letter/25156?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/24708?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25424?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/24965?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25713?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26490?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26420?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/24910?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25428?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26507?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25208?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/24867?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26470?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26551?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26118?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25453?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/24684?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/26402?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25147?page=2&sort=PASSED_AT&tab=all',
#  'https://linkareer.com/cover-letter/25569?page=2&sort=PASSED_AT&tab=all']

# %%
# 리스트 확인 작업
Crawler = Linkareer()
Crawler.get_links()

# %%
urls = Crawler.links[:]
len(Crawler.links)
# Out:
# 9879

# %%
Crawler.crawling2(False)
# Out:
# @@@@@@@ this file is remove and restart crawling! @@@@@@@
# @@@ current url :  https://linkareer.com/cover-letter/25204?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25579?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28660?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28662?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28755?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28753?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28762?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28746?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28665?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28761?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28759?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28657?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28661?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28760?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28658?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28758?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28756?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28752?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28751?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28663?page=1&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28749?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28754?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28659?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28748?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28747?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28666?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28757?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/28750?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24606?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24626?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26068?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25826?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25568?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24979?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25498?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26515?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26577?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24703?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24697?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25168?page=2&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25712?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26373?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24687?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24936?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25001?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24852?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24868?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26420?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24741?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24708?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24930?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25424?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24956?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26105?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26104?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26470?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25462?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26311?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26412?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24653?page=3&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24648?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26464?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26105?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24705?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24956?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25520?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24974?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25864?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25082?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26448?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26539?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25174?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25205?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26197?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26577?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24903?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25172?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24703?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24697?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26490?page=4&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25168?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24616?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26118?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25366?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25200?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25462?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26104?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26470?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25359?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25086?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24909?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25569?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26147?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25147?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24762?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25712?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26373?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24598?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25274?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26507?page=5&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25713?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26436?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24665?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26474?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25364?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26311?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25085?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24794?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25096?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25094?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25441?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25337?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24834?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26525?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26278?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24687?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24936?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25001?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24852?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25304?page=6&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25513?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25851?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26412?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25425?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26183?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26202?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25870?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24819?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25112?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24868?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26242?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25427?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25321?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25040?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25375?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25297?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26420?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24741?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24905?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26011?page=7&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26233?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26019?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24838?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25367?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26035?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25299?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26053?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25028?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26261?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25255?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24645?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26225?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24984?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25263?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25372?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25555?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26551?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24925?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25245?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25420?page=8&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24925?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25973?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26399?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25218?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25046?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26522?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25534?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25048?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25348?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26404?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26585?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25098?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25165?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25974?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26019?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24838?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25263?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24645?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25858?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25306?page=9&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24709?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26461?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26600?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25534?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25048?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25348?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25987?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26564?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25250?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25046?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25002?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24996?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26404?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26585?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26150?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26205?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24891?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24769?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26587?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26482?page=10&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25027?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25098?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25289?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25316?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25165?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25974?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25212?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25257?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24988?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24867?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24613?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26538?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25428?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24866?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25115?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26286?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25507?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24833?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26073?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24945?page=11&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25025?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/25164?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/24828?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26530?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26309?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26552?page=12&sort=PASSED_AT&tab=all
# @@@ current url :  https://linkareer.com/cover-letter/26252?page=12&sort=PASSED_AT&tab=all

# %%
error_urls = Crawler.error_urls[:]
len(Crawler.error_urls)

# %% [markdown]
# ### [2] 내용 확인

# %%
import pandas as pd

df = pd.read_csv('G:\내 드라이브\web_crawling\linkareer.csv')

df.isnull().sum()
# Out:
# CompanyName        0
# CompanyCareer      0
# CompanyDate        0
# UserInfos          0
# Score            407
# Content            0
# URL                0
# dtype: int64

# %%
len(df)

# %%
len(df)
# Out:
# 9023

# %%
df[df['Score'].isnull() == True]
# Out:
#        CompanyName CompanyCareer CompanyDate  \
# 170       삼성엔지니어링        플랜트 설계     2020 하반기
# 198   한미글로벌건축사사무소       사업관리 전기     2020 하반기
# 214        한국동서발전          발전전기     2020 하반기
# 257         효성중공업       건설 전기시공     2020 하반기
# 282        서울교통공사            사무     2020 하반기
# ...            ...           ...         ...
# 8863        현대모비스          연구개발     2015 하반기
# 8885      한국후지제록스            영업     2015 상반기
# 8918       LG유플러스          네트워크     2015 상반기
# 8988         동아지질          토목시공     2015 상반기
# 8990         대한항공        객실 승무원     2014 하반기
#
#                                               UserInfos Score  \
# 170   서울년제 / 전기공학과 / 학점.31/4.5 / 토익: 845, 오픽: IH / 사...   NaN
# 198   서울년제 / 전기공학과 / 학점.31/4.5 / 토익: 845, 오픽: IH / 사...   NaN
# 214   서울년제 / 전기공학과 / 학점.31/4.5 / 토익: 845, 오픽: IH / 사...   NaN
# 257   서울년제 / 전기공학과 / 학점.31/4.5 / 토익: 845, 오픽: IH / 사...   NaN
# 282   수도권년제 / 체육학과 / 학점 3.31 /.5 / 토익: 600 / 기타: MOS...   NaN
# ...                                                 ...   ...
# 8863      서울년제 / 컴퓨터공학 / 학점 3.0 / 토익 725 / 특허 유니버시아드 수상   NaN
# 8885   지방년제 / 상경계열 / 외국계기업 인턴, KT&G 상상 발렌티어, 상상프렌즈 대외활동   NaN
# 8918                     서울권년제 / 컴공 / 학점 3.5 / 앱 공모전 수상   NaN
# 8988                       서울년제 / 토목 / 학점 3.87 / 토익 830   NaN
# 8990  인서울년제 여대 / 영문과/경영복전 / 학점 3.5 / 토익 820 / 교내 통역봉...   NaN
#
#                                                 Content  \
# 170   1. 삼성엔지니어링을 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오...
# 198   1. 지원분야와 관련하여 귀하가 가진 역량(지식, 기술, 열정, 경력)에 대해 기술...
# 214   1. 귀하가 동서발전에 지원하게 된 계기는 무엇입니까?\n가) 우리 회사에 관심과 ...
# 257   1. 지원 직무 관련 자신이 갖춘 역량에 대하여 구체적으로 기술하여 주십시오.(수강...
# 282   1. 자신이 왜 서울교통공사의 인재상에 부합되는 인물이라고 생각하는지 구체적으로 기...
# ...                                                 ...
# 8863  현대모비스 해당 직무 분야에 지원하게 된 이유를 기재해 주시기 바랍니다. (700자...
# 8885  <한국후지제록스 자기소개서 항목>\n\n성장과정 및 자기소개\n\n[시련을 통해 배...
# 8918  ■ ‘회사 및 지원 직무에 대한 지원동기’와 ‘해당 직무를 잘 수행하기 위해 어떤 ...
# 8988  성장과정 \n\n‘검토의 습관’\n학창시절 100% 완벽하게 준비하지 못하는 성격을...
# 8990  1. 지원동기\n\n교환학생으로 영국에서 보낸 6개월 동안 저는 다른 문화를 가진 ...
#
#                                                     URL
# 170   https://linkareer.com/cover-letter/25487?page=...
# 198   https://linkareer.com/cover-letter/25479?page=...
# 214   https://linkareer.com/cover-letter/25449?page=...
# 257   https://linkareer.com/cover-letter/25450?page=...
# 282   https://linkareer.com/cover-letter/25367?page=...
# ...                                                 ...
# 8863  https://linkareer.com/cover-letter/13365?page=...
# 8885  https://linkareer.com/cover-letter/13230?page=...
# 8918  https://linkareer.com/cover-letter/13151?page=...
# 8988  https://linkareer.com/cover-letter/20228?page=...
# 8990  https://linkareer.com/cover-letter/15410?page=...
#
# [407 rows x 7 columns]
