# %% [markdown]
# # 데이터 전처리

# %%
from selenium import webdriver
import time
import pickle

# %%
URL = 'https://www.jobkorea.co.kr/starter/passassay/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('headless')
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('lang=ko_KR')

driver = webdriver.Chrome(executable_path='chromedriver', chrome_options=chrome_options)
driver.implicitly_wait(2)

driver.get(url=URL)
# Out:
# <ipython-input-21-7da07ceafcb5>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path='chromedriver', chrome_options=chrome_options)

# %%
def get_pageNum():
    pageNumList = driver.find_element_by_class_name('tplPagination')
    pageNumList = pageNumList.find_elements_by_tag_name('a')
    pageNumList = [url.get_attribute('href') for url in pageNumList]
    
    return pageNumList

# %%
def get_resumeUrlList():
    resumeList_class = driver.find_element_by_class_name('selfLists')
    resumeClass_tit = resumeList_class.find_elements_by_class_name('tit')
    corpName = [url.find_element_by_class_name('titTx').get_attribute('textContent').strip() for url in resumeClass_tit]
    resumeUrlList = [url.find_element_by_tag_name('a').get_attribute('href') for url in resumeClass_tit]
    
    return corpName, resumeUrlList

# %%
def get_resumeData():
    queList, ansList, adivceList = [], [], []
    
    qnaList_class = driver.find_element_by_class_name('qnaLists') 
    queList_dt = qnaList_class.find_elements_by_tag_name('dt')
    ansList_dd = qnaList_class.find_elements_by_tag_name('dd')

    queList = [q.find_element_by_class_name('tx').get_attribute('textContent').strip() for q in queList_dt]
    ansList = [a.find_element_by_class_name('tx').get_attribute('textContent').strip() for a in ansList_dd]
    
    for dd in ansList_dd:
        try:
            advs = dd.find_element_by_class_name('advice').find_elements_by_tag_name('p')
            advText = ''
            for adv in advs:
                advText += adv.get_attribute('textContent').strip() + '\n'
                
            adivceList.append(advText)
        except:
            adivceList.append('')
    
    return (queList, ansList, adivceList)

# %%
link = "https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page="
# AllResumeData = {}

pageUrlList = [link + str(i) for i in range(241, 340)]
count = 4800
flag = True

error = []

for i, pageUrl in enumerate(pageUrlList):
    print("현재 URL: ", pageUrl)
    print("진행정도: {:.2f}% ({}/{})".format((i+1) / len(pageUrlList) * 100, i+1, len(pageUrlList)), end=' / ')
    driver.get(pageUrl)
    
    corpNames, resumeUrlList = get_resumeUrlList()
    print("현재 page 자소서 개수: ", len(resumeUrlList))
    for corpName, resumeURL in zip(corpNames, resumeUrlList):
        try:
            count += 1
            print("진행 상황: {}/{}".format(count, 6630), end='\r',flush=True)
            driver.get(resumeURL)

            AllResumeData[count] = (corpName, get_resumeData())
            
        except Exception as e:
            print(e)
            error.append(count)
            
    
    if count % 1000 == 0:
        f = open('jobkor_backup_{}.pickle'.format(count), 'wb')
        pickle.dump(AllResumeData, f)
        f.close()
# Out:
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=241
# 진행정도: 1.01% (1/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=242
# 진행정도: 2.02% (2/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=243
# 진행정도: 3.03% (3/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=244
# 진행정도: 4.04% (4/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=245
# 진행정도: 5.05% (5/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=246
# 진행정도: 6.06% (6/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=247
# 진행정도: 7.07% (7/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=248
# 진행정도: 8.08% (8/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=249
# 진행정도: 9.09% (9/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=250
# 진행정도: 10.10% (10/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=251
# 진행정도: 11.11% (11/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=252
# 진행정도: 12.12% (12/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=253
# 진행정도: 13.13% (13/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=254
# 진행정도: 14.14% (14/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=255
# 진행정도: 15.15% (15/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=256
# 진행정도: 16.16% (16/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=257
# 진행정도: 17.17% (17/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=258
# 진행정도: 18.18% (18/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=259
# 진행정도: 19.19% (19/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=260
# 진행정도: 20.20% (20/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=261
# 진행정도: 21.21% (21/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=262
# 진행정도: 22.22% (22/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=263
# 진행정도: 23.23% (23/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=264
# 진행정도: 24.24% (24/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=265
# 진행정도: 25.25% (25/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=266
# 진행정도: 26.26% (26/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=267
# 진행정도: 27.27% (27/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=268
# 진행정도: 28.28% (28/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=269
# 진행정도: 29.29% (29/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=270
# 진행정도: 30.30% (30/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=271
# 진행정도: 31.31% (31/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=272
# 진행정도: 32.32% (32/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=273
# 진행정도: 33.33% (33/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=274
# 진행정도: 34.34% (34/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=275
# 진행정도: 35.35% (35/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=276
# 진행정도: 36.36% (36/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=277
# 진행정도: 37.37% (37/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=278
# 진행정도: 38.38% (38/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=279
# 진행정도: 39.39% (39/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=280
# 진행정도: 40.40% (40/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=281
# 진행정도: 41.41% (41/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=282
# 진행정도: 42.42% (42/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=283
# 진행정도: 43.43% (43/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=284
# 진행정도: 44.44% (44/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=285
# 진행정도: 45.45% (45/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=286
# 진행정도: 46.46% (46/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=287
# 진행정도: 47.47% (47/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=288
# 진행정도: 48.48% (48/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=289
# 진행정도: 49.49% (49/99) / 현재 page 자소서 개수:  20
# Alert Text: 선택하신 합격자소서 정보가 없습니다.
# Message: unexpected alert open: {Alert text : 선택하신 합격자소서 정보가 없습니다.}
#   (Session info: headless chrome=92.0.4515.159)
#
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=290
# 진행정도: 50.51% (50/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=291
# 진행정도: 51.52% (51/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=292
# 진행정도: 52.53% (52/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=293
# 진행정도: 53.54% (53/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=294
# 진행정도: 54.55% (54/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=295
# 진행정도: 55.56% (55/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=296
# 진행정도: 56.57% (56/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=297
# 진행정도: 57.58% (57/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=298
# 진행정도: 58.59% (58/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=299
# 진행정도: 59.60% (59/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=300
# 진행정도: 60.61% (60/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=301
# 진행정도: 61.62% (61/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=302
# 진행정도: 62.63% (62/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=303
# 진행정도: 63.64% (63/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=304
# 진행정도: 64.65% (64/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=305
# 진행정도: 65.66% (65/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=306
# 진행정도: 66.67% (66/99) / 현재 page 자소서 개수:  20
# 현재 URL:  https://www.jobkorea.co.kr/starter/PassAssay?FavorCo_Stat=0&Pass_An_Stat=0&OrderBy=0&EduType=0&WorkType=0&isSaved=0&Page=307
# 진행정도: 67.68% (67/99) / 현재 page 자소서 개수:  20
# 진행 상황: 6139/6630

# %%
f = open('jobkor_backup_{}.pickle'.format(count), 'wb')
pickle.dump(AllResumeData, f)
f.close()
